# %%
# Import Library
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ### Halaman 1

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/?s={}".format(keyword)

# %%
#Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
"""
"Untuk Looping Cuman Masih Gagal"
data = []

for page in range(1, 56):
    req = requests.get("https://turnbackhoax.id/?s=covid-19"+ str(page))
    soup = BeautifulSoup(req.text, "html.parser")
    
    content = [1, 56]
    for teks in content:
        column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))
    
    for i in column:
        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
        link = i.find("a", {"rel": "bookmark"})["href"]
data.append([text, link])
"""
# Out:
# '\n"Untuk Looping Cuman Masih Gagal"\ndata = []\n\nfor page in range(1, 56):\n    req = requests.get("https://turnbackhoax.id/?s=covid-19"+ str(page))\n    soup = BeautifulSoup(req.text, "html.parser")\n    \n    content = [1, 56]\n    for teks in content:\n        column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))\n    \n    for i in column:\n        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")\n        link = i.find("a", {"rel": "bookmark"})["href"]\ndata.append([text, link])\n'

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df1 = pd.DataFrame(data)
df1.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Vaksin Covid-19 Dapat Mengubah Warna ...
# 1  [[SALAH] Mengonsumsi Labu Kuning Dapat Menyemb...
# 2        [[SALAH] Muammar Gaddafi Prediksi Covid-19]
# 3  [[SALAH] Obat Covid-19 Molnulpiravir Mulai Ber...
# 4  [[SALAH] Campuran Air Kelapa Muda, Jeruk Nipis...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/09/30/salah-vaksi...
# 1  https://turnbackhoax.id/2021/09/22/salah-mengo...
# 2  https://turnbackhoax.id/2021/09/04/salah-muamm...
# 3  https://turnbackhoax.id/2021/09/03/salah-obat-...
# 4  https://turnbackhoax.id/2021/08/30/salah-campu...

# %%
# Mengganti nama kolom pada DataFrame "df1"
df1.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df1.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Vaksin Covid-19 Dapat Mengubah Warna ...
# 1  [[SALAH] Mengonsumsi Labu Kuning Dapat Menyemb...
# 2        [[SALAH] Muammar Gaddafi Prediksi Covid-19]
# 3  [[SALAH] Obat Covid-19 Molnulpiravir Mulai Ber...
# 4  [[SALAH] Campuran Air Kelapa Muda, Jeruk Nipis...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/09/30/salah-vaksi...
# 1  https://turnbackhoax.id/2021/09/22/salah-mengo...
# 2  https://turnbackhoax.id/2021/09/04/salah-muamm...
# 3  https://turnbackhoax.id/2021/09/03/salah-obat-...
# 4  https://turnbackhoax.id/2021/08/30/salah-campu...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 2

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/2/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df2 = pd.DataFrame(data)
df2.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Mata Jenazah Covid-19 diambil tanpa S...
# 1  [[SALAH] Minuman Penambah Imun untuk Cegah Pen...
# 2  [[SALAH] Singapura Negara Pertama yang Lakukan...
# 3  [[SALAH] Nilai CT Pada Tes PCR Menentukan Kese...
# 4  [[SALAH] Banyaknya Varian Covid-19 Muncul Sete...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/07/25/salah-mata-...
# 1  https://turnbackhoax.id/2021/07/21/salah-minum...
# 2  https://turnbackhoax.id/2021/07/20/salah-singa...
# 3  https://turnbackhoax.id/2021/07/19/salah-nilai...
# 4  https://turnbackhoax.id/2021/07/19/salah-banya...

# %%
# Mengganti nama kolom pada DataFrame "df2"
df2.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df2.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Mata Jenazah Covid-19 diambil tanpa S...
# 1  [[SALAH] Minuman Penambah Imun untuk Cegah Pen...
# 2  [[SALAH] Singapura Negara Pertama yang Lakukan...
# 3  [[SALAH] Nilai CT Pada Tes PCR Menentukan Kese...
# 4  [[SALAH] Banyaknya Varian Covid-19 Muncul Sete...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/25/salah-mata-...
# 1  https://turnbackhoax.id/2021/07/21/salah-minum...
# 2  https://turnbackhoax.id/2021/07/20/salah-singa...
# 3  https://turnbackhoax.id/2021/07/19/salah-nilai...
# 4  https://turnbackhoax.id/2021/07/19/salah-banya...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 3

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/3/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df3 = pd.DataFrame(data)
df3.head()
# Out:
#                                                    0  \
# 0         [[SALAH] Resep Obat Untuk Pasien Covid-19]
# 1  [[SALAH] Jateng Membludak, Media TV Hanya Lipu...
# 2  [[SALAH] “Pemkot Pekanbaru, Riau menarik vaksi...
# 3  [[SALAH] Vaksinasi Sebabkan Varian Baru COVID-19]
# 4  [[SALAH] Video “Eric Tohir Sangat Terbuka Menj...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/06/25/salah-resep...
# 1  https://turnbackhoax.id/2021/06/24/salah-jaten...
# 2  https://turnbackhoax.id/2021/06/17/salah-pemko...
# 3  https://turnbackhoax.id/2021/06/16/salah-vaksi...
# 4  https://turnbackhoax.id/2021/06/11/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df3"
df3.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df3.head()
# Out:
#                                                 Text  \
# 0         [[SALAH] Resep Obat Untuk Pasien Covid-19]
# 1  [[SALAH] Jateng Membludak, Media TV Hanya Lipu...
# 2  [[SALAH] “Pemkot Pekanbaru, Riau menarik vaksi...
# 3  [[SALAH] Vaksinasi Sebabkan Varian Baru COVID-19]
# 4  [[SALAH] Video “Eric Tohir Sangat Terbuka Menj...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/06/25/salah-resep...
# 1  https://turnbackhoax.id/2021/06/24/salah-jaten...
# 2  https://turnbackhoax.id/2021/06/17/salah-pemko...
# 3  https://turnbackhoax.id/2021/06/16/salah-vaksi...
# 4  https://turnbackhoax.id/2021/06/11/salah-video...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 4

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/4/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df4 = pd.DataFrame(data)
df4.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Foto Seorang Lansia Menggunakan Alat ...
# 1  [[FALSE] Inhaling Mothballs, Cloves, Carom See...
# 2  [[SALAH] Menghirup Kapur Barus, Cengkeh, Biji ...
# 3  [[FALSE] All Covid-19 Vaccine Test Animals Are...
# 4  [[SALAH] Makan Bawang Mentah dan Garam bisa Ub...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/04/25/salah-foto-...
# 1  https://turnbackhoax.id/2021/04/25/false-inhal...
# 2  https://turnbackhoax.id/2021/04/23/salah-mengh...
# 3  https://turnbackhoax.id/2021/04/22/false-all-c...
# 4  https://turnbackhoax.id/2021/04/21/salah-makan...

# %%
# Mengganti nama kolom pada DataFrame "df4"
df4.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df4.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Foto Seorang Lansia Menggunakan Alat ...
# 1  [[FALSE] Inhaling Mothballs, Cloves, Carom See...
# 2  [[SALAH] Menghirup Kapur Barus, Cengkeh, Biji ...
# 3  [[FALSE] All Covid-19 Vaccine Test Animals Are...
# 4  [[SALAH] Makan Bawang Mentah dan Garam bisa Ub...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/04/25/salah-foto-...
# 1  https://turnbackhoax.id/2021/04/25/false-inhal...
# 2  https://turnbackhoax.id/2021/04/23/salah-mengh...
# 3  https://turnbackhoax.id/2021/04/22/false-all-c...
# 4  https://turnbackhoax.id/2021/04/21/salah-makan...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 5

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/5/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df5 = pd.DataFrame(data)
df5.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Menghirup Uap Panas Teh Herbal Dapat ...
# 1  [[SALAH] Pesan Berantai Video “Potensi Bahaya ...
# 2  [[SALAH] Uap Panas Hasil Rebusan Daun Jambu da...
# 3  [[SALAH] Pemberian Vaksin Covid-19 oleh Badan ...
# 4  [[SALAH] “kenapa semua nya meninggal dengan ci...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/10/salah-mengh...
# 1  https://turnbackhoax.id/2021/03/07/salah-pesan...
# 2  https://turnbackhoax.id/2021/03/07/salah-uap-p...
# 3  https://turnbackhoax.id/2021/03/06/salah-pembe...
# 4  https://turnbackhoax.id/2021/03/05/salah-kenap...

# %%
# Mengganti nama kolom pada DataFrame "df5"
df5.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df5.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Menghirup Uap Panas Teh Herbal Dapat ...
# 1  [[SALAH] Pesan Berantai Video “Potensi Bahaya ...
# 2  [[SALAH] Uap Panas Hasil Rebusan Daun Jambu da...
# 3  [[SALAH] Pemberian Vaksin Covid-19 oleh Badan ...
# 4  [[SALAH] “kenapa semua nya meninggal dengan ci...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/03/10/salah-mengh...
# 1  https://turnbackhoax.id/2021/03/07/salah-pesan...
# 2  https://turnbackhoax.id/2021/03/07/salah-uap-p...
# 3  https://turnbackhoax.id/2021/03/06/salah-pembe...
# 4  https://turnbackhoax.id/2021/03/05/salah-kenap...

# %% [markdown]
# ### Halaman 6

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/6/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df6 = pd.DataFrame(data)
df6.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Nomor Palsu Satgas Covid-19 Beredar d...
# 1     [[SALAH] Diagram Chip 5G pada Vaksin Covid-19]
# 2  [[SALAH] Obat COVID-19 Dexamethasone Lebih Mur...
# 3  [[SALAH] “Eric tohir sang missionaris chip cov...
# 4  [[SALAH] “5 cara utk meningkatkan ANTI BODY” d...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/28/salah-nomor...
# 1  https://turnbackhoax.id/2021/01/21/salah-diagr...
# 2  https://turnbackhoax.id/2021/01/21/salah-obat-...
# 3  https://turnbackhoax.id/2021/01/21/salah-penje...
# 4  https://turnbackhoax.id/2021/01/20/salah-5-car...

# %%
# Mengganti nama kolom pada DataFrame "df6"
df6.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df6.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Nomor Palsu Satgas Covid-19 Beredar d...
# 1     [[SALAH] Diagram Chip 5G pada Vaksin Covid-19]
# 2  [[SALAH] Obat COVID-19 Dexamethasone Lebih Mur...
# 3  [[SALAH] “Eric tohir sang missionaris chip cov...
# 4  [[SALAH] “5 cara utk meningkatkan ANTI BODY” d...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/01/28/salah-nomor...
# 1  https://turnbackhoax.id/2021/01/21/salah-diagr...
# 2  https://turnbackhoax.id/2021/01/21/salah-obat-...
# 3  https://turnbackhoax.id/2021/01/21/salah-penje...
# 4  https://turnbackhoax.id/2021/01/20/salah-5-car...

# %% [markdown]
# ### Halaman 7

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/7/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df7 = pd.DataFrame(data)
df7.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video Ribuan Jamaah Tanpa Masker Samb...
# 1  [[SALAH] “Bill Gates mengatakan dia tidak akan...
# 2  [[SALAH] Minum Teh Dengan Batang Lada Dapat Se...
# 3  [[SALAH] Istora Senayan Dijadikan Tempat Penam...
# 4  [[SALAH] Tiga Wanita Bintang Iklan Jamu Covid-19]
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/02/salah-video...
# 1  https://turnbackhoax.id/2021/01/02/salah-bill-...
# 2  https://turnbackhoax.id/2021/01/02/salah-minum...
# 3  https://turnbackhoax.id/2021/01/01/salah-istor...
# 4  https://turnbackhoax.id/2020/12/28/salah-tiga-...

# %%
# Mengganti nama kolom pada DataFrame "df7"
df7.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df7.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video Ribuan Jamaah Tanpa Masker Samb...
# 1  [[SALAH] “Bill Gates mengatakan dia tidak akan...
# 2  [[SALAH] Minum Teh Dengan Batang Lada Dapat Se...
# 3  [[SALAH] Istora Senayan Dijadikan Tempat Penam...
# 4  [[SALAH] Tiga Wanita Bintang Iklan Jamu Covid-19]
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/01/02/salah-video...
# 1  https://turnbackhoax.id/2021/01/02/salah-bill-...
# 2  https://turnbackhoax.id/2021/01/02/salah-minum...
# 3  https://turnbackhoax.id/2021/01/01/salah-istor...
# 4  https://turnbackhoax.id/2020/12/28/salah-tiga-...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 8

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/8/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df8 = pd.DataFrame(data)
df8.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Gratis Langganan Netflix Selama Satu ...
# 1   [[SALAH] Kopi Bisa Cegah dan Sembuhkan Covid-19]
# 2  [[SALAH] Foto Keadaan Rumah Sakit yang Sepi da...
# 3  [[SALAH] Vaksin Covid-19 berbasis mRNA Dapat M...
# 4  [[SALAH] Kebijakan Ticketmaster, Wajibkan Vaks...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/07/salah-grati...
# 1  https://turnbackhoax.id/2020/12/07/salah-kopi-...
# 2  https://turnbackhoax.id/2020/12/04/salah-foto-...
# 3  https://turnbackhoax.id/2020/11/28/salah-vaksi...
# 4  https://turnbackhoax.id/2020/11/27/salah-kebij...

# %%
# Mengganti nama kolom pada DataFrame "df8"
df8.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df8.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Gratis Langganan Netflix Selama Satu ...
# 1   [[SALAH] Kopi Bisa Cegah dan Sembuhkan Covid-19]
# 2  [[SALAH] Foto Keadaan Rumah Sakit yang Sepi da...
# 3  [[SALAH] Vaksin Covid-19 berbasis mRNA Dapat M...
# 4  [[SALAH] Kebijakan Ticketmaster, Wajibkan Vaks...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/12/07/salah-grati...
# 1  https://turnbackhoax.id/2020/12/07/salah-kopi-...
# 2  https://turnbackhoax.id/2020/12/04/salah-foto-...
# 3  https://turnbackhoax.id/2020/11/28/salah-vaksi...
# 4  https://turnbackhoax.id/2020/11/27/salah-kebij...

# %%
df8.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Pesan Pembuatan Grup WhatsApp tentang...
# 16  [[SALAH] Kawasan Johor Baru Malaysia Terdampak...
# 17  [[SALAH] Pandemi Telah Berakhir dan Covid-19 A...
# 18  [[SALAH] “Pendataan Imunisasi Covid-19 untuk T...
# 19  [[SALAH] Jenazah Pasien Covid-19 Dikubur Masih...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/10/27/salah-pesan...
# 16  https://turnbackhoax.id/2020/10/27/salah-kawas...
# 17  https://turnbackhoax.id/2020/10/25/salah-pande...
# 18  https://turnbackhoax.id/2020/10/23/salah-penda...
# 19  https://turnbackhoax.id/2020/10/20/salah-jenaz...

# %% [markdown]
# ### Halaman 9

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/9/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df9 = pd.DataFrame(data)
df9.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Vaksin COVID-19 Dapat Mengubah DNA Ma...
# 1  [[SALAH] Presiden Donald Trump Meninggal Dunia...
# 2  [[SALAH] MUI Larang Penggunaan Vaksin Covid-19...
# 3  [[SALAH] COVID-19 Tidak Membuat Orang Meningga...
# 4  [[SALAH] Foto Dokter Menyatakan COVID-19 Diseb...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/19/salah-vaksi...
# 1  https://turnbackhoax.id/2020/10/17/salah-presi...
# 2  https://turnbackhoax.id/2020/10/16/salah-mui-l...
# 3  https://turnbackhoax.id/2020/10/15/salah-covid...
# 4  https://turnbackhoax.id/2020/10/14/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df9"
df9.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df9.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Vaksin COVID-19 Dapat Mengubah DNA Ma...
# 1  [[SALAH] Presiden Donald Trump Meninggal Dunia...
# 2  [[SALAH] MUI Larang Penggunaan Vaksin Covid-19...
# 3  [[SALAH] COVID-19 Tidak Membuat Orang Meningga...
# 4  [[SALAH] Foto Dokter Menyatakan COVID-19 Diseb...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/10/19/salah-vaksi...
# 1  https://turnbackhoax.id/2020/10/17/salah-presi...
# 2  https://turnbackhoax.id/2020/10/16/salah-mui-l...
# 3  https://turnbackhoax.id/2020/10/15/salah-covid...
# 4  https://turnbackhoax.id/2020/10/14/salah-foto-...

# %% [markdown]
# ### Halaman 10

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/10/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df10 = pd.DataFrame(data)
df10.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Foto Peta Persebaran COVID-19 di Jaka...
# 1  [[SALAH] Sejumlah Negara Membeli Produk Alat T...
# 2  [[SALAH] Video Teknik Menahan Napas Untuk Dete...
# 3  [[SALAH] Covid-19 Singkatan dari Certificate o...
# 4  [[SALAH] Pesan Berantai “Salah Satu Cara Untuk...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/18/salah-foto-...
# 1  https://turnbackhoax.id/2020/09/18/salah-sejum...
# 2  https://turnbackhoax.id/2020/09/14/salah-video...
# 3  https://turnbackhoax.id/2020/09/06/salah-covid...
# 4  https://turnbackhoax.id/2020/09/05/salah-pesan...

# %%
# Mengganti nama kolom pada DataFrame "df10"
df10.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df10.tail()
# Out:
#                                                  Text  \
# 15      [[SALAH] Kanada Sudah Terbebas dari Covid-19]
# 16  [[SALAH] Pesan Berantai Kantor Pusat PT Kawan ...
# 17  [[ACARA] Muhammadiyah COVID-19 Command Center:...
# 18  [[SALAH] Setiap Hari Puskesmas di Kelapa Gadin...
# 19  [[SALAH] Pedagang di Pasar Mayestik Meninggal ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/11/salah-kanad...
# 16  https://turnbackhoax.id/2020/08/10/salah-pesan...
# 17  https://turnbackhoax.id/2020/08/08/acara-muham...
# 18  https://turnbackhoax.id/2020/08/07/salah-setia...
# 19  https://turnbackhoax.id/2020/08/07/salah-pedag...

# %% [markdown]
# ### Halaman 11

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/11/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df11 = pd.DataFrame(data)
df11.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Beberapa RSUD Di Jakarta dan Depok Di...
# 16  [[SALAH] Pedagang di Pasar Segiri Positif Covi...
# 17  [[SALAH] Nasi Padang Menjadi Sumber Penularan ...
# 18  [[SALAH] “Video pembuangan jenazah-jenazah kor...
# 19  [[SALAH] “SEHARI SETELAH DILAKUKAN RAPID TEST ...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/07/16/salah-beber...
# 16  https://turnbackhoax.id/2020/07/13/salah-pedag...
# 17  https://turnbackhoax.id/2020/07/13/salah-nasi-...
# 18  https://turnbackhoax.id/2020/07/12/salah-video...
# 19  https://turnbackhoax.id/2020/07/05/salah-sehar...

# %%
# Mengganti nama kolom pada DataFrame "df11"
df11.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df11.head()
# Out:
#                                                 Text  \
# 0  [[ACARA] MAFINDO Malang: Bincang Online “Cek F...
# 1  [[DOKUMENTASI] MAFINDO Jombang: The Fact Talk ...
# 2  [[BERITA] KOMPAS: “Infodemi Membuat Publik Aba...
# 3  [[SALAH] Foto Presiden Jokowi Bersama Pelawak ...
# 4         [[SALAH] Klaim Hadi Pranoto Soal COVID-19]
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/08/05/dokumentasi...
# 1  https://turnbackhoax.id/2020/08/05/dokumentasi...
# 2  https://turnbackhoax.id/2020/08/05/berita-komp...
# 3  https://turnbackhoax.id/2020/08/04/salah-foto-...
# 4  https://turnbackhoax.id/2020/08/04/salah-klaim...

# %% [markdown]
# ### Halaman 12

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/12/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
"""
"Untuk Looping Cuman Masih Gagal"
data = []
#count_page = 0

for page in range(1, 56):
    #count_page += 1
    #print("Halaman Scrapping: ", count_page)
    
    req = requests.get(url + str(page))
    soup = BeautifulSoup(req.text, "html.parser")
    column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))
    
    for i in column:
        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
        link = i.find("a", {"rel": "bookmark"})["href"]
        data.append([text, link])
"""
# Out:
# '\n"Untuk Looping Cuman Masih Gagal"\ndata = []\n#count_page = 0\n\nfor page in range(1, 56):\n    #count_page += 1\n    #print("Halaman Scrapping: ", count_page)\n    \n    req = requests.get(url + str(page))\n    soup = BeautifulSoup(req.text, "html.parser")\n    column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))\n    \n    for i in column:\n        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")\n        link = i.find("a", {"rel": "bookmark"})["href"]\n        data.append([text, link])\n'

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df12 = pd.DataFrame(data)
df12.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “warga Puruk cahu murung raya desa ma...
# 16  [[SALAH] Video “Kisah pilu dari ITALY IBU nya ...
# 17  [[SALAH] PBB Tak Beri Bantuan Covid-19 Bagi Ne...
# 18  [[SALAH] “Italia mengalahkan COVID-19 “Koagula...
# 19  [[SALAH] “WHO: Pria berpenis besar lebih renta...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/05/28/salah-warga...
# 16  https://turnbackhoax.id/2020/05/27/salah-video...
# 17  https://turnbackhoax.id/2020/05/26/salah-pbb-t...
# 18  https://turnbackhoax.id/2020/05/26/salah-itali...
# 19  https://turnbackhoax.id/2020/05/22/salah-who-p...

# %%
# Mengganti nama kolom pada DataFrame "df12"
df12.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df12.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Desain Helm Covid-19 Pada Kompetisi NFL]
# 1  [[SALAH] Pesta Homo Seksual di Italia Sebelum ...
# 2  [[SALAH] Tak Perlu Ikut Rapid Test, Mencium Ba...
# 3  [[SALAH] Dokter RSAL Surabaya Meninggal akibat...
# 4             [[ACARA] Sosialisasi Waspada COVID-19]
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/07/03/salah-desai...
# 1  https://turnbackhoax.id/2020/06/27/salah-pesta...
# 2  https://turnbackhoax.id/2020/06/25/salah-tak-p...
# 3  https://turnbackhoax.id/2020/06/23/salah-dokte...
# 4  https://turnbackhoax.id/2020/06/20/acara-sosia...

# %% [markdown]
# ### Halaman 13

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/13/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df13 = pd.DataFrame(data)
df13.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Donasi Bahan Iftar dan Sahur di Masa ...
# 16  [[SALAH] ”Seorang Pasien Dalam Pengawasan Covi...
# 17  [[SALAH] Pesan Berantai “Taman Raya Tahap V Zo...
# 18  [[SALAH] Kuota 100GB Gratis dari Pemerintah Se...
# 19  [[SALAH] “Ternyata Klaster penyebar Covid-19 t...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/05/12/salah-donas...
# 16  https://turnbackhoax.id/2020/05/11/salah-seora...
# 17  https://turnbackhoax.id/2020/05/11/salah-pesan...
# 18  https://turnbackhoax.id/2020/05/10/salah-kuota...
# 19  https://turnbackhoax.id/2020/05/10/salah-terny...

# %%
# Mengganti nama kolom pada DataFrame "df13"
df13.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df13.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Sekeluarga Terinfeksi Covid-19 Setela...
# 1  [[SALAH] Golden Swalayan Jadi Klaster Baru Cov...
# 2  [[SALAH] Manager Giant Pal 6 Banjarmasin Menin...
# 3  [[SALAH] “Registrasi Ambil Dana Bantuan Anda C...
# 4  [[SALAH] “Pemerintah Takkan Umumkan Lagi Kasus...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/05/22/salah-sekel...
# 1  https://turnbackhoax.id/2020/05/19/salah-golde...
# 2  https://turnbackhoax.id/2020/05/19/salah-manag...
# 3  https://turnbackhoax.id/2020/05/18/salah-regis...
# 4  https://turnbackhoax.id/2020/05/18/salah-pemer...

# %% [markdown]
# ### Halaman 14

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/14/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df14 = pd.DataFrame(data)
df14.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Hanya di Indonesia Narapidana Dibebas...
# 16  [[SALAH] Beberapa Negara Membuang Jenazah Pasi...
# 17  [[SALAH] Peta Sebaran Covid-19 Wilayah Situbondo]
# 18  [[SALAH] Dari Ratusan Ribu Tahanan Tidak Ada S...
# 19  [[SALAH] Alfamart Menyumbangkan 6000 Kupon Unt...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/26/salah-hanya...
# 16  https://turnbackhoax.id/2020/04/26/salah-beber...
# 17  https://turnbackhoax.id/2020/04/24/salah-peta-...
# 18  https://turnbackhoax.id/2020/04/22/salah-dari-...
# 19  https://turnbackhoax.id/2020/04/22/salah-alfam...

# %%
# Mengganti nama kolom pada DataFrame "df14"
df14.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df14.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Seorang Kakek di Tulungagung Meningga...
# 1  [[SALAH] “Setelah adanya Virus Covid-19. Umat ...
# 2  [[SALAH] “Tenaga Medis Covid-19 RSUD Purworejo...
# 3  [[SALAH] Satgas Covid-19 Kabupaten Pangkep Sem...
# 4  [[SALAH] “Jokowi: Hukuman Seumur Hidup Bagi Ke...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/05/07/salah-seora...
# 1  https://turnbackhoax.id/2020/05/07/salah-setel...
# 2  https://turnbackhoax.id/2020/05/07/salah-tenag...
# 3  https://turnbackhoax.id/2020/05/07/salah-satga...
# 4  https://turnbackhoax.id/2020/05/06/salah-jokow...

# %% [markdown]
# ### Halaman 15

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/15/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df15 = pd.DataFrame(data)
df15.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “Modus Menghabisi Ustadz, disuntik co...
# 16  [[SALAH] Mantan Manajer RAPP dan Istri Terpapa...
# 17  [[SALAH] Terlibat Pembuatan COVID-19 di China,...
# 18  [[SALAH] Rakyat Italia Buang Duit ke Jalan kar...
# 19  [[SALAH] “jakarta menjadi daerah paling banyak...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/06/salah-modus...
# 16  https://turnbackhoax.id/2020/04/06/salah-manta...
# 17  https://turnbackhoax.id/2020/04/03/salah-terli...
# 18  https://turnbackhoax.id/2020/04/03/salah-rakya...
# 19  https://turnbackhoax.id/2020/04/03/salah-jakar...

# %%
# Mengganti nama kolom pada DataFrame "df15"
df15.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df15.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Semua Pasien Positif Covid-19 di Pada...
# 1  [[SALAH] RSUD Waluyo Jati Ditutup Karena Semua...
# 2  [[SALAH] Foto “Italia telah Gagal Sepenuhnya C...
# 3  [[SALAH] Video “Obat COVID-19 Telah Ditemukan ...
# 4  [[SALAH] Foto “Ariel NOAH Jadi Relawan Tenaga ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/22/salah-semua...
# 1  https://turnbackhoax.id/2020/04/20/salah-rsud-...
# 2  https://turnbackhoax.id/2020/04/19/salah-foto-...
# 3  https://turnbackhoax.id/2020/04/17/salah-video...
# 4  https://turnbackhoax.id/2020/04/16/salah-foto-...

# %% [markdown]
# ### Halaman 16

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/16/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df16 = pd.DataFrame(data)
df16.tail()
# Out:
#                                                     0  \
# 15  [[BERITA] Perkembangan Chloroquine Untuk Obat ...
# 16         [[SALAH] “Ganja Mampu Menangkal Covid-19”]
# 17  [[SALAH] Dosen Kedokteran Gigi UI Meninggal Ka...
# 18  [[SALAH] Foto “1 korban dlm pengawasan Covid-1...
# 19  [[SALAH] “Satu lagi Mentri Kabinet Jokowi Posi...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/21/berita-perk...
# 16  https://turnbackhoax.id/2020/03/20/salah-ganja...
# 17  https://turnbackhoax.id/2020/03/18/salah-dosen...
# 18  https://turnbackhoax.id/2020/03/18/salah-foto-...
# 19  https://turnbackhoax.id/2020/03/17/salah-satu-...

# %%
# Mengganti nama kolom pada DataFrame "df16"
df16.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df16.head()
# Out:
#                                                 Text  \
# 0  [[RILIS PERS] Launching AyoLawanCOVID19.ID, Ge...
# 1  [[SALAH] Menaruh Amoxilin Dalam Tandon Air Dap...
# 2  [[SALAH] Mulai Senin 30 Maret Kota Makassar lo...
# 3  [[SALAH] Foto “kumpulan untuk mengakhiri COVID...
# 4  [[FALSE] Picture of “March to End COVID-19 in ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/02/rilis-pers-...
# 1  https://turnbackhoax.id/2020/03/31/salah-menar...
# 2  https://turnbackhoax.id/2020/03/30/salah-mulai...
# 3  https://turnbackhoax.id/2020/03/30/salah-foto-...
# 4  https://turnbackhoax.id/2020/03/30/false-pictu...

# %% [markdown]
# ### Halaman 17

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/17/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df17 = pd.DataFrame(data)
df17.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] WHO Merencanakan Modifikasi Genetik M...
# 16  [[SALAH] Video “mama Egawati yg lagi dirawat d...
# 17  [[SALAH] Video “Rakyat Menang.. !! Pemerintah ...
# 18  [[SALAH] Tukul Arwana Alami Pendarahan Otak ka...
# 19  [[SALAH] Operasi Razia Lalu Lintas di Banjarma...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/10/01/salah-who-m...
# 16  https://turnbackhoax.id/2021/09/30/salah-video...
# 17  https://turnbackhoax.id/2021/09/30/salah-video...
# 18  https://turnbackhoax.id/2021/09/30/salah-tukul...
# 19  https://turnbackhoax.id/2021/09/27/salah-opera...

# %%
# Mengganti nama kolom pada DataFrame "df17"
df17.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df17.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “Chloroquine (Obat Malaria Klorokuin)...
# 1         [[SALAH] COVID-19 Sudah Sampai Purwakarta]
# 2  [[SALAH] “Alkohol Bisa Membunuh Coronavirus Co...
# 3  [[SALAH] Ditemukannya Virus Corona atau COVID-...
# 4  [[EDUKASI] WHO: “T&J tentang coronavirus (COVI...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/03/17/salah-chlor...
# 1  https://turnbackhoax.id/2020/03/16/salah-covid...
# 2  https://turnbackhoax.id/2020/03/16/salah-alkoh...
# 3  https://turnbackhoax.id/2020/03/16/salah-ditem...
# 4  https://turnbackhoax.id/2020/03/15/edukasi-who...

# %% [markdown]
# ### Halaman 18

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/18/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df18 = pd.DataFrame(data)
df18.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Vaksin Corona Mengandung Babi, Dapat ...
# 16  [[SALAH] Foto Poster Pengumuman Nikah Gratis d...
# 17  [[SALAH] Bendera Merah Putih Dilarang Berkibar...
# 18  [[SALAH] Akun Whatsapp Sekretaris Daerah Kota ...
# 19  [[SALAH] Video “Biang covid bill gates kena ti...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/08/27/salah-vaksi...
# 16  https://turnbackhoax.id/2021/08/27/salah-foto-...
# 17  https://turnbackhoax.id/2021/08/25/salah-bende...
# 18  https://turnbackhoax.id/2021/08/24/salah-akun-...
# 19  https://turnbackhoax.id/2021/08/22/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df18"
df18.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df18.head()
# Out:
#                                                 Text  \
# 0      [[SALAH] PPKM diperpanjang Bansos dihentikan]
# 1  [[SALAH] Video Umat Nasrani Diikat di Afganistan]
# 2  [[SALAH] Siaran tvOneNews “Harta Pejabat Menin...
# 3  [[SALAH] Panggilan Telepon Informasi Seputar V...
# 4  [[SALAH] Mulai 1 Oktober Pasien Covid Tidak Di...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/09/26/salah-ppkm-...
# 1  https://turnbackhoax.id/2021/09/22/salah-video...
# 2  https://turnbackhoax.id/2021/09/20/salah-siara...
# 3  https://turnbackhoax.id/2021/09/19/salah-pangg...
# 4  https://turnbackhoax.id/2021/09/19/salah-mulai...

# %% [markdown]
# ### Halaman 19

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/19/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df19 = pd.DataFrame(data)
df19.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Tautan Pendaftaran Bantuan Sosial Seb...
# 16  [[SALAH] “Vaksin Corona Tidak Terbukti Aman da...
# 17  [[SALAH] Akun Instagram PT Wijaya Karya Indust...
# 18  [[SALAH] Pernyataan Moh Indro Cahyono “TERBONG...
# 19  [[SALAH] “Mobil Dinas Presiden Baru, Harga ber...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/08/07/salah-tauta...
# 16  https://turnbackhoax.id/2021/08/07/salah-vaksi...
# 17  https://turnbackhoax.id/2021/08/02/salah-akun-...
# 18  https://turnbackhoax.id/2021/07/31/salah-perny...
# 19  https://turnbackhoax.id/2021/07/31/salah-mobil...

# %%
# Mengganti nama kolom pada DataFrame "df19"
df19.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df19.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Hewan Mati Bergelimpangan karena Efek...
# 1  [[SALAH] Informasi Vaksin Dosis 1 dan 2 16 Agu...
# 2       [[SALAH] Ustad Yahya Waloni Meninggal Dunia]
# 3  [[SALAH] Pernyataan Dr. Ir. Hj. Sri Nurdiati “...
# 4  [[SALAH] Foto Aksi Demo Paspor Kesehatan di Pa...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/08/21/salah-hewan...
# 1  https://turnbackhoax.id/2021/08/20/salah-infor...
# 2  https://turnbackhoax.id/2021/08/20/salah-ustad...
# 3  https://turnbackhoax.id/2021/08/19/salah-perny...
# 4  https://turnbackhoax.id/2021/08/19/salah-foto-...

# %% [markdown]
# ### Halaman 20

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/20/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df20 = pd.DataFrame(data)
df20.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Campuran Lemon dan Soda Kue Dapat Mem...
# 16  [[SALAH] “Pemerintah Resmi Izinkan Sholat Idul...
# 17  [[SALAH] Video Kondisi Gibran “BERITA TERBARU ...
# 18  [[SALAH] Pernyataan “Semua orang yang divaksin...
# 19  [[SALAH] Imbauan Lepas Masker Mulai Rabu 21 Ju...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/22/salah-campu...
# 16  https://turnbackhoax.id/2021/07/22/salah-pemer...
# 17  https://turnbackhoax.id/2021/07/21/salah-video...
# 18  https://turnbackhoax.id/2021/07/20/salah-perny...
# 19  https://turnbackhoax.id/2021/07/20/salah-imbau...

# %%
# Mengganti nama kolom pada DataFrame "df20"
df20.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df20.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Shopee, Grab dan Gojek Dukung Aksi Na...
# 1  [[SALAH] Surat Donasi Tempat Ibadah Oleh Pemka...
# 2  [[SALAH] Bantuan PPKM Rp1 Juta Bagi Pemilik Se...
# 3  [[SALAH] BNPB Membuka Donasi Kaos Oblong bagi ...
# 4  [[SALAH] Nasi Bungkus Telat Dibagikan, Massa A...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/31/salah-shope...
# 1  https://turnbackhoax.id/2021/07/30/salah-surat...
# 2  https://turnbackhoax.id/2021/07/30/salah-bantu...
# 3  https://turnbackhoax.id/2021/07/29/salah-bnpb-...
# 4  https://turnbackhoax.id/2021/07/29/salah-nasi-...

# %% [markdown]
# ### Halaman 21

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/21/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df21 = pd.DataFrame(data)
df21.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] SPBU Tutup Sementara dari 12 sampai 1...
# 16  [[SALAH] Air Rebusan Bawang Putih Dapat Menyem...
# 17  [[SALAH] “Gubernur Sumut Instruksikan Seluruh ...
# 18  [[SALAH] “Khusus D.K.I Mulai tanggal 7-30 juli...
# 19  [[SALAH] Suara Adzan Di Masjid Dapat Mengecilk...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/11/salah-spbu-...
# 16  https://turnbackhoax.id/2021/07/10/salah-air-r...
# 17  https://turnbackhoax.id/2021/07/09/salah-guber...
# 18  https://turnbackhoax.id/2021/07/09/salah-khusu...
# 19  https://turnbackhoax.id/2021/07/09/salah-suara...

# %%
# Mengganti nama kolom pada DataFrame "df21"
df21.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df21.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Ustadz Abdul Somad (UAS) Meninggal Du...
# 1  [[SALAH] “Semangkin Gawat Indonesia sekarang i...
# 2  [[SALAH] Chemtrails Penyebar Virus Penyakit Mu...
# 3  [[SALAH] Tabung Selam Dapat Digunakan sebagai ...
# 4  [[SALAH] Video “Di Probolinggo, 16 Juli 2021 M...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/20/salah-ustad...
# 1  https://turnbackhoax.id/2021/07/19/salah-seman...
# 2  https://turnbackhoax.id/2021/07/19/salah-chemt...
# 3  https://turnbackhoax.id/2021/07/18/salah-tabun...
# 4  https://turnbackhoax.id/2021/07/18/salah-video...

# %% [markdown]
# ### Halaman 22

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/22/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df22 = pd.DataFrame(data)
df22.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Konsumsi Nigella Oil Menghilangkan Pe...
# 16  [[SALAH] Pesan Berantai “SANDIWARA CORONA” dar...
# 17  [[SALAH] “##BERAKHIR PAHIT##. SK GUBERNUR DI C...
# 18     [[SALAH] Foto “Erdogan cium tangan joe biden”]
# 19  [[SALAH] Malaysia Dapat Tambahan 10 Ribu Kuota...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/06/24/salah-konsu...
# 16  https://turnbackhoax.id/2021/06/23/salah-pesan...
# 17  https://turnbackhoax.id/2021/06/22/salah-berak...
# 18  https://turnbackhoax.id/2021/06/21/salah-foto-...
# 19  https://turnbackhoax.id/2021/06/19/salah-malay...

# %%
# Mengganti nama kolom pada DataFrame "df22"
df22.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df22.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “3 ambulance yang sengaja muter...
# 1  [[SALAH] “MAHASISWA AKAN AKSI BESAR BESARAN da...
# 2  [[SALAH] Virus Corona Sangat Ganas Dan Menakut...
# 3  [[SALAH] Per 1 Juli 2021 Mengurus SIM dan SKCK...
# 4  [[SALAH] Ketersediaan Ventilator Cukup Memadai...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/07/salah-video...
# 1  https://turnbackhoax.id/2021/07/05/salah-mahas...
# 2  https://turnbackhoax.id/2021/07/05/salah-virus...
# 3  https://turnbackhoax.id/2021/07/04/salah-per-1...
# 4  https://turnbackhoax.id/2021/07/04/salah-keter...

# %% [markdown]
# ### Halaman 23

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/23/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df23 = pd.DataFrame(data)
df23.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Berada Di Sekitar Orang yang Baru Div...
# 16  [[SALAH] Video “Warga Malaysia antri nginep di...
# 17     [[SALAH] Obat dan Bahan Herbal Mencegah Covid]
# 18  [[SALAH] Foto “Wapres Ma’ruf Amin video call d...
# 19  [[SALAH] Mengonsumsi Air Hangat dan Berkumur D...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/05/23/salah-berad...
# 16  https://turnbackhoax.id/2021/05/20/salah-video...
# 17  https://turnbackhoax.id/2021/05/20/salah-obat-...
# 18  https://turnbackhoax.id/2021/05/19/salah-foto-...
# 19  https://turnbackhoax.id/2021/05/10/salah-mengo...

# %%
# Mengganti nama kolom pada DataFrame "df23"
df23.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df23.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “Ini sinetron Bajay Bajuri thn 2002,s...
# 1  [[SALAH] “TAK TERTOLONG..!!! SELAMAT JALAN FAD...
# 2  [[SALAH] Pesepakbola Christian Eriksen Terkena...
# 3  [[SALAH] Bantuan Sosial Rp1.2 Juta Rupiah untu...
# 4      [[SALAH] Foto “The Last Moment Dokter Hadio”]
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/06/19/salah-ini-s...
# 1  https://turnbackhoax.id/2021/06/18/salah-tak-t...
# 2  https://turnbackhoax.id/2021/06/16/salah-pesep...
# 3  https://turnbackhoax.id/2021/06/16/salah-bantu...
# 4  https://turnbackhoax.id/2021/06/15/salah-foto-...

# %% [markdown]
# ### Halaman 24

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/24/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df24 = pd.DataFrame(data)
df24.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Video “salah satu pejabat pemerintah ...
# 16  [[SALAH] Kenaikan Limfosit Usai Vaksin, Sebabk...
# 17  [[SALAH] Video Seorang Kakek Ditahan Karena Ti...
# 18  [[SALAH] Akun Twittter Doku.id “@CsDOKUid” dan...
# 19     [[SALAH] Bupati Bojonegoro Sebar Bantuan UMKM]
#
#                                                     1
# 15  https://turnbackhoax.id/2021/04/21/salah-video...
# 16  https://turnbackhoax.id/2021/04/21/salah-kenai...
# 17  https://turnbackhoax.id/2021/04/19/salah-video...
# 18  https://turnbackhoax.id/2021/04/17/salah-akun-...
# 19  https://turnbackhoax.id/2021/04/17/salah-bupat...

# %%
# Mengganti nama kolom pada DataFrame "df24"
df24.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df24.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Akhirnya Ketahuan Kenapa Cina ...
# 1  [[SALAH] Video Warga India Menyerang Kendaraan...
# 2  [[SALAH] Mendeteksi Virus Corona dengan Menaha...
# 3  [[SALAH] Foto “Persiapan penutupan jalan tangg...
# 4  [[SALAH] Foto Hasil CT Scan Paru-Paru Orang Ya...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/05/10/salah-video...
# 1  https://turnbackhoax.id/2021/05/09/salah-video...
# 2  https://turnbackhoax.id/2021/05/08/salah-mende...
# 3  https://turnbackhoax.id/2021/05/06/salah-foto-...
# 4  https://turnbackhoax.id/2021/05/05/salah-foto-...

# %% [markdown]
# ### Halaman 25

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/25/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df25 = pd.DataFrame(data)
df25.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Ekstrak Nanas Bisa Dijadikan Obat Vir...
# 16  [[SALAH] Nama AstraZeneca Memiliki Arti ‘Senja...
# 17  [[SALAH] Vaksin Berbasis mRna, Dapat Menyebabk...
# 18  [[SALAH] “Yg vaksin jgn Lupa Kalau bisa sesuai...
# 19  [[SALAH] “Haji 2021 Akan Berlangsung Seperti B...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/03/29/salah-ekstr...
# 16  https://turnbackhoax.id/2021/03/29/salah-nama-...
# 17  https://turnbackhoax.id/2021/03/25/salah-vaksi...
# 18  https://turnbackhoax.id/2021/03/25/salah-yg-va...
# 19  https://turnbackhoax.id/2021/03/25/salah-haji-...

# %%
# Mengganti nama kolom pada DataFrame "df25"
df25.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df25.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Positif Covid Disebabkan oleh Kekuran...
# 1  [[SALAH] “vaksin korongna itu mRNA, ini bukan ...
# 2  [[SALAH] WHO Ungkapkan Bahwa Hasil Tes PCR ada...
# 3  [[SALAH] “Korban Vaksin Lagi. Kini anggota Bri...
# 4            [[SALAH] Foto “Munarman udah divaksin”]
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/04/16/salah-posit...
# 1  https://turnbackhoax.id/2021/04/16/salah-vaksi...
# 2  https://turnbackhoax.id/2021/04/16/salah-who-u...
# 3  https://turnbackhoax.id/2021/04/13/salah-korba...
# 4  https://turnbackhoax.id/2021/04/10/salah-foto-...

# %% [markdown]
# ### Halaman 26

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/26/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df26 = pd.DataFrame(data)
df26.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Tulisan ini dari kawan-kawan komunit...
# 1  [[SALAH] Rumput Paragis untuk Menyembuhkan Kan...
# 2  [[SALAH] Foto Gubernur Korea Selatan Menggunak...
# 3  [[SALAH] 17 Negara Melarang Penyebaran Vaksin ...
# 4  [[SALAH] Artikel berjudul “Arief Poyuono: Prab...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/24/salah-tulis...
# 1  https://turnbackhoax.id/2021/03/22/salah-rumpu...
# 2  https://turnbackhoax.id/2021/03/21/salah-foto-...
# 3  https://turnbackhoax.id/2021/03/21/salah-17-ne...
# 4  https://turnbackhoax.id/2021/03/17/salah-artik...

# %%
# Mengganti nama kolom pada DataFrame "df26"
df26.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df26.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Masa Lockdown di Kanada Berakhir Seja...
# 16  [[SALAH] “Anosmia Bukan Gejala khas Virus, Min...
# 17  [[SALAH] “Jual Minuman Keras Hukumnya Boleh un...
# 18  [[SALAH] Bantuan 3,5 Juta dari Pemerintah untu...
# 19  [[FALSE] “12 important questions and answers b...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/03/03/salah-masa-...
# 16  https://turnbackhoax.id/2021/03/01/salah-anosm...
# 17  https://turnbackhoax.id/2021/03/01/salah-jual-...
# 18  https://turnbackhoax.id/2021/02/27/salah-bantu...
# 19  https://turnbackhoax.id/2021/02/27/false-12-im...

# %% [markdown]
# ### Halaman 27

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/27/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df27 = pd.DataFrame(data)
df27.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Menteri Agama Tandatangani Surat Lara...
# 1  [[SALAH] Pernyataan Ketua Satgas Covid terkait...
# 2   [[SALAH] Foto “vtube skrg dibawah naungan FIFA”]
# 3  [[SALAH] “setelah di vaksin maka kasus HIV dan...
# 4             [[SALAH] Dahlan Iskan Meninggal Dunia]
#
#                                                    1
# 0  https://turnbackhoax.id/2021/02/23/salah-mente...
# 1  https://turnbackhoax.id/2021/02/23/salah-perny...
# 2  https://turnbackhoax.id/2021/02/20/salah-foto-...
# 3  https://turnbackhoax.id/2021/02/20/salah-setel...
# 4  https://turnbackhoax.id/2021/02/19/salah-dahla...

# %%
# Mengganti nama kolom pada DataFrame "df27"
df27.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df27.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “PSBB jawa & Bali di perpanjang sampa...
# 16       [[SALAH] “Semua Fraksi Sepakat Copot Anies”]
# 17  [[SALAH] “Satu2nya negara yg tidak ada COVID19...
# 18          [[SALAH] Pesan Berantai “Paradox vaksin”]
# 19  [[SALAH] “test Ge Nose C19, Mudah n murah. Rp ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/02/06/salah-psbb-...
# 16  https://turnbackhoax.id/2021/02/05/salah-semua...
# 17  https://turnbackhoax.id/2021/02/03/salah-satu2...
# 18  https://turnbackhoax.id/2021/02/02/salah-pesan...
# 19  https://turnbackhoax.id/2021/02/02/salah-test-...

# %% [markdown]
# ### Halaman 28

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/28/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df28 = pd.DataFrame(data)
df28.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video “Anda Harus Tahu Kebenaran ada ...
# 1  [[SALAH] Video “Cawapres USA Kamala Harris dis...
# 2  [[SALAH] “Gereja Haramkan Vaksin kok MUI Halal...
# 3   [[SALAH] Bank Indonesia Cetak Uang 300 Triliyun]
# 4  [[SALAH] Berkumur dengan Air Hangat dan Air Ga...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/02/01/salah-video...
# 1  https://turnbackhoax.id/2021/02/01/salah-video...
# 2  https://turnbackhoax.id/2021/01/31/salah-gerej...
# 3  https://turnbackhoax.id/2021/01/29/salah-bank-...
# 4  https://turnbackhoax.id/2021/01/28/salah-berku...

# %%
# Mengganti nama kolom pada DataFrame "df28"
df28.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df28.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Ketua BPOM Ditekan dan Diancam Untuk ...
# 16  [[SALAH] Foto Pemerintahan Biden Mengibarkan B...
# 17  [[SALAH] “VAKSINASI PRESIDEN HARUS DIULANG DAN...
# 18  [[SALAH] Tangkapan Layar Video CNN Memberitaka...
# 19         [[SALAH] Video Pemakaman Syeikh Ali Jaber]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/23/salah-ketua...
# 16  https://turnbackhoax.id/2021/01/22/salah-foto-...
# 17  https://turnbackhoax.id/2021/01/22/salah-vaksi...
# 18  https://turnbackhoax.id/2021/01/21/salah-tangk...
# 19  https://turnbackhoax.id/2021/01/20/salah-video...

# %% [markdown]
# ### Halaman 29

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/29/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df29 = pd.DataFrame(data)
df29.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video “Setelah disuntik vaksin pingsa...
# 1  [[SALAH] “Kasdim 0817 Gresik Mayor Sugeng Riya...
# 2     [[SALAH] Merokok Bisa Menghadang Virus Corona]
# 3  [[SALAH] Pembagian Masker Gratis Dicampur Obat...
# 4  [[SALAH] “Cairan nya Masih Utuh Udah di Cabut ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/19/salah-video...
# 1  https://turnbackhoax.id/2021/01/18/salah-kasdi...
# 2  https://turnbackhoax.id/2021/01/18/salah-merok...
# 3  https://turnbackhoax.id/2021/01/18/salah-pemba...
# 4  https://turnbackhoax.id/2021/01/17/salah-caira...

# %%
# Mengganti nama kolom pada DataFrame "df29"
df29.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df29.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Jokowi Kejang dan Meninggal Dunia set...
# 16   [[SALAH] Jokowi Menggunakan Vaksin Buatan Eropa]
# 17  [[SALAH] “Rakyat Aceh menolak vaksin covid19 k...
# 18  [[SALAH] “Kemasan vaksin Sinovac ga pake ampul...
# 19   [[SALAH] Anies Ngumpet Pura-Pura Positif Corona]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/15/salah-jokow...
# 16  https://turnbackhoax.id/2021/01/14/salah-jokow...
# 17  https://turnbackhoax.id/2021/01/14/salah-rakya...
# 18  https://turnbackhoax.id/2021/01/13/salah-kemas...
# 19  https://turnbackhoax.id/2021/01/13/salah-anies...

# %% [markdown]
# ### Halaman 30

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/30/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df30 = pd.DataFrame(data)
df30.head()
# Out:
#                                                    0  \
# 0     [[SALAH] Risma Joget Tanpa Menggunakan Masker]
# 1  [[SALAH] 21% Pasien Mengalami Efek Samping Set...
# 2  [[SALAH] Pesan Berantai Rekrutmen Relawan Untu...
# 3  [[SALAH] Video “vaksin AstraZeneca menggunakan...
# 4  [[SALAH] Surat Edaran MUI Waspada Rapid Test M...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/13/salah-risma...
# 1  https://turnbackhoax.id/2021/01/12/salah-21-pa...
# 2  https://turnbackhoax.id/2021/01/12/salah-pesan...
# 3  https://turnbackhoax.id/2021/01/11/salah-video...
# 4  https://turnbackhoax.id/2021/01/10/salah-surat...

# %%
# Mengganti nama kolom pada DataFrame "df30"
df30.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df30.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Vaksin Bermasalah dan Mengerikan, Dis...
# 16  [[SALAH] Masjid Istiqlal Tidak Mengadakan Sala...
# 17  [[SALAH] “Raja Thailand panggil ulama Islam ba...
# 18  [[SALAH] Vaksin Sinovac Mengandung Sel Kera Hi...
# 19  [[SALAH] Artikel CNN “Seorang Dokter Merekomen...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/06/salah-vaksi...
# 16  https://turnbackhoax.id/2021/01/06/salah-masji...
# 17  https://turnbackhoax.id/2021/01/05/salah-raja-...
# 18  https://turnbackhoax.id/2021/01/05/salah-vaksi...
# 19  https://turnbackhoax.id/2021/01/05/salah-artik...

# %% [markdown]
# ### Halaman 31

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/31/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df31 = pd.DataFrame(data)
df31.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Surat Edaran Kompensasi Zona Merah ol...
# 1  [[SALAH] “kesimpulan Rob Oswald: COVID 19 adal...
# 2  [[SALAH] “mulai tanggal 31-12-2020 pukul 06.00...
# 3  [[SALAH] “WHO menyatakan bahwa vaksin Sinovac ...
# 4       [[SALAH] Video Keadaan RS Covid Wisma Atlet]
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/03/salah-surat...
# 1  https://turnbackhoax.id/2021/01/01/salah-kesim...
# 2  https://turnbackhoax.id/2021/01/01/salah-mulai...
# 3  https://turnbackhoax.id/2021/01/01/salah-who-m...
# 4  https://turnbackhoax.id/2020/12/30/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df31"
df31.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df31.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Rumah Sakit Di Lockdown Karena Pasie...
# 16  [[SALAH] Purworejo Lockdown Mulai Tanggal 24 D...
# 17  [[SALAH] “Syarat Vaksin Gratis Jokowi: BPJS Ke...
# 18       [[SALAH] Foto Demonstrasi di Paris, Prancis]
# 19  [[SALAH] Relawan Alami Gangguan Saraf Setelah ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/12/25/salah-rumah...
# 16  https://turnbackhoax.id/2020/12/24/salah-purwo...
# 17  https://turnbackhoax.id/2020/12/23/salah-syara...
# 18  https://turnbackhoax.id/2020/12/23/salah-foto-...
# 19  https://turnbackhoax.id/2020/12/23/salah-relaw...

# %% [markdown]
# ### Halaman 32

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/32/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df32 = pd.DataFrame(data)
df32.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Paus Fransiskus Mengatakan Vaksin Co...
# 1  [[SALAH] Jokowi Akan Menggunakan Vaksin Pfizer...
# 2  [[SALAH] Kerumunan Gibran Bebas Hukuman karena...
# 3  [[SALAH] Kebijakan Lockdown dan Menjaga Jarak ...
# 4  [[SALAH] Foto Bupati Gowa dengan Narasi Lockdo...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/22/salah-paus-...
# 1  https://turnbackhoax.id/2020/12/21/salah-jokow...
# 2  https://turnbackhoax.id/2020/12/20/salah-kerum...
# 3  https://turnbackhoax.id/2020/12/20/salah-kebij...
# 4  https://turnbackhoax.id/2020/12/20/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df32"
df32.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df32.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Link Untuk Mendapatkan 35 GB Kuota Gr...
# 16  [[SALAH] Pesan WhatsApp Soal Razia Keliling Se...
# 17  [[SALAH] “Baru sehari mentrinya jd TSK bantuan...
# 18    [[SALAH] Pemasangan Barcode pada Badan Manusia]
# 19  [[SALAH] “Pemerintah Kota Surakarta menetapkan...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/12/09/salah-link-...
# 16  https://turnbackhoax.id/2020/12/07/salah-pesan...
# 17  https://turnbackhoax.id/2020/12/07/salah-baru-...
# 18  https://turnbackhoax.id/2020/12/06/salah-pemas...
# 19  https://turnbackhoax.id/2020/12/05/salah-pemer...

# %% [markdown]
# ### Halaman 33

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/33/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df33 = pd.DataFrame(data)
df33.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “tim satgas cov ugm saat ini sangat k...
# 1  [[SALAH] Presiden Pecat Menteri Polhukam Mahfu...
# 2  [[SALAH] Wakil Wali Kota Probolinggo Meninggal...
# 3  [[SALAH] “Pesan Bupati Situbondo Sebelum Belia...
# 4  [[SALAH] “KONDISI KRITIS IMAM BESAR POSITIVE K...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/04/salah-tim-s...
# 1  https://turnbackhoax.id/2020/12/02/salah-presi...
# 2  https://turnbackhoax.id/2020/11/30/salah-wakil...
# 3  https://turnbackhoax.id/2020/11/29/salah-pesan...
# 4  https://turnbackhoax.id/2020/11/28/salah-kondi...

# %%
# Mengganti nama kolom pada DataFrame "df33"
df33.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df33.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] BPOM Halangi Vaksin yang akan Diberikan]
# 16         [[SALAH] Voucher Undian Alfamart 21 Tahun]
# 17           [[SALAH] Presiden Jokowi Menjadi Dokter]
# 18  [[SALAH] “Bioskop XXI Kembali Dibuka, Penonton...
# 19  [[SALAH] Situs Formulir Online BANPRES oleh Ke...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/11/03/salah-bpom-...
# 16  https://turnbackhoax.id/2020/10/29/salah-vouch...
# 17  https://turnbackhoax.id/2020/10/28/salah-presi...
# 18  https://turnbackhoax.id/2020/10/21/salah-biosk...
# 19  https://turnbackhoax.id/2020/10/20/salah-situs...

# %% [markdown]
# ### Halaman 34

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/34/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df34 = pd.DataFrame(data)
df34.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “TERNYATA SUDAH 10 hari PENDEMO tidak...
# 1  [[SALAH] Donald Trump: “Darahku adalah vaksinn...
# 2  [[SALAH] Perusakan Alat Musik Ketipung oleh Pe...
# 3  [[SALAH] Dinkes Bantul Keluarkan Surat Penutup...
# 4  [[SALAH] Harga Vaksin di Indonesia 1000% Lebih...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/18/salah-terny...
# 1  https://turnbackhoax.id/2020/10/16/salah-donal...
# 2  https://turnbackhoax.id/2020/10/16/salah-perus...
# 3  https://turnbackhoax.id/2020/10/16/salah-dinke...
# 4  https://turnbackhoax.id/2020/10/15/salah-harga...

# %%
# Mengganti nama kolom pada DataFrame "df34"
df34.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df34.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Emil Saat Diambil Darah untuk Uji Va...
# 16  [[SALAH] “Peneliti, analis laboratorium, tidak...
# 17  [[SALAH] Arahan Kapolres Simalungun Meniadakan...
# 18  [[SALAH] PT Telkom Indonesia Berikan 100GB Dat...
# 19       [[SALAH] “BANSER ADALAH BESANAN DENGAN PKI”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/10/03/salah-emil-...
# 16  https://turnbackhoax.id/2020/10/02/salah-penel...
# 17  https://turnbackhoax.id/2020/10/02/salah-araha...
# 18  https://turnbackhoax.id/2020/10/01/salah-pt-te...
# 19  https://turnbackhoax.id/2020/10/01/salah-banse...

# %% [markdown]
# ### Halaman 35

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/35/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df35 = pd.DataFrame(data)
df35.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Cina mentargetkan 100 jt penduduk in...
# 1  [[SALAH] “menghilangkan virus adalah mengkonsu...
# 2  [[SALAH] “Bocor A1. dari temen Gue di Mabes Po...
# 3  [[SALAH] Artikel Detik.com “Trans Studio Bandu...
# 4  [[SALAH] “PILKADA JANGAN DITUNDA, PILPRES TUND...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/01/salah-cina-...
# 1  https://turnbackhoax.id/2020/10/01/salah-mengh...
# 2  https://turnbackhoax.id/2020/09/30/salah-bocor...
# 3  https://turnbackhoax.id/2020/09/28/salah-artik...
# 4  https://turnbackhoax.id/2020/09/27/salah-pilka...

# %%
# Mengganti nama kolom pada DataFrame "df35"
df35.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df35.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Jokowi: Tidak Perlu Dibesar besarkan...
# 16  [[SALAH] Foto “Akhirnya Syekh Ali Jabber terba...
# 17  [[SALAH] Selama Covid19 Ada, Tidak ada Orang G...
# 18  [[SALAH] “Anies dapat instruksi dari ‘KAMI’ ag...
# 19    [[SALAH] Pembagian Masker Gratis Dicampur Bius]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/09/17/salah-jokow...
# 16  https://turnbackhoax.id/2020/09/17/salah-foto-...
# 17  https://turnbackhoax.id/2020/09/15/salah-selam...
# 18  https://turnbackhoax.id/2020/09/14/salah-anies...
# 19  https://turnbackhoax.id/2020/09/14/salah-pemba...

# %% [markdown]
# ### Halaman 36

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/36/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df36 = pd.DataFrame(data)
df36.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Sejumlah Negara Tak Izinkan WNI Data...
# 1  [[SALAH] Anies Baswedan Mengendarai Mobil Peti...
# 2  [[SALAH] Rumah DP 0% DKI Jakarta dengan Foto P...
# 3  [[SALAH] “RS wisma atlet lampu Kamar menyala s...
# 4           [[SALAH] Bandung Kota Zona Hitam Corona]
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/13/salah-sejum...
# 1  https://turnbackhoax.id/2020/09/12/salah-anies...
# 2  https://turnbackhoax.id/2020/09/12/salah-rumah...
# 3  https://turnbackhoax.id/2020/09/11/salah-rs-wi...
# 4  https://turnbackhoax.id/2020/09/09/salah-bandu...

# %%
# Mengganti nama kolom pada DataFrame "df36"
df36.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df36.tail()
# Out:
#                                                  Text  \
# 15             [[SALAH] Vaksin Covid Sebabkan Mandul]
# 16  [[SALAH] Hukuman Masuk Peti Mati Karena Tidak ...
# 17  [[SALAH] Putri Vladimir Putin Meninggal Setela...
# 18  [[SALAH] Presiden Joko Widodo Terlihat Memakai...
# 19  [[SALAH] Video Rusia Jadi Pemenang Pembuatan V...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/30/salah-vaksi...
# 16  https://turnbackhoax.id/2020/08/29/salah-hukum...
# 17  https://turnbackhoax.id/2020/08/20/salah-putri...
# 18  https://turnbackhoax.id/2020/08/17/salah-presi...
# 19  https://turnbackhoax.id/2020/08/16/salah-video...

# %% [markdown]
# ### Halaman 37

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/37/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df37 = pd.DataFrame(data)
df37.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Adeku di tilang di toko Samarinda Ce...
# 1          [[SALAH] BIN Tetapkan Jakarta Zona Hitam]
# 2  [[SALAH] Foto “Putri Presiden Rusia Vladimir P...
# 3  [[SALAH] “Gunakan Bagian Putih Masker Di Luar ...
# 4  [[SALAH] Instruksi Bupati Malang Izinkan Lomba...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/08/16/salah-adeku...
# 1  https://turnbackhoax.id/2020/08/16/salah-bin-t...
# 2  https://turnbackhoax.id/2020/08/15/salah-foto-...
# 3  https://turnbackhoax.id/2020/08/14/salah-gunak...
# 4  https://turnbackhoax.id/2020/08/14/salah-instr...

# %%
# Mengganti nama kolom pada DataFrame "df37"
df37.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df37.tail()
# Out:
#                                                  Text  \
# 15          [[SALAH] STAN Ditutup Karena Radikalisme]
# 16  [[SALAH] Seluruh Karyawan Pabrik ESEMKA Terken...
# 17  [[SALAH] Foto “1 Agustus 2020, jutaan warga Je...
# 18  [[SALAH] Pesan Berantai “Sebuah peringatan !! ...
# 19  [[SALAH] “99, 9% Tingkat Kesembuhan Covid dan ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/07/salah-stan-...
# 16  https://turnbackhoax.id/2020/08/07/salah-selur...
# 17  https://turnbackhoax.id/2020/08/07/salah-foto-...
# 18  https://turnbackhoax.id/2020/08/07/salah-pesan...
# 19  https://turnbackhoax.id/2020/08/06/salah-99-9-...

# %% [markdown]
# ### Halaman 38

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/38/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df38 = pd.DataFrame(data)
df38.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video Jokowi Tidak Tahu Penyebab Kasu...
# 1  [[SALAH] Foto Sirkuit Mandalika NTB Siap digun...
# 2  [[SALAH] Virus ini punya obat Hydroxychloroqui...
# 3  [[SALAH] “Cita-cita kalian sudah saya wujudkan...
# 4  [[SALAH] Tangkapan Layar “Wapres menyebut Idul...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/08/06/salah-video...
# 1  https://turnbackhoax.id/2020/08/05/salah-foto-...
# 2  https://turnbackhoax.id/2020/08/04/salah-virus...
# 3  https://turnbackhoax.id/2020/08/04/salah-cita-...
# 4  https://turnbackhoax.id/2020/08/04/salah-tangk...

# %%
# Mengganti nama kolom pada DataFrame "df38"
df38.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df38.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Awas Hati-hati Apa Yang Disemprotkan ...
# 16  [[SALAH] “mayat positif covid 19 dikuburkan ma...
# 17  [[SALAH] Inventaris Pesawat Terbang Untuk Para...
# 18  [[SALAH] “hindari Citos byk karyawannya terpap...
# 19       [[SALAH] Virus Baru bernama SFTS dari China]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/07/28/salah-awas-...
# 16  https://turnbackhoax.id/2020/07/28/salah-mayat...
# 17  https://turnbackhoax.id/2020/07/28/salah-inven...
# 18  https://turnbackhoax.id/2020/07/27/salah-hinda...
# 19  https://turnbackhoax.id/2020/07/27/salah-virus...

# %% [markdown]
# ### Halaman 39

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/39/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df39 = pd.DataFrame(data)
df39.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Penginjil Asal Amerika Serikat Joyce ...
# 1  [[SALAH] “Indonesia satu2nya negara didunia ya...
# 2  [[SALAH] Foto “Heboh, Israel Ubah Masjid Berse...
# 3  [[SALAH] Petani dipukuli Polisi yang dibayar o...
# 4  [[SALAH] Video “BIADAB BANGET PERLAKUAN MEREKA...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/07/26/salah-pengi...
# 1  https://turnbackhoax.id/2020/07/26/salah-indon...
# 2  https://turnbackhoax.id/2020/07/25/salah-foto-...
# 3  https://turnbackhoax.id/2020/07/25/salah-petan...
# 4  https://turnbackhoax.id/2020/07/24/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df39"
df39.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df39.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Risma Sujud ke IDI Karena Warga Surab...
# 16  [[SALAH] Xi Jinping Berterimakasih Karena Terp...
# 17  [[SALAH] “Dirut RSUI bersama 2 Direktur RSUI l...
# 18  [[SALAH] Selebaran Kegiatan Budaya “Gawai Daya...
# 19  [[SALAH] Video “Raja Thailand dan Istrinya ber...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/07/10/salah-risma...
# 16  https://turnbackhoax.id/2020/07/10/salah-xi-ji...
# 17  https://turnbackhoax.id/2020/07/08/salah-dirut...
# 18  https://turnbackhoax.id/2020/07/07/salah-seleb...
# 19  https://turnbackhoax.id/2020/07/07/salah-video...

# %% [markdown]
# ### Halaman 40

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/40/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df40 = pd.DataFrame(data)
df40.head()
# Out:
#                                                    0  \
# 0  [[FALSE] “Actor Javed Haider sells vegetables ...
# 1  [[SALAH] “Aktor Javed Haider menjual sayuran k...
# 2  [[SALAH] Tenaga Medis di Sampang Sengaja Sebar...
# 3  [[SALAH] Video “rumah sakit terkenal di Brazil...
# 4       [[SALAH] “Jokowi Akui Gagal Pimpin Negara!”]
#
#                                                    1
# 0  https://turnbackhoax.id/2020/07/07/false-actor...
# 1  https://turnbackhoax.id/2020/07/07/salah-aktor...
# 2  https://turnbackhoax.id/2020/07/06/salah-tenag...
# 3  https://turnbackhoax.id/2020/07/04/salah-video...
# 4  https://turnbackhoax.id/2020/07/03/salah-jokow...

# %%
# Mengganti nama kolom pada DataFrame "df40"
df40.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df40.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “New Fatwa ‘Sholat Tanpa Wudhu Tanpa ...
# 16  [[SALAH] Denda Rp250 Ribu Saat Razia Masker Ta...
# 17  [[SALAH] “Menurut laporan WHO, Corona Virus ad...
# 18  [[SALAH] “dokter gigi di Surabaya stres telanj...
# 19  [[EVENT] East-West Center: “Fighting Disinform...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/06/23/salah-new-f...
# 16  https://turnbackhoax.id/2020/06/22/salah-denda...
# 17  https://turnbackhoax.id/2020/06/21/salah-menur...
# 18  https://turnbackhoax.id/2020/06/20/salah-dokte...
# 19  https://turnbackhoax.id/2020/06/19/event-east-...

# %% [markdown]
# ### Halaman 41

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/41/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df41 = pd.DataFrame(data)
df41.head()
# Out:
#                                                    0  \
# 0     [[SALAH] “sakitnya apa di diagnosa nya covid”]
# 1  [[SALAH] Abu Vulkanik Dapat Membunuh Virus Cor...
# 2  [[SALAH] Akun Facebook Bupati Tegal “Hajjah Um...
# 3  [[SALAH] Servis Mobil Gratis “Suzuki Peduli Co...
# 4  [[SALAH] “Ternyata ini tujuan masuk mall pakai...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/06/18/salah-sakit...
# 1  https://turnbackhoax.id/2020/06/17/salah-abu-v...
# 2          https://turnbackhoax.id/2020/06/17/41098/
# 3  https://turnbackhoax.id/2020/06/17/salah-servi...
# 4  https://turnbackhoax.id/2020/06/17/salah-terny...

# %%
# Mengganti nama kolom pada DataFrame "df41"
df41.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df41.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] 30 Pembantu Baru Positif Corona di Pe...
# 16  [[SALAH] “Heboh! Pernyataan Dokter Indonesia S...
# 17  [[SALAH] “Pemprov DKI Tunaikan Janji Bansos, N...
# 18      [[SALAH] Video “Setelah lockdown … Maradona”]
# 19  [[SALAH] “Corona Virus adalah BOHONG. bukan da...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/06/11/salah-30-pe...
# 16  https://turnbackhoax.id/2020/06/10/salah-heboh...
# 17  https://turnbackhoax.id/2020/06/10/salah-pempr...
# 18  https://turnbackhoax.id/2020/06/08/salah-video...
# 19  https://turnbackhoax.id/2020/06/06/salah-coron...

# %% [markdown]
# ### Halaman 42

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/42/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df42 = pd.DataFrame(data)
df42.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Rekrutmen PT BGA Bersyarat “Bukan ora...
# 1                      [[SALAH] Zona Hitam Surabaya]
# 2                   [[SALAH] PKI Nyamar Jadi Dokter]
# 3  [[SALAH] Foto “Sekarang malesiya sapu habis pe...
# 4  [[SALAH] “Jgn lewat tenggiri gg 12.. ada 12 or...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/06/06/salah-rekru...
# 1  https://turnbackhoax.id/2020/06/06/salah-zona-...
# 2  https://turnbackhoax.id/2020/06/06/salah-pki-n...
# 3  https://turnbackhoax.id/2020/06/02/salah-foto-...
# 4  https://turnbackhoax.id/2020/06/02/salah-jgn-l...

# %%
# Mengganti nama kolom pada DataFrame "df42"
df42.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df42.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “KRN PEMERINTAHNYA NGEYEL & RAKYATNYA...
# 16  [[SALAH] “kadus dihakimi warga sampai babak be...
# 17  [[SALAH] Voucher Dua Pizza Besar Domino’s Pizz...
# 18  [[SALAH] Ellen DeGeneres Membagikan Bantuan Un...
# 19  [[SALAH] Video “PENJELASAN AHLI VIRUS BAHWA CO...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/26/salah-krn-p...
# 16  https://turnbackhoax.id/2020/05/25/salah-kadus...
# 17  https://turnbackhoax.id/2020/05/25/salah-vouch...
# 18  https://turnbackhoax.id/2020/05/24/salah-ellen...
# 19  https://turnbackhoax.id/2020/05/23/salah-video...

# %% [markdown]
# ### Halaman 43

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/43/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df43 = pd.DataFrame(data)
df43.head()
# Out:
#                                                    0  \
# 0     [[SALAH] Daftar Virus yang Berasal dari China]
# 1  [[SALAH] Seleksi Alam Dimulai, 7 Nyawa Dalam 2...
# 2  [[SALAH] Foto “FBI Menangkap Bill Gates Karena...
# 3           [[SALAH] Video “Tanah abang penuh bray”]
# 4  [[BERITA] Koreksi Post “Empat Ton Telur Bansos...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/23/salah-dafta...
# 1  https://turnbackhoax.id/2020/05/22/salah-selek...
# 2  https://turnbackhoax.id/2020/05/22/salah-foto-...
# 3  https://turnbackhoax.id/2020/05/21/salah-video...
# 4  https://turnbackhoax.id/2020/05/21/berita-kore...

# %%
# Mengganti nama kolom pada DataFrame "df43"
df43.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df43.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Perawat Royal td suaminya jg wafat b...
# 16  [[SALAH] “Katanya jaga jarak mutusin mataranta...
# 17  [[SALAH] Pesan Berantai “Ganjar Pranowo Bolehk...
# 18  [[SALAH] “Bikin laboratorium apa mau jualan ub...
# 19  [[SALAH] “jgn ke lippo dulu sdh zona merah, 14...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/18/salah-peraw...
# 16  https://turnbackhoax.id/2020/05/18/salah-katan...
# 17  https://turnbackhoax.id/2020/05/18/salah-pesan...
# 18  https://turnbackhoax.id/2020/05/17/salah-bikin...
# 19  https://turnbackhoax.id/2020/05/16/salah-jgn-k...

# %% [markdown]
# ### Halaman 44

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/44/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df44 = pd.DataFrame(data)
df44.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Pesan Berantai “ada 13 org penjual da...
# 1  [[SALAH] Video “Warga india diserang Serangga ...
# 2  [[SALAH] Foto Kondisi Pasar Baru Jakarta Ramai...
# 3  [[SALAH] Warga India Membuang Patung Ke Sungai...
# 4  [[SALAH] 200 Orang di Pasar Karombasan Reaktif...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/16/salah-pesan...
# 1  https://turnbackhoax.id/2020/05/15/salah-video...
# 2  https://turnbackhoax.id/2020/05/15/salah-foto-...
# 3  https://turnbackhoax.id/2020/05/14/salah-warga...
# 4  https://turnbackhoax.id/2020/05/14/salah-200-o...

# %%
# Mengganti nama kolom pada DataFrame "df44"
df44.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df44.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Saran Jack Ma semoga kita bisa melew...
# 16  [[SALAH] “Masuukk truusss silahkan masuukk, Or...
# 17    [[SALAH] Bupati Konawe Akui Disuap Menko Luhut]
# 18                        [[SALAH] Video “Plandemic”]
# 19  [[SALAH] “baru kemarin pemerintah putuskan tak...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/11/salah-saran...
# 16  https://turnbackhoax.id/2020/05/11/salah-masuu...
# 17  https://turnbackhoax.id/2020/05/10/salah-bupat...
# 18  https://turnbackhoax.id/2020/05/10/salah-video...
# 19  https://turnbackhoax.id/2020/05/10/salah-baru-...

# %% [markdown]
# ### Halaman 45

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/45/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df45 = pd.DataFrame(data)
df45.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Sri Mulyani: Pemerintah Pusat Tidak M...
# 1  [[SALAH] Berdamai dengan Corona yang Dimaksud ...
# 2  [[SALAH] “Warga Dibolehkan Mudik Oleh Kemenhub...
# 3  [[SALAH] “menteri kesehatan America sdh menand...
# 4  [[SALAH] Video Penampakan Kuntilanak di Rumah ...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/09/salah-sri-m...
# 1  https://turnbackhoax.id/2020/05/09/salah-berda...
# 2  https://turnbackhoax.id/2020/05/07/salah-warga...
# 3  https://turnbackhoax.id/2020/05/07/salah-mente...
# 4  https://turnbackhoax.id/2020/05/06/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df45"
df45.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df45.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Elisa Granato kelinci percobaan vaks...
# 16  [[SALAH] “Fatwah wapres gila Menghina Jokowi S...
# 17  [[SALAH] “Profesor Dr Tasuku Honjo mengatakan ...
# 18  [[SALAH] WHO Sebut Penularan Corona Tak Lagi H...
# 19  [[SALAH] “Apabila ada masyarakat tidak mampu m...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/01/salah-elisa...
# 16  https://turnbackhoax.id/2020/05/01/salah-fatwa...
# 17  https://turnbackhoax.id/2020/04/29/salah-profe...
# 18  https://turnbackhoax.id/2020/04/29/salah-who-s...
# 19  https://turnbackhoax.id/2020/04/29/salah-apabi...

# %% [markdown]
# ### Halaman 46

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/46/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df46 = pd.DataFrame(data)
df46.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Donasi Kaos Oblong Bekas Untuk Tim Me...
# 1  [[SALAH] Italia Meminta Dibacakan Al-Qur’an Da...
# 2  [[SALAH] Razia Besar-besaran Karena Kerabat Be...
# 3  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 4  [[SALAH] “Corona Merebak, Gibran Salahkan Raky...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/04/29/salah-donas...
# 1  https://turnbackhoax.id/2020/04/28/salah-itali...
# 2  https://turnbackhoax.id/2020/04/28/salah-razia...
# 3  https://turnbackhoax.id/2020/04/28/top-5-topik...
# 4  https://turnbackhoax.id/2020/04/28/salah-coron...

# %%
# Mengganti nama kolom pada DataFrame "df46"
df46.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df46.tail()
# Out:
#                                                  Text  \
# 15  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 16  [[SALAH] Foto Di Tengah Pemerintah Sibuk Melaw...
# 17       [[SALAH] Azan Dapat Melemahkan Virus Corona]
# 18  [[SALAH] Luhut Perintahkan TNI-Polri Tangkap P...
# 19  [[SALAH] “di DKI setiap keluarga sudah diberi ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/04/22/top-5-topik...
# 16  https://turnbackhoax.id/2020/04/22/salah-foto-...
# 17  https://turnbackhoax.id/2020/04/21/salah-azan-...
# 18  https://turnbackhoax.id/2020/04/21/salah-luhut...
# 19  https://turnbackhoax.id/2020/04/20/salah-di-dk...

# %% [markdown]
# ### Halaman 47

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/47/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df47 = pd.DataFrame(data)
df47.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Jokowi Keluarkan Kartu Corona Indones...
# 16  [[SALAH] Akun Instagram Mengatasnamakan BNPB M...
# 17  [[SALAH] Video “BLACK MARKET *ITALIA SUDAH MEN...
# 18  [[SALAH] Insentif Virus Corona, Pemerintah Gra...
# 19  [[FALSE] “Italy arrest Doctor for intentionall...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/14/salah-jokow...
# 16  https://turnbackhoax.id/2020/04/13/salah-akun-...
# 17  https://turnbackhoax.id/2020/04/13/salah-video...
# 18  https://turnbackhoax.id/2020/04/12/salah-insen...
# 19  https://turnbackhoax.id/2020/04/12/false-italy...

# %%
# Mengganti nama kolom pada DataFrame "df47"
df47.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df47.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Sudah Lockdown, Sikafir China ...
# 1  [[SALAH] “FBI menggrebek sinagoge Yahudi di Ne...
# 2  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 3  [[SALAH] “Darurat Corona, Ma’ruf Amin Himbau M...
# 4  [[SALAH] “Hati2 Alat Ini Sdh Di Setting Suhu 3...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/20/salah-video...
# 1  https://turnbackhoax.id/2020/04/18/salah-fbi-m...
# 2  https://turnbackhoax.id/2020/04/17/top-5-topik...
# 3  https://turnbackhoax.id/2020/04/17/salah-darur...
# 4  https://turnbackhoax.id/2020/04/17/salah-hati2...

# %% [markdown]
# ### Halaman 48

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/48/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df48 = pd.DataFrame(data)
df48.tail()
# Out:
#                                                     0  \
# 15  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 16  [[SALAH] “Rezim togog Bedebah pasilitasi karan...
# 17  [[SALAH] Video “Ngeri Karena Corona Italia pun...
# 18  [[SALAH] Video “Donald Trump di ruqyah sebab s...
# 19  [[SALAH] Puncak Persebaran Virus Corona 4 Apri...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/07/top-5-topik...
# 16  https://turnbackhoax.id/2020/04/06/salah-rezim...
# 17  https://turnbackhoax.id/2020/04/06/salah-video...
# 18  https://turnbackhoax.id/2020/04/06/salah-video...
# 19  https://turnbackhoax.id/2020/04/06/salah-punca...

# %%
# Mengganti nama kolom pada DataFrame "df48"
df48.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df48.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Surat Imbauan Dinkes Kota Batam untuk...
# 1  [[SALAH] Dokter Italia Sengaja Membunuh Pasien...
# 2  [[SALAH] “Tadi Malem di Amerika Serikat, Shola...
# 3  [[SALAH] “Lagu “corona” dr Bimbo.. lagu 30 tah...
# 4  [[SALAH] “3 hari kedepan Arus angin dari Utara...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/12/salah-surat...
# 1  https://turnbackhoax.id/2020/04/12/salah-dokte...
# 2  https://turnbackhoax.id/2020/04/10/salah-tadi-...
# 3  https://turnbackhoax.id/2020/04/10/salah-lagu-...
# 4  https://turnbackhoax.id/2020/04/09/salah-3-har...

# %% [markdown]
# ### Halaman 49

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/49/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df49 = pd.DataFrame(data)
df49.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Video “Azan PERTAMA di SPANYOL Setela...
# 16  [[SALAH] “Sekeluarga Kena Corona, Tinggal di B...
# 17             [[FALSE] Video of “lockdown in Spain”]
# 18  [[SALAH] Pemerintah Stop Layanan KRL, MRT, LRT...
# 19  [[SALAH] Enam Penumpang Kapal di Pelabuhan Sam...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/02/salah-video...
# 16  https://turnbackhoax.id/2020/04/02/salah-sekel...
# 17  https://turnbackhoax.id/2020/04/02/false-pictu...
# 18  https://turnbackhoax.id/2020/04/02/salah-pemer...
# 19  https://turnbackhoax.id/2020/04/02/salah-enam-...

# %%
# Mengganti nama kolom pada DataFrame "df49"
df49.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df49.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Gereja minta di azankan corona...
# 1  [[BERITA] Pasien positif Covid -19 di RST Latu...
# 2     [[SALAH] Video “ITALIA bergema takbir aamiin”]
# 3  [[SALAH] Foto “Dampak 16 Hari Lockdown di Ital...
# 4  [[SALAH] “Pak Jokowi Yang Nyuruh Orang Tidak S...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/05/salah-video...
# 1  https://turnbackhoax.id/2020/04/05/berita-pasi...
# 2  https://turnbackhoax.id/2020/04/05/salah-video...
# 3  https://turnbackhoax.id/2020/04/05/salah-foto-...
# 4  https://turnbackhoax.id/2020/04/04/salah-pak-j...

# %% [markdown]
# ### Halaman 50

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/50/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df50 = pd.DataFrame(data)
df50.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “ISTANA : TIDAK ADA LOCK DOWN DAERAH,...
# 16             [[SALAH] Bukit Tinggi Segera Lockdown]
# 17  [[SALAH] Video “Di Amerika sudah terjadi penja...
# 18  [[SALAH] Jembatan Suramadu Bebas dari Aktivita...
# 19  [[SALAH] Larangan Keluar Rumah Karena Puncak P...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/30/salah-istan...
# 16  https://turnbackhoax.id/2020/03/29/salah-bukit...
# 17  https://turnbackhoax.id/2020/03/29/salah-video...
# 18  https://turnbackhoax.id/2020/03/28/salah-jemba...
# 19  https://turnbackhoax.id/2020/03/28/salah-laran...

# %%
# Mengganti nama kolom pada DataFrame "df50"
df50.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df50.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “Ternyata virus corona dapat diobati ...
# 1  [[SALAH] Warga Jakarta Saling Memberikan Seman...
# 2  [[SALAH] “China memang bener” jahat mengirim b...
# 3  [[SALAH] Imigran China Sengaja Membawa Virus, ...
# 4  [[SALAH] Uap Air Panas Dapat Membunuh Virus Co...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/02/salah-terny...
# 1  https://turnbackhoax.id/2020/04/01/salah-warga...
# 2  https://turnbackhoax.id/2020/04/01/salah-china...
# 3  https://turnbackhoax.id/2020/04/01/salah-imigr...
# 4  https://turnbackhoax.id/2020/04/01/salah-uap-a...

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

#Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

#Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = []

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append(text)
    #print(link)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="id-ID">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <link rel="profile" href="http://gmpg.org/xfn/11" />
# <meta name='robots' content='noindex, follow' />
#
# 	<!-- This site is optimized with the Yoast SEO plugin v16.6 - https://yoast.com/wordpress/plugins/seo/ -->
# 	<title>You searched for PPKM - TurnBackHoax.ID</title>
# 	<meta property="og:locale" content="id_ID" />
# 	<meta property="og:type" content="article" />
# 	<meta property="og:title" content="You searched for PPKM - TurnBackHoax.ID" />
# 	<meta property="og:url" content="https://turnbackhoax.id/search/PPKM/" />
# 	<meta property="og:site_name" content="TurnBackHoax.ID" />
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:title" content="You searched for PPKM - TurnBackHoax.ID" />
# 	<meta name="twitter:site" content="@turnbackhoax" />
# 	<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://turnbackhoax.id/#organization","name":"MAFINDO","url":"https://turnbackhoax.id/","sameAs":["http://facebook.com/mafindoid","http://instagram.com/turnbackhoaxid","https://www.youtube.com/channel/UC9oTzP5epXaytHUO3_NvwRg","https://twitter.com/turnbackhoax"],"logo":{"@type":"ImageObject","@id":"https://turnbackhoax.id/#logo","inLanguage":"id-ID","url":"https://turnbackhoax.id/wp-content/uploads/2018/04/logo.jpg","contentUrl":"https://turnbackhoax.id/wp-content/uploads/2018/04/logo.jpg","width":772,"height":960,"caption":"MAFINDO"},"image":{"@id":"https://turnbackhoax.id/#logo"}},{"@type":"WebSite","@id":"https://turnbackhoax.id/#website","url":"https://turnbackhoax.id/","name":"MAFINDO TurnBackHoax","description":"Persembahan dari MAFINDO :: Masyarakat Anti Fitnah Indonesia","publisher":{"@id":"https://turnbackhoax.id/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://turnbackhoax.id/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"id-ID"},{"@type":["CollectionPage","SearchResultsPage"],"@id":"#webpage","url":"","name":"You searched for PPKM - TurnBackHoax.ID","isPartOf":{"@id":"https://turnbackhoax.id/#website"},"breadcrumb":{"@id":"#breadcrumb"},"inLanguage":"id-ID","potentialAction":[{"@type":"ReadAction","target":[""]}]},{"@type":"BreadcrumbList","@id":"#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://turnbackhoax.id/"},{"@type":"ListItem","position":2,"name":"You searched for PPKM"}]}]}</script>
# 	<!-- / Yoast SEO plugin. -->
#
#
# <link rel='dns-prefetch' href='//www.google.com' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="TurnBackHoax.ID &raquo; Feed" href="https://turnbackhoax.id/feed/" />
# <link rel="alternate" type="application/rss+xml" title="TurnBackHoax.ID &raquo; Umpan Komentar" href="https://turnbackhoax.id/comments/feed/" />
# <link rel="alternate" type="application/rss+xml" title="TurnBackHoax.ID &raquo; Hasil Pencarian untuk Umpan &#8220;PPKM&#8221;" href="https://turnbackhoax.id/search/PPKM/feed/rss2/" />
# 		<!-- This site uses the Google Analytics by ExactMetrics plugin v6.7.0 - Using Analytics tracking - https://www.exactmetrics.com/ -->
# 							<script src="//www.googletagmanager.com/gtag/js?id=UA-129659568-2"  type="text/javascript" data-cfasync="false"></script>
# 			<script type="text/javascript" data-cfasync="false">
# 				var em_version = '6.7.0';
# 				var em_track_user = true;
# 				var em_no_track_reason = '';
#
# 								var disableStr = 'ga-disable-UA-129659568-2';
#
# 				/* Function to detect opted out users */
# 				function __gtagTrackerIsOptedOut() {
# 					return document.cookie.indexOf( disableStr + '=true' ) > - 1;
# 				}
#
# 				/* Disable tracking if the opt-out cookie exists. */
# 				if ( __gtagTrackerIsOptedOut() ) {
# 					window[disableStr] = true;
# 				}
#
# 				/* Opt-out function */
# 				function __gtagTrackerOptout() {
# 					document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 					window[disableStr] = true;
# 				}
#
# 				if ( 'undefined' === typeof gaOptout ) {
# 					function gaOptout() {
# 						__gtagTrackerOptout();
# 					}
# 				}
# 								window.dataLayer = window.dataLayer || [];
# 				if ( em_track_user ) {
# 					function __gtagTracker() {dataLayer.push( arguments );}
# 					__gtagTracker( 'js', new Date() );
# 					__gtagTracker( 'set', {
# 						'developer_id.dNDMyYj' : true,
# 						                    });
# 					__gtagTracker( 'config', 'UA-129659568-2', {
# 						forceSSL:true,page_path:'/?s=PPKM&cat=plus-5-results',					} );
# 										window.gtag = __gtagTracker;										(
# 						function () {
# 							/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# 							/* ga and __gaTracker compatibility shim. */
# 							var noopfn = function () {
# 								return null;
# 							};
# 							var newtracker = function () {
# 								return new Tracker();
# 							};
# 							var Tracker = function () {
# 								return null;
# 							};
# 							var p = Tracker.prototype;
# 							p.get = noopfn;
# 							p.set = noopfn;
# 							p.send = function (){
# 								var args = Array.prototype.slice.call(arguments);
# 								args.unshift( 'send' );
# 								__gaTracker.apply(null, args);
# 							};
# 							var __gaTracker = function () {
# 								var len = arguments.length;
# 								if ( len === 0 ) {
# 									return;
# 								}
# 								var f = arguments[len - 1];
# 								if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
# 									if ( 'send' === arguments[0] ) {
# 										var hitConverted, hitObject = false, action;
# 										if ( 'event' === arguments[1] ) {
# 											if ( 'undefined' !== typeof arguments[3] ) {
# 												hitObject = {
# 													'eventAction': arguments[3],
# 													'eventCategory': arguments[2],
# 													'eventLabel': arguments[4],
# 													'value': arguments[5] ? arguments[5] : 1,
# 												}
# 											}
# 										}
# 										if ( typeof arguments[2] === 'object' ) {
# 											hitObject = arguments[2];
# 										}
# 										if ( typeof arguments[5] === 'object' ) {
# 											Object.assign( hitObject, arguments[5] );
# 										}
# 										if ( 'undefined' !== typeof (
# 											arguments[1].hitType
# 										) ) {
# 											hitObject = arguments[1];
# 										}
# 										if ( hitObject ) {
# 											action = 'timing' === arguments[1].hitType ? 'timing_complete' : hitObject.eventAction;
# 											hitConverted = mapArgs( hitObject );
# 											__gtagTracker( 'event', action, hitConverted );
# 										}
# 									}
# 									return;
# 								}
#
# 								function mapArgs( args ) {
# 									var gaKey, hit = {};
# 									var gaMap = {
# 										'eventCategory': 'event_category',
# 										'eventAction': 'event_action',
# 										'eventLabel': 'event_label',
# 										'eventValue': 'event_value',
# 										'nonInteraction': 'non_interaction',
# 										'timingCategory': 'event_category',
# 										'timingVar': 'name',
# 										'timingValue': 'value',
# 										'timingLabel': 'event_label',
# 									};
# 									for ( gaKey in gaMap ) {
# 										if ( 'undefined' !== typeof args[gaKey] ) {
# 											hit[gaMap[gaKey]] = args[gaKey];
# 										}
# 									}
# 									return hit;
# 								}
#
# 								try {
# 									f.hitCallback();
# 								} catch ( ex ) {
# 								}
# 							};
# 							__gaTracker.create = newtracker;
# 							__gaTracker.getByName = newtracker;
# 							__gaTracker.getAll = function () {
# 								return [];
# 							};
# 							__gaTracker.remove = noopfn;
# 							__gaTracker.loaded = true;
# 							window['__gaTracker'] = __gaTracker;
# 						}
# 					)();
# 									} else {
# 										console.log( "" );
# 					( function () {
# 							function __gtagTracker() {
# 								return null;
# 							}
# 							window['__gtagTracker'] = __gtagTracker;
# 							window['gtag'] = __gtagTracker;
# 					} )();
# 									}
# 			</script>
# 				<!-- / Google Analytics by ExactMetrics -->
# 				<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/turnbackhoax.id\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.8.1"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([10084,65039,8205,55357,56613],[10084,65039,8203,55357,56613])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# 	<link rel='stylesheet' id='wp-block-library-css'  href='https://turnbackhoax.id/wp-includes/css/dist/block-library/style.min.css?ver=5.8.1' type='text/css' media='all' />
# <link rel='stylesheet' id='contact-form-7-css'  href='https://turnbackhoax.id/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.4.2' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-magazine-lite-css'  href='https://turnbackhoax.id/wp-content/themes/mh-magazine-lite/style.css?ver=2.9.0' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-sportsmagazine-css'  href='https://turnbackhoax.id/wp-content/themes/mh-sportsmagazine/style.css?ver=1.1.3' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-font-awesome-css'  href='https://turnbackhoax.id/wp-content/themes/mh-magazine-lite/includes/font-awesome.min.css' type='text/css' media='all' />
# <link rel='stylesheet' id='mh-sportsmagazine-fonts-css'  href='https://fonts.googleapis.com/css?family=Glegoo:400,700%7cTitillium+Web:300,400,400italic,600,700' type='text/css' media='all' />
# <script type='text/javascript' id='exactmetrics-frontend-script-js-extra'>
# /* <![CDATA[ */
# var exactmetrics_frontend = {"js_events_tracking":"true","download_extensions":"zip,mp3,mpeg,pdf,docx,pptx,xlsx,rar","inbound_paths":"[{\"path\":\"\\\/go\\\/\",\"label\":\"affiliate\"},{\"path\":\"\\\/recommend\\\/\",\"label\":\"affiliate\"}]","home_url":"https:\/\/turnbackhoax.id","hash_tracking":"false","ua":"UA-129659568-2"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-content/plugins/google-analytics-dashboard-for-wp/assets/js/frontend-gtag.min.js?ver=6.7.0' id='exactmetrics-frontend-script-js'></script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-includes/js/jquery/jquery.min.js?ver=3.6.0' id='jquery-core-js'></script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2' id='jquery-migrate-js'></script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-content/themes/mh-magazine-lite/js/scripts.js?ver=2.9.0' id='mh-scripts-js'></script>
# <link rel="https://api.w.org/" href="https://turnbackhoax.id/wp-json/" /><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://turnbackhoax.id/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://turnbackhoax.id/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 5.8.1" />
# <!--[if lt IE 9]>
# <script src="https://turnbackhoax.id/wp-content/themes/mh-magazine-lite/js/css3-mediaqueries.js"></script>
# <![endif]-->
# <link rel="icon" href="https://turnbackhoax.id/wp-content/uploads/2021/06/cropped-cropped-logo-Mafindo-square-300x300-1-32x32.png" sizes="32x32" />
# <link rel="icon" href="https://turnbackhoax.id/wp-content/uploads/2021/06/cropped-cropped-logo-Mafindo-square-300x300-1-192x192.png" sizes="192x192" />
# <link rel="apple-touch-icon" href="https://turnbackhoax.id/wp-content/uploads/2021/06/cropped-cropped-logo-Mafindo-square-300x300-1-180x180.png" />
# <meta name="msapplication-TileImage" content="https://turnbackhoax.id/wp-content/uploads/2021/06/cropped-cropped-logo-Mafindo-square-300x300-1-270x270.png" />
# </head>
# <body id="mh-mobile" class="search search-results mh-right-sb" itemscope="itemscope" itemtype="https://schema.org/WebPage">
# <div class="mh-header-mobile-nav mh-clearfix"></div>
# <header class="mh-header" itemscope="itemscope" itemtype="https://schema.org/WPHeader">
# 	<div class="mh-container mh-container-inner mh-row mh-clearfix">
# 		<div class="mh-custom-header mh-clearfix">
# <a class="mh-header-image-link" href="https://turnbackhoax.id/" title="TurnBackHoax.ID" rel="home">
# <img class="mh-header-image" src="https://turnbackhoax.id/wp-content/uploads/2021/06/cropped-tbh-header-1.png" height="132" width="1080" alt="TurnBackHoax.ID" />
# </a>
# </div>
# 	</div>
# 	<div class="mh-main-nav-wrap">
# 		<nav class="mh-navigation mh-main-nav mh-container mh-container-inner mh-clearfix" itemscope="itemscope" itemtype="https://schema.org/SiteNavigationElement">
# 			<div class="menu"><ul>
# <li class="page_item page-item-96"><a href="https://turnbackhoax.id/forum/">Forum</a></li>
# <li class="page_item page-item-6335"><a href="https://turnbackhoax.id/lapor-hoax/">Lapor Hoax</a></li>
# <li class="page_item page-item-6333"><a href="https://turnbackhoax.id/layanan-publik/">Layanan Publik</a></li>
# <li class="page_item page-item-98"><a href="https://turnbackhoax.id/media/">Media</a></li>
# <li class="page_item page-item-667"><a href="https://turnbackhoax.id/relawan/">Relawan</a></li>
# <li class="page_item page-item-2 page_item_has_children"><a href="https://turnbackhoax.id/tentang-kami/">Tentang Kami</a>
# <ul class='children'>
# 	<li class="page_item page-item-12398"><a href="https://turnbackhoax.id/tentang-kami/kontak-kami/">Kontak Kami</a></li>
# 	<li class="page_item page-item-12403 page_item_has_children"><a href="https://turnbackhoax.id/tentang-kami/policies-kebijakan/">Policies / Kebijakan</a>
# 	<ul class='children'>
# 		<li class="page_item page-item-8421"><a href="https://turnbackhoax.id/tentang-kami/policies-kebijakan/kode-etik/">Kode Etik</a></li>
# 		<li class="page_item page-item-12405"><a href="https://turnbackhoax.id/tentang-kami/policies-kebijakan/koreksi-open-honest-correction-policy/">Koreksi / Open &#038; Honest Correction Policy</a></li>
# 		<li class="page_item page-item-16000"><a href="https://turnbackhoax.id/tentang-kami/policies-kebijakan/hbt-privacy-policy/">Privacy Policy</a></li>
# 		<li class="page_item page-item-69210"><a href="https://turnbackhoax.id/tentang-kami/policies-kebijakan/terms-of-use/">Terms of Use</a></li>
# 	</ul>
# </li>
# 	<li class="page_item page-item-12458"><a href="https://turnbackhoax.id/tentang-kami/team-profile/">Team Profile</a></li>
# </ul>
# </li>
# </ul></div>
# 		</nav>
# 	</div>
# </header><div class="mh-container mh-container-outer">
# <div class="mh-wrapper mh-clearfix">
# 	<div id="main-content" class="mh-loop mh-content" role="main">			<header class="page-header">
# 				<h1 class="page-title">
# 					Hasil pencarian atas <span>PPKM</span>				</h1>
# 			</header><article class="mh-loop-item mh-clearfix post-70057 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/09/26/salah-ppkm-diperpanjang-bansos-dihentikan/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1632635347889-326x245.png" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1632635347889-326x245.png 326w, https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1632635347889-80x60.png 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/09/26/salah-ppkm-diperpanjang-bansos-dihentikan/" rel="bookmark">
# 					[SALAH] PPKM diperpanjang Bansos dihentikan				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>September 26, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/09/26/salah-ppkm-diperpanjang-bansos-dihentikan/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Luthfiyah Oktari Jasmien (UIN Raden Mas Said Surakarta). Infomasi tersebut tidak benar. Mensos Tri Risma telah mengungkapkan program bansos reguler dan bansos <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/09/26/salah-ppkm-diperpanjang-bansos-dihentikan/" title="[SALAH] PPKM diperpanjang Bansos dihentikan">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-68472 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/19/salah-ppkm-dilanjutkan-sampai-hari-kiamat/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629359632706-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629359632706-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629359632706-300x225.jpg 300w, https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629359632706-678x509.jpg 678w, https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629359632706-80x60.jpg 80w, https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629359632706.jpg 720w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/19/salah-ppkm-dilanjutkan-sampai-hari-kiamat/" rel="bookmark">
# 					[SALAH] &#8220;PPKM DILANJUTKAN SAMPAI HARI KIAMAT&#8221;				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 19, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/19/salah-ppkm-dilanjutkan-sampai-hari-kiamat/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Fachrun Nisa (Universitas Muhammadiyah Luwuk). Judul Berita telah disunting. Selengkapnya pada penjelasan! = = = = = KATEGORI: SATIRE CONTENT = = <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/19/salah-ppkm-dilanjutkan-sampai-hari-kiamat/" title="[SALAH] &#8220;PPKM DILANJUTKAN SAMPAI HARI KIAMAT&#8221;">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-67515 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/07/30/salah-bantuan-ppkm-rp1-juta-bagi-pemilik-sertifikat-vaksinasi/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/07/PicsArt_07-30-08.31.48-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/07/PicsArt_07-30-08.31.48-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/07/PicsArt_07-30-08.31.48-678x509.jpg 678w, https://turnbackhoax.id/wp-content/uploads/2021/07/PicsArt_07-30-08.31.48-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/07/30/salah-bantuan-ppkm-rp1-juta-bagi-pemilik-sertifikat-vaksinasi/" rel="bookmark">
# 					[SALAH] Bantuan PPKM Rp1 Juta Bagi Pemilik Sertifikat Vaksinasi				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Juli 30, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/07/30/salah-bantuan-ppkm-rp1-juta-bagi-pemilik-sertifikat-vaksinasi/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Gabriela Nauli Sinaga (Universitas Sumatera Utara) Faktanya bantuan tersebut bukan ditujukan kepada pemilik sertifikat vaksinasi, namun bantuan tersebut merupakan program Kementrian Ketenagakerjaan <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/07/30/salah-bantuan-ppkm-rp1-juta-bagi-pemilik-sertifikat-vaksinasi/" title="[SALAH] Bantuan PPKM Rp1 Juta Bagi Pemilik Sertifikat Vaksinasi">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-67392 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/07/29/salah-kita-bukan-bodoh-tapi-dibodohkan-kita-tidak-miskin-tapi-dimiskin-oleh-sebuah-sistem-ppkmlevel4diperpanjang/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/07/rapid-expired-03-1-326x245.png" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/07/rapid-expired-03-1-326x245.png 326w, https://turnbackhoax.id/wp-content/uploads/2021/07/rapid-expired-03-1-678x509.png 678w, https://turnbackhoax.id/wp-content/uploads/2021/07/rapid-expired-03-1-80x60.png 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/07/29/salah-kita-bukan-bodoh-tapi-dibodohkan-kita-tidak-miskin-tapi-dimiskin-oleh-sebuah-sistem-ppkmlevel4diperpanjang/" rel="bookmark">
# 					[SALAH] &#8220;KITA BUKAN BODOH TAPI DIBODOHKAN KITA TIDAK MISKIN TAPI DIMISKIN OLEH SEBUAH SISTEM #PPKMLevel4Diperpanjang&#8221;				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Juli 29, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/aribowo/">Aribowo Sasmito</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/07/29/salah-kita-bukan-bodoh-tapi-dibodohkan-kita-tidak-miskin-tapi-dimiskin-oleh-sebuah-sistem-ppkmlevel4diperpanjang/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>MENYESATKAN. Faktanya, Rapid Test Antibody per Desember tahun 2020, sebelum masa PPKM saat ini (2021), sudah TIDAK berlaku, digantikan oleh Rapid Test Antigen (Swab). Selain <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/07/29/salah-kita-bukan-bodoh-tapi-dibodohkan-kita-tidak-miskin-tapi-dimiskin-oleh-sebuah-sistem-ppkmlevel4diperpanjang/" title="[SALAH] &#8220;KITA BUKAN BODOH TAPI DIBODOHKAN KITA TIDAK MISKIN TAPI DIMISKIN OLEH SEBUAH SISTEM #PPKMLevel4Diperpanjang&#8221;">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-66993 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/07/22/salah-mata-pengemudi-ditusuk-hingga-buta-oleh-petugas-di-pos-ppkm-padang/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/07/sumber-7-326x245.png" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/07/sumber-7-326x245.png 326w, https://turnbackhoax.id/wp-content/uploads/2021/07/sumber-7-678x509.png 678w, https://turnbackhoax.id/wp-content/uploads/2021/07/sumber-7-80x60.png 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/07/22/salah-mata-pengemudi-ditusuk-hingga-buta-oleh-petugas-di-pos-ppkm-padang/" rel="bookmark">
# 					[SALAH] Mata Pengemudi ditusuk hingga Buta oleh Petugas di Pos PPKM Padang				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Juli 22, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/07/22/salah-mata-pengemudi-ditusuk-hingga-buta-oleh-petugas-di-pos-ppkm-padang/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Natalia Kristian (Anggota Komisariat MAFINDO Universitas Indonesia). Informasi yang salah. Pengemudi tersebut telah mengakui bahwa luka tersebut bukanlah karena matanya ditusuk melainkan <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/07/22/salah-mata-pengemudi-ditusuk-hingga-buta-oleh-petugas-di-pos-ppkm-padang/" title="[SALAH] Mata Pengemudi ditusuk hingga Buta oleh Petugas di Pos PPKM Padang">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-66077 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/07/09/salah-link-untuk-pengecekan-penerima-bantuan-ppkm-rp300-000/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/07/IMG_20210709_081241_022-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/07/IMG_20210709_081241_022-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/07/IMG_20210709_081241_022-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/07/09/salah-link-untuk-pengecekan-penerima-bantuan-ppkm-rp300-000/" rel="bookmark">
# 					[SALAH] Link untuk pengecekan penerima bantuan PPKM Rp300.000				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Juli 9, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/07/09/salah-link-untuk-pengecekan-penerima-bantuan-ppkm-rp300-000/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Luthfiyah Oktari Jasmien (UIN Raden Mas Said Surakarta). Melalui akun Instagram resmi Kemensos menginformasikan bahwa link yang beredar tersebut tidak benar.Selengkapnya pada <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/07/09/salah-link-untuk-pengecekan-penerima-bantuan-ppkm-rp300-000/" title="[SALAH] Link untuk pengecekan penerima bantuan PPKM Rp300.000">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-65895 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/07/04/salah-foto-perbanyak-pergi-ke-mesjid-ppkm-darurat-pemkab-sukabumi/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/07/ppkm-sukabumi-03-1-326x245.png" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/07/ppkm-sukabumi-03-1-326x245.png 326w, https://turnbackhoax.id/wp-content/uploads/2021/07/ppkm-sukabumi-03-1-678x509.png 678w, https://turnbackhoax.id/wp-content/uploads/2021/07/ppkm-sukabumi-03-1-80x60.png 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/07/04/salah-foto-perbanyak-pergi-ke-mesjid-ppkm-darurat-pemkab-sukabumi/" rel="bookmark">
# 					[SALAH] Foto &#8220;PERBANYAK PERGI KE MESJID&#8221; PPKM Darurat Pemkab Sukabumi				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Juli 4, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/aribowo/">Aribowo Sasmito</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/07/04/salah-foto-perbanyak-pergi-ke-mesjid-ppkm-darurat-pemkab-sukabumi/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil SUNTINGAN. FAKTANYA, tulisan pada foto ASLI adalah &#8220;PEMBERLAKUAN PEMBATASAN KEGIATAN MASYARAKAT (PPKM) DARURAT&#8221; yang sudah dipublikasikan sebelumnya pada tanggal 2 Juli lalu, bukan &#8220;PERBANYAK <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/07/04/salah-foto-perbanyak-pergi-ke-mesjid-ppkm-darurat-pemkab-sukabumi/" title="[SALAH] Foto &#8220;PERBANYAK PERGI KE MESJID&#8221; PPKM Darurat Pemkab Sukabumi">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-69302 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/09/08/salah-link-cek-bantuan-per-10-september-2021-sebesar-rp600-000-bagi-pengguna-e-ktp/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1631081358887-326x245.png" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1631081358887-326x245.png 326w, https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1631081358887-678x509.png 678w, https://turnbackhoax.id/wp-content/uploads/2021/09/Watermark_1631081358887-80x60.png 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/09/08/salah-link-cek-bantuan-per-10-september-2021-sebesar-rp600-000-bagi-pengguna-e-ktp/" rel="bookmark">
# 					[SALAH] Link Cek Bantuan per 10 September 2021 sebesar Rp600.000 bagi Pengguna E-KTP				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>September 8, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/09/08/salah-link-cek-bantuan-per-10-september-2021-sebesar-rp600-000-bagi-pengguna-e-ktp/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Luthfiyah Oktari Jasmien (UIN Raden Mas Said Surakarta). Link berikut https://tinyurl[dot]com/yrnt3sre adalah palsu. Kepala Biro Humas Kemensos, Hasim menyatakan bahwa untuk link <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/09/08/salah-link-cek-bantuan-per-10-september-2021-sebesar-rp600-000-bagi-pengguna-e-ktp/" title="[SALAH] Link Cek Bantuan per 10 September 2021 sebesar Rp600.000 bagi Pengguna E-KTP">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-69094 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/31/salah-munarman-kritis-total-nasibnya-memilukan-2/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1630414822354-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1630414822354-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1630414822354-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/31/salah-munarman-kritis-total-nasibnya-memilukan-2/" rel="bookmark">
# 					[SALAH] Munarman Kritis Total, nasibnya memilukan				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 31, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/31/salah-munarman-kritis-total-nasibnya-memilukan-2/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Fachrun Nisa (Universitas Muhammadiyah Luwuk). Informasi tersebut telah dibantah oleh Aziz Yazid selaku pengacara Munarman. Selengkapnya pada penjelasan! = = = = <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/31/salah-munarman-kritis-total-nasibnya-memilukan-2/" title="[SALAH] Munarman Kritis Total, nasibnya memilukan">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-68771 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/25/salah-bendera-merah-putih-dilarang-berkibar-di-pik/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-25-07.39.43-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-25-07.39.43-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-25-07.39.43-678x509.jpg 678w, https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-25-07.39.43-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/25/salah-bendera-merah-putih-dilarang-berkibar-di-pik/" rel="bookmark">
# 					[SALAH] Bendera Merah Putih Dilarang Berkibar di PIK				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 25, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/25/salah-bendera-merah-putih-dilarang-berkibar-di-pik/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Gabriela Nauli Sinaga (Universitas Sumatera Utara) Faktanya pelarangan itu dilakukan karena adanya aturan PPKM yang mencegah kerumunan untuk menekan angka penularan Covid-19. <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/25/salah-bendera-merah-putih-dilarang-berkibar-di-pik/" title="[SALAH] Bendera Merah Putih Dilarang Berkibar di PIK">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-68519 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/20/salah-sertifikat-vaksin-covid-19-bukan-syarat-administrasi/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/IMG_20210820_213555_320-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/IMG_20210820_213555_320-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/IMG_20210820_213555_320-678x509.jpg 678w, https://turnbackhoax.id/wp-content/uploads/2021/08/IMG_20210820_213555_320-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/20/salah-sertifikat-vaksin-covid-19-bukan-syarat-administrasi/" rel="bookmark">
# 					[SALAH] Sertifikat Vaksin Covid-19 Bukan Syarat Administrasi				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 20, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/20/salah-sertifikat-vaksin-covid-19-bukan-syarat-administrasi/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil periksa fakta Rahmah an nisaa (UIN Sunan Ampel Surabaya). Faktanya, narasi tersebut adalah hoaks. Semenjak diberlakukannya PPKM Darurat mengacu pada Surat Edaran Satgas Penanganan <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/20/salah-sertifikat-vaksin-covid-19-bukan-syarat-administrasi/" title="[SALAH] Sertifikat Vaksin Covid-19 Bukan Syarat Administrasi">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-68478 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/19/salah-munarman-kritis-total-nasibnya-memilukan/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629360377343-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629360377343-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/FB_IMG_1629360377343-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/19/salah-munarman-kritis-total-nasibnya-memilukan/" rel="bookmark">
# 					[SALAH] Munarman Kritis Total, nasibnya memilukan				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 19, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/19/salah-munarman-kritis-total-nasibnya-memilukan/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Fachrun Nisa (Universitas Muhammadiyah Luwuk). Informasi tersebut telah dibantah oleh Aziz Yazid selaku pengacara Munarman. Selengkapnya pada penjelasan! = = = = <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/19/salah-munarman-kritis-total-nasibnya-memilukan/" title="[SALAH] Munarman Kritis Total, nasibnya memilukan">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-68327 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/17/salah-grab-berikan-bantuan-sembako-senilai-rp80-ribu-untuk-warga-surabaya/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/ss-grab-bagi-bagi-sembako-di-surabaya-1-1-326x245.png" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/ss-grab-bagi-bagi-sembako-di-surabaya-1-1-326x245.png 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/ss-grab-bagi-bagi-sembako-di-surabaya-1-1-678x509.png 678w, https://turnbackhoax.id/wp-content/uploads/2021/08/ss-grab-bagi-bagi-sembako-di-surabaya-1-1-80x60.png 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/17/salah-grab-berikan-bantuan-sembako-senilai-rp80-ribu-untuk-warga-surabaya/" rel="bookmark">
# 					[SALAH] Grab Berikan Bantuan Sembako Senilai Rp80 Ribu untuk Warga Surabaya				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 17, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/17/salah-grab-berikan-bantuan-sembako-senilai-rp80-ribu-untuk-warga-surabaya/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Nadine Salsabila (Universitas Diponegoro) Hal tersebut tidak benar. Bantuan yang diberikan oleh Grab ditujukan untuk mitra pengemudi yang ada di tujuh kota <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/17/salah-grab-berikan-bantuan-sembako-senilai-rp80-ribu-untuk-warga-surabaya/" title="[SALAH] Grab Berikan Bantuan Sembako Senilai Rp80 Ribu untuk Warga Surabaya">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-68062 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# 	<figure class="mh-loop-thumb">
# 		<a href="https://turnbackhoax.id/2021/08/11/salah-bantuan-rp500-ribu-dari-kementerian-sosial-ri/"><img width="326" height="245" src="https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-11-08.33.41-326x245.jpg" class="attachment-mh-magazine-lite-medium size-mh-magazine-lite-medium wp-post-image" alt="" loading="lazy" srcset="https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-11-08.33.41-326x245.jpg 326w, https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-11-08.33.41-678x509.jpg 678w, https://turnbackhoax.id/wp-content/uploads/2021/08/PicsArt_08-11-08.33.41-80x60.jpg 80w" sizes="(max-width: 326px) 100vw, 326px" />		</a>
# 	</figure>
# 	<div class="mh-loop-content mh-clearfix">
# 		<header class="mh-loop-header">
# 			<h3 class="entry-title mh-loop-title">
# 				<a href="https://turnbackhoax.id/2021/08/11/salah-bantuan-rp500-ribu-dari-kementerian-sosial-ri/" rel="bookmark">
# 					[SALAH] Bantuan Rp500 Ribu dari Kementerian Sosial RI				</a>
# 			</h3>
# 			<div class="mh-meta mh-loop-meta">
# 				<span class="mh-meta-date updated"><i class="fa fa-clock-o"></i>Agustus 11, 2021</span>
# <span class="mh-meta-author author vcard"><i class="fa fa-user"></i><a class="fn" href="https://turnbackhoax.id/author/admin/">Admin Web</a></span>
# <span class="mh-meta-comments"><i class="fa fa-comment-o"></i><a class="mh-comment-count-link" href="https://turnbackhoax.id/2021/08/11/salah-bantuan-rp500-ribu-dari-kementerian-sosial-ri/#mh-comments">0</a></span>
# 			</div>
# 		</header>
# 		<div class="mh-loop-excerpt">
# 			<div class="mh-excerpt"><p>Hasil Periksa Fakta Gabriela Nauli Sinaga (Universitas Sumatera Utara) Faktanya, tidak ada jenis bantuan dengan mengisi survey dari Kemensos RI. Hal ini pun telah ditegaskan <a class="mh-excerpt-more" href="https://turnbackhoax.id/2021/08/11/salah-bantuan-rp500-ribu-dari-kementerian-sosial-ri/" title="[SALAH] Bantuan Rp500 Ribu dari Kementerian Sosial RI">[&#8230;]</a></p>
# </div>		</div>
# 	</div>
# </article><article class="mh-loop-item mh-clearfix post-67943 post type-post status-publish format-standard has-post-thumbnail hentry category-fitnah-hasut-hoax">
# ...
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/10/01/salah-utsmaniy-menjadi-pelopor-dalam-penanganan-wabah-melalui-vaksinasi/">[SALAH] &#8220;Utsmaniy menjadi pelopor dalam penanganan wabah melalui vaksinasi&#8221;</a>
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/10/01/salah-akun-facebook-wakil-gubernur-kalimantan-tengah-edy-pratowo/">[SALAH] Akun Facebook Wakil Gubernur Kalimantan Tengah, Edy Pratowo</a>
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/10/01/salah-gambar-tangkapan-layar-berjudul-nelayan-natuna-dibayangi-kapal-kuwait-hingga-nelayan-yaman/">[SALAH] Gambar Tangkapan Layar Berjudul &#8220;Nelayan Natuna Dibayangi Kapal Kuwait Hingga Nelayan Yaman&#8221;</a>
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/09/30/salah-narasi-mulai-tanggal-6-kemarin-siap2-kedepan-beli-lotek-cendol-seblak-cireng-cilok-dan-sebagainya-bisa-jadi-wajib-oleh-yuan/">[SALAH] Narasi “Mulai tanggal 6 kemarin siap2 kedepan beli lotek, cendol, seblak, cireng, cilok dan sebagainya bisa jadi wajib oleh yuan”</a>
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/09/30/salah-video-mama-egawati-yg-lagi-dirawat-di-rspp/">[SALAH] Video “mama Egawati yg lagi dirawat di RSPP”</a>
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/09/30/salah-video-rakyat-menang-pemerintah-rumania-menutup-semua-pusat-vaksin/">[SALAH] Video &#8220;Rakyat Menang.. !! Pemerintah Rumania menutup semua pusat vaksin..!&#8221;</a>
# 									</li>
# 											<li>
# 					<a href="https://turnbackhoax.id/2021/09/30/salah-situs-bank-rakyat-indonesia-120th-anniversary-through-the-questionnaire-you-will-have-a-chance-to-get-3000-dollar/">[SALAH] Situs &#8220;Bank Rakyat Indonesia 120th Anniversary! Through the questionnaire, you will have a chance to get 3000 Dollar.&#8221;</a>
# 									</li>
# 					</ul>
#
# 		</div><div id="tag_cloud-2" class="mh-widget widget_tag_cloud"><h4 class="mh-widget-title"><span class="mh-widget-title-inner">Tag</span></h4><div class="tagcloud"><a href="https://turnbackhoax.id/tag/cekfaktacovid19/" class="tag-cloud-link tag-link-2141 tag-link-position-1" style="font-size: 12px;">#CekFaktaCOVID19</a>
# <a href="https://turnbackhoax.id/tag/cekfaktapilkadamafindo/" class="tag-cloud-link tag-link-2194 tag-link-position-2" style="font-size: 12px;">#cekfaktapilkadamafindo</a>
# <a href="https://turnbackhoax.id/tag/agama/" class="tag-cloud-link tag-link-183 tag-link-position-3" style="font-size: 12px;">AGAMA</a>
# <a href="https://turnbackhoax.id/tag/ahok/" class="tag-cloud-link tag-link-3 tag-link-position-4" style="font-size: 12px;">ahok</a>
# <a href="https://turnbackhoax.id/tag/anies-baswedan/" class="tag-cloud-link tag-link-136 tag-link-position-5" style="font-size: 12px;">anies baswedan</a>
# <a href="https://turnbackhoax.id/tag/bencana-alam/" class="tag-cloud-link tag-link-725 tag-link-position-6" style="font-size: 12px;">Bencana Alam</a>
# <a href="https://turnbackhoax.id/tag/china/" class="tag-cloud-link tag-link-177 tag-link-position-7" style="font-size: 12px;">china</a>
# <a href="https://turnbackhoax.id/tag/coronavirus/" class="tag-cloud-link tag-link-1785 tag-link-position-8" style="font-size: 12px;">Coronavirus</a>
# <a href="https://turnbackhoax.id/tag/covid-19/" class="tag-cloud-link tag-link-1804 tag-link-position-9" style="font-size: 12px;">COVID-19</a>
# <a href="https://turnbackhoax.id/tag/disinformasi/" class="tag-cloud-link tag-link-159 tag-link-position-10" style="font-size: 12px;">disinformasi</a>
# <a href="https://turnbackhoax.id/tag/fabricated-content/" class="tag-cloud-link tag-link-1372 tag-link-position-11" style="font-size: 12px;">Fabricated Content</a>
# <a href="https://turnbackhoax.id/tag/facebook/" class="tag-cloud-link tag-link-235 tag-link-position-12" style="font-size: 12px;">Facebook</a>
# <a href="https://turnbackhoax.id/tag/false-connection/" class="tag-cloud-link tag-link-1361 tag-link-position-13" style="font-size: 12px;">False Connection</a>
# <a href="https://turnbackhoax.id/tag/false-context/" class="tag-cloud-link tag-link-1340 tag-link-position-14" style="font-size: 12px;">False Context</a>
# <a href="https://turnbackhoax.id/tag/foto/" class="tag-cloud-link tag-link-293 tag-link-position-15" style="font-size: 12px;">foto</a>
# <a href="https://turnbackhoax.id/tag/fpi/" class="tag-cloud-link tag-link-105 tag-link-position-16" style="font-size: 12px;">fpi</a>
# <a href="https://turnbackhoax.id/tag/hoaks/" class="tag-cloud-link tag-link-742 tag-link-position-17" style="font-size: 12px;">hoaks</a>
# <a href="https://turnbackhoax.id/tag/imposter-content/" class="tag-cloud-link tag-link-1328 tag-link-position-18" style="font-size: 12px;">Imposter Content</a>
# <a href="https://turnbackhoax.id/tag/jokowi/" class="tag-cloud-link tag-link-6 tag-link-position-19" style="font-size: 12px;">jokowi</a>
# <a href="https://turnbackhoax.id/tag/joko-widodo/" class="tag-cloud-link tag-link-27 tag-link-position-20" style="font-size: 12px;">joko widodo</a>
# <a href="https://turnbackhoax.id/tag/kesehatan/" class="tag-cloud-link tag-link-21 tag-link-position-21" style="font-size: 12px;">kesehatan</a>
# <a href="https://turnbackhoax.id/tag/klarifikasi/" class="tag-cloud-link tag-link-155 tag-link-position-22" style="font-size: 12px;">klarifikasi</a>
# <a href="https://turnbackhoax.id/tag/koneksi-yang-salah/" class="tag-cloud-link tag-link-1362 tag-link-position-23" style="font-size: 12px;">Koneksi yang Salah</a>
# <a href="https://turnbackhoax.id/tag/konten-palsu/" class="tag-cloud-link tag-link-1756 tag-link-position-24" style="font-size: 12px;">Konten Palsu</a>
# <a href="https://turnbackhoax.id/tag/konten-tiruan/" class="tag-cloud-link tag-link-1329 tag-link-position-25" style="font-size: 12px;">Konten Tiruan</a>
# <a href="https://turnbackhoax.id/tag/konten-yang-dimanipulasi/" class="tag-cloud-link tag-link-1324 tag-link-position-26" style="font-size: 12px;">Konten yang Dimanipulasi</a>
# <a href="https://turnbackhoax.id/tag/konten-yang-menyesatkan/" class="tag-cloud-link tag-link-1765 tag-link-position-27" style="font-size: 12px;">Konten yang Menyesatkan</a>
# <a href="https://turnbackhoax.id/tag/konten-yang-salah/" class="tag-cloud-link tag-link-1347 tag-link-position-28" style="font-size: 12px;">Konten yang Salah</a>
# <a href="https://turnbackhoax.id/tag/kpu/" class="tag-cloud-link tag-link-120 tag-link-position-29" style="font-size: 12px;">kpu</a>
# <a href="https://turnbackhoax.id/tag/maruf-amin/" class="tag-cloud-link tag-link-1246 tag-link-position-30" style="font-size: 12px;">Ma&#039;ruf Amin</a>
# <a href="https://turnbackhoax.id/tag/manipulated-content/" class="tag-cloud-link tag-link-1323 tag-link-position-31" style="font-size: 12px;">Manipulated Content</a>
# <a href="https://turnbackhoax.id/tag/misleading-content/" class="tag-cloud-link tag-link-1495 tag-link-position-32" style="font-size: 12px;">Misleading Content</a>
# <a href="https://turnbackhoax.id/tag/pemilu-2019/" class="tag-cloud-link tag-link-1031 tag-link-position-33" style="font-size: 12px;">Pemilu 2019</a>
# <a href="https://turnbackhoax.id/tag/pilpres-2019/" class="tag-cloud-link tag-link-1016 tag-link-position-34" style="font-size: 12px;">pilpres 2019</a>
# <a href="https://turnbackhoax.id/tag/pki/" class="tag-cloud-link tag-link-207 tag-link-position-35" style="font-size: 12px;">PKI</a>
# <a href="https://turnbackhoax.id/tag/polisi/" class="tag-cloud-link tag-link-66 tag-link-position-36" style="font-size: 12px;">polisi</a>
# <a href="https://turnbackhoax.id/tag/politik/" class="tag-cloud-link tag-link-216 tag-link-position-37" style="font-size: 12px;">politik</a>
# <a href="https://turnbackhoax.id/tag/polri/" class="tag-cloud-link tag-link-404 tag-link-position-38" style="font-size: 12px;">polri</a>
# <a href="https://turnbackhoax.id/tag/presiden-joko-widodo/" class="tag-cloud-link tag-link-230 tag-link-position-39" style="font-size: 12px;">presiden joko widodo</a>
# <a href="https://turnbackhoax.id/tag/tni/" class="tag-cloud-link tag-link-92 tag-link-position-40" style="font-size: 12px;">tni</a>
# <a href="https://turnbackhoax.id/tag/twitter/" class="tag-cloud-link tag-link-1443 tag-link-position-41" style="font-size: 12px;">twitter</a>
# <a href="https://turnbackhoax.id/tag/video/" class="tag-cloud-link tag-link-288 tag-link-position-42" style="font-size: 12px;">Video</a>
# <a href="https://turnbackhoax.id/tag/virus-corona/" class="tag-cloud-link tag-link-1786 tag-link-position-43" style="font-size: 12px;">virus corona</a>
# <a href="https://turnbackhoax.id/tag/whatsapp/" class="tag-cloud-link tag-link-412 tag-link-position-44" style="font-size: 12px;">whatsapp</a>
# <a href="https://turnbackhoax.id/tag/youtube/" class="tag-cloud-link tag-link-1680 tag-link-position-45" style="font-size: 12px;">Youtube</a></div>
# </div><div id="archives-2" class="mh-widget widget_archive"><h4 class="mh-widget-title"><span class="mh-widget-title-inner">Arsip</span></h4>
# 			<ul>
# 					<li><a href='https://turnbackhoax.id/2021/10/'>Oktober 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/09/'>September 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/08/'>Agustus 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/07/'>Juli 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/06/'>Juni 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/05/'>Mei 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/04/'>April 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/03/'>Maret 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/02/'>Februari 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2021/01/'>Januari 2021</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/12/'>Desember 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/11/'>November 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/10/'>Oktober 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/09/'>September 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/08/'>Agustus 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/07/'>Juli 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/06/'>Juni 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/05/'>Mei 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/04/'>April 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/03/'>Maret 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/02/'>Februari 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2020/01/'>Januari 2020</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/12/'>Desember 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/11/'>November 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/10/'>Oktober 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/09/'>September 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/08/'>Agustus 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/07/'>Juli 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/06/'>Juni 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/05/'>Mei 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/04/'>April 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/03/'>Maret 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/02/'>Februari 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2019/01/'>Januari 2019</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/12/'>Desember 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/11/'>November 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/10/'>Oktober 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/09/'>September 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/08/'>Agustus 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/07/'>Juli 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/06/'>Juni 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/05/'>Mei 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/04/'>April 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/03/'>Maret 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/02/'>Februari 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2018/01/'>Januari 2018</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/12/'>Desember 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/11/'>November 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/10/'>Oktober 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/09/'>September 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/08/'>Agustus 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/07/'>Juli 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/06/'>Juni 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/05/'>Mei 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/04/'>April 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/03/'>Maret 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/02/'>Februari 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2017/01/'>Januari 2017</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/12/'>Desember 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/11/'>November 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/10/'>Oktober 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/09/'>September 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/08/'>Agustus 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/07/'>Juli 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/06/'>Juni 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/05/'>Mei 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/04/'>April 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/03/'>Maret 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/02/'>Februari 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2016/01/'>Januari 2016</a></li>
# 	<li><a href='https://turnbackhoax.id/2015/12/'>Desember 2015</a></li>
# 	<li><a href='https://turnbackhoax.id/2015/11/'>November 2015</a></li>
# 	<li><a href='https://turnbackhoax.id/2015/10/'>Oktober 2015</a></li>
# 	<li><a href='https://turnbackhoax.id/2015/09/'>September 2015</a></li>
# 	<li><a href='https://turnbackhoax.id/2015/07/'>Juli 2015</a></li>
# 			</ul>
#
# 			</div></aside></div>
# </div><!-- .mh-container-outer -->
# <div class="mh-copyright-wrap">
# 	<div class="mh-container mh-container-inner mh-clearfix">
# 		<p class="mh-copyright">Copyright &copy; 2021 | WordPress Theme by <a href="https://mhthemes.com/" rel="nofollow">MH Themes</a></p>
# 	</div>
# </div>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-includes/js/dist/vendor/regenerator-runtime.min.js?ver=0.13.7' id='regenerator-runtime-js'></script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=3.15.0' id='wp-polyfill-js'></script>
# <script type='text/javascript' id='contact-form-7-js-extra'>
# /* <![CDATA[ */
# var wpcf7 = {"api":{"root":"https:\/\/turnbackhoax.id\/wp-json\/","namespace":"contact-form-7\/v1"},"cached":"1"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-content/plugins/contact-form-7/includes/js/index.js?ver=5.4.2' id='contact-form-7-js'></script>
# <script type='text/javascript' src='https://www.google.com/recaptcha/api.js?render=6LemwpwUAAAAAC3l3VH0kZVZyJCH2iNVx8fMT7f4&#038;ver=3.0' id='google-recaptcha-js'></script>
# <script type='text/javascript' id='wpcf7-recaptcha-js-extra'>
# /* <![CDATA[ */
# var wpcf7_recaptcha = {"sitekey":"6LemwpwUAAAAAC3l3VH0kZVZyJCH2iNVx8fMT7f4","actions":{"homepage":"homepage","contactform":"contactform"}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-content/plugins/contact-form-7/modules/recaptcha/index.js?ver=5.4.2' id='wpcf7-recaptcha-js'></script>
# <script type='text/javascript' src='https://turnbackhoax.id/wp-includes/js/wp-embed.min.js?ver=5.8.1' id='wp-embed-js'></script>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://turnbackhoax.id/?s=PPKM"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
