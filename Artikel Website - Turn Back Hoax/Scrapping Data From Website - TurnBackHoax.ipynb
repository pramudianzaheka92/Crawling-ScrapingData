# %%
# Import Library
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ### Halaman 1

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/?s={}".format(keyword)

# %%
#Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
"""
"Untuk Looping Cuman Masih Gagal"
data = []

for page in range(1, 56):
    req = requests.get("https://turnbackhoax.id/?s=covid-19"+ str(page))
    soup = BeautifulSoup(req.text, "html.parser")
    
    content = [1, 56]
    for teks in content:
        column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))
    
    for i in column:
        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
        link = i.find("a", {"rel": "bookmark"})["href"]
data.append([text, link])
"""
# Out:
# '\n"Untuk Looping Cuman Masih Gagal"\ndata = []\n\nfor page in range(1, 56):\n    req = requests.get("https://turnbackhoax.id/?s=covid-19"+ str(page))\n    soup = BeautifulSoup(req.text, "html.parser")\n    \n    content = [1, 56]\n    for teks in content:\n        column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))\n    \n    for i in column:\n        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")\n        link = i.find("a", {"rel": "bookmark"})["href"]\ndata.append([text, link])\n'

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df1 = pd.DataFrame(data)
df1.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Foto PM Singapura Mengantre Vaksin Co...
# 1  [[SALAH] Vaksin Covid-19 Dapat Mengubah Warna ...
# 2  [[SALAH] Mengonsumsi Labu Kuning Dapat Menyemb...
# 3        [[SALAH] Muammar Gaddafi Prediksi Covid-19]
# 4  [[SALAH] Obat Covid-19 Molnulpiravir Mulai Ber...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/10/06/salah-foto-...
# 1  https://turnbackhoax.id/2021/09/30/salah-vaksi...
# 2  https://turnbackhoax.id/2021/09/22/salah-mengo...
# 3  https://turnbackhoax.id/2021/09/04/salah-muamm...
# 4  https://turnbackhoax.id/2021/09/03/salah-obat-...

# %%
# Mengganti nama kolom pada DataFrame "df1"
df1.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df1.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Foto PM Singapura Mengantre Vaksin Co...
# 1  [[SALAH] Vaksin Covid-19 Dapat Mengubah Warna ...
# 2  [[SALAH] Mengonsumsi Labu Kuning Dapat Menyemb...
# 3        [[SALAH] Muammar Gaddafi Prediksi Covid-19]
# 4  [[SALAH] Obat Covid-19 Molnulpiravir Mulai Ber...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/10/06/salah-foto-...
# 1  https://turnbackhoax.id/2021/09/30/salah-vaksi...
# 2  https://turnbackhoax.id/2021/09/22/salah-mengo...
# 3  https://turnbackhoax.id/2021/09/04/salah-muamm...
# 4  https://turnbackhoax.id/2021/09/03/salah-obat-...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 2

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/2/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df2 = pd.DataFrame(data)
df2.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Foto Beberapa Jenazah Covid-19 di Bek...
# 1  [[SALAH] Mata Jenazah Covid-19 diambil tanpa S...
# 2  [[SALAH] Minuman Penambah Imun untuk Cegah Pen...
# 3  [[SALAH] Singapura Negara Pertama yang Lakukan...
# 4  [[SALAH] Nilai CT Pada Tes PCR Menentukan Kese...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/07/25/salah-foto-...
# 1  https://turnbackhoax.id/2021/07/25/salah-mata-...
# 2  https://turnbackhoax.id/2021/07/21/salah-minum...
# 3  https://turnbackhoax.id/2021/07/20/salah-singa...
# 4  https://turnbackhoax.id/2021/07/19/salah-nilai...

# %%
# Mengganti nama kolom pada DataFrame "df2"
df2.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df2.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Foto Beberapa Jenazah Covid-19 di Bek...
# 1  [[SALAH] Mata Jenazah Covid-19 diambil tanpa S...
# 2  [[SALAH] Minuman Penambah Imun untuk Cegah Pen...
# 3  [[SALAH] Singapura Negara Pertama yang Lakukan...
# 4  [[SALAH] Nilai CT Pada Tes PCR Menentukan Kese...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/25/salah-foto-...
# 1  https://turnbackhoax.id/2021/07/25/salah-mata-...
# 2  https://turnbackhoax.id/2021/07/21/salah-minum...
# 3  https://turnbackhoax.id/2021/07/20/salah-singa...
# 4  https://turnbackhoax.id/2021/07/19/salah-nilai...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 3

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/3/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df3 = pd.DataFrame(data)
df3.head()
# Out:
#                                                    0  \
# 0                 [[SALAH] Covid-19 Tidak Mematikan]
# 1         [[SALAH] Resep Obat Untuk Pasien Covid-19]
# 2  [[SALAH] Jateng Membludak, Media TV Hanya Lipu...
# 3  [[SALAH] “Pemkot Pekanbaru, Riau menarik vaksi...
# 4  [[SALAH] Vaksinasi Sebabkan Varian Baru COVID-19]
#
#                                                    1
# 0  https://turnbackhoax.id/2021/06/26/salah-covid...
# 1  https://turnbackhoax.id/2021/06/25/salah-resep...
# 2  https://turnbackhoax.id/2021/06/24/salah-jaten...
# 3  https://turnbackhoax.id/2021/06/17/salah-pemko...
# 4  https://turnbackhoax.id/2021/06/16/salah-vaksi...

# %%
# Mengganti nama kolom pada DataFrame "df3"
df3.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df3.head()
# Out:
#                                                 Text  \
# 0                 [[SALAH] Covid-19 Tidak Mematikan]
# 1         [[SALAH] Resep Obat Untuk Pasien Covid-19]
# 2  [[SALAH] Jateng Membludak, Media TV Hanya Lipu...
# 3  [[SALAH] “Pemkot Pekanbaru, Riau menarik vaksi...
# 4  [[SALAH] Vaksinasi Sebabkan Varian Baru COVID-19]
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/06/26/salah-covid...
# 1  https://turnbackhoax.id/2021/06/25/salah-resep...
# 2  https://turnbackhoax.id/2021/06/24/salah-jaten...
# 3  https://turnbackhoax.id/2021/06/17/salah-pemko...
# 4  https://turnbackhoax.id/2021/06/16/salah-vaksi...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 4

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/4/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df4 = pd.DataFrame(data)
df4.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video “Seseorang yang wafat karena te...
# 1  [[SALAH] Foto Seorang Lansia Menggunakan Alat ...
# 2  [[FALSE] Inhaling Mothballs, Cloves, Carom See...
# 3  [[SALAH] Menghirup Kapur Barus, Cengkeh, Biji ...
# 4  [[FALSE] All Covid-19 Vaccine Test Animals Are...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/05/02/salah-video...
# 1  https://turnbackhoax.id/2021/04/25/salah-foto-...
# 2  https://turnbackhoax.id/2021/04/25/false-inhal...
# 3  https://turnbackhoax.id/2021/04/23/salah-mengh...
# 4  https://turnbackhoax.id/2021/04/22/false-all-c...

# %%
# Mengganti nama kolom pada DataFrame "df4"
df4.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df4.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Seseorang yang wafat karena te...
# 1  [[SALAH] Foto Seorang Lansia Menggunakan Alat ...
# 2  [[FALSE] Inhaling Mothballs, Cloves, Carom See...
# 3  [[SALAH] Menghirup Kapur Barus, Cengkeh, Biji ...
# 4  [[FALSE] All Covid-19 Vaccine Test Animals Are...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/05/02/salah-video...
# 1  https://turnbackhoax.id/2021/04/25/salah-foto-...
# 2  https://turnbackhoax.id/2021/04/25/false-inhal...
# 3  https://turnbackhoax.id/2021/04/23/salah-mengh...
# 4  https://turnbackhoax.id/2021/04/22/false-all-c...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 5

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/5/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df5 = pd.DataFrame(data)
df5.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Bio Farma Mengadakan Vaksinasi Covid-...
# 1  [[SALAH] Menghirup Uap Panas Teh Herbal Dapat ...
# 2  [[SALAH] Pesan Berantai Video “Potensi Bahaya ...
# 3  [[SALAH] Uap Panas Hasil Rebusan Daun Jambu da...
# 4  [[SALAH] Pemberian Vaksin Covid-19 oleh Badan ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/12/salah-bio-f...
# 1  https://turnbackhoax.id/2021/03/10/salah-mengh...
# 2  https://turnbackhoax.id/2021/03/07/salah-pesan...
# 3  https://turnbackhoax.id/2021/03/07/salah-uap-p...
# 4  https://turnbackhoax.id/2021/03/06/salah-pembe...

# %%
# Mengganti nama kolom pada DataFrame "df5"
df5.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df5.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Bio Farma Mengadakan Vaksinasi Covid-...
# 1  [[SALAH] Menghirup Uap Panas Teh Herbal Dapat ...
# 2  [[SALAH] Pesan Berantai Video “Potensi Bahaya ...
# 3  [[SALAH] Uap Panas Hasil Rebusan Daun Jambu da...
# 4  [[SALAH] Pemberian Vaksin Covid-19 oleh Badan ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/03/12/salah-bio-f...
# 1  https://turnbackhoax.id/2021/03/10/salah-mengh...
# 2  https://turnbackhoax.id/2021/03/07/salah-pesan...
# 3  https://turnbackhoax.id/2021/03/07/salah-uap-p...
# 4  https://turnbackhoax.id/2021/03/06/salah-pembe...

# %% [markdown]
# ### Halaman 6

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/6/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df6 = pd.DataFrame(data)
df6.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Lianhua Qingwen Dapat Digunakan Sebag...
# 1  [[SALAH] Nomor Palsu Satgas Covid-19 Beredar d...
# 2     [[SALAH] Diagram Chip 5G pada Vaksin Covid-19]
# 3  [[SALAH] Obat COVID-19 Dexamethasone Lebih Mur...
# 4  [[SALAH] “Eric tohir sang missionaris chip cov...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/28/salah-lianh...
# 1  https://turnbackhoax.id/2021/01/28/salah-nomor...
# 2  https://turnbackhoax.id/2021/01/21/salah-diagr...
# 3  https://turnbackhoax.id/2021/01/21/salah-obat-...
# 4  https://turnbackhoax.id/2021/01/21/salah-penje...

# %%
# Mengganti nama kolom pada DataFrame "df6"
df6.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df6.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Lianhua Qingwen Dapat Digunakan Sebag...
# 1  [[SALAH] Nomor Palsu Satgas Covid-19 Beredar d...
# 2     [[SALAH] Diagram Chip 5G pada Vaksin Covid-19]
# 3  [[SALAH] Obat COVID-19 Dexamethasone Lebih Mur...
# 4  [[SALAH] “Eric tohir sang missionaris chip cov...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/01/28/salah-lianh...
# 1  https://turnbackhoax.id/2021/01/28/salah-nomor...
# 2  https://turnbackhoax.id/2021/01/21/salah-diagr...
# 3  https://turnbackhoax.id/2021/01/21/salah-obat-...
# 4  https://turnbackhoax.id/2021/01/21/salah-penje...

# %% [markdown]
# ### Halaman 7

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/7/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df7 = pd.DataFrame(data)
df7.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Resep Campuran Teh Hijau dan Lemon Un...
# 1  [[SALAH] Video Ribuan Jamaah Tanpa Masker Samb...
# 2  [[SALAH] “Bill Gates mengatakan dia tidak akan...
# 3  [[SALAH] Minum Teh Dengan Batang Lada Dapat Se...
# 4  [[SALAH] Istora Senayan Dijadikan Tempat Penam...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/05/salah-resep...
# 1  https://turnbackhoax.id/2021/01/02/salah-video...
# 2  https://turnbackhoax.id/2021/01/02/salah-bill-...
# 3  https://turnbackhoax.id/2021/01/02/salah-minum...
# 4  https://turnbackhoax.id/2021/01/01/salah-istor...

# %%
# Mengganti nama kolom pada DataFrame "df7"
df7.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df7.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Resep Campuran Teh Hijau dan Lemon Un...
# 1  [[SALAH] Video Ribuan Jamaah Tanpa Masker Samb...
# 2  [[SALAH] “Bill Gates mengatakan dia tidak akan...
# 3  [[SALAH] Minum Teh Dengan Batang Lada Dapat Se...
# 4  [[SALAH] Istora Senayan Dijadikan Tempat Penam...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/01/05/salah-resep...
# 1  https://turnbackhoax.id/2021/01/02/salah-video...
# 2  https://turnbackhoax.id/2021/01/02/salah-bill-...
# 3  https://turnbackhoax.id/2021/01/02/salah-minum...
# 4  https://turnbackhoax.id/2021/01/01/salah-istor...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 8

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/8/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df8 = pd.DataFrame(data)
df8.head()
# Out:
#                                                    0  \
# 0  [[SALAH] China Sembuh dari COVID-19 Tanpa Vaksin]
# 1  [[SALAH] Gratis Langganan Netflix Selama Satu ...
# 2   [[SALAH] Kopi Bisa Cegah dan Sembuhkan Covid-19]
# 3  [[SALAH] Foto Keadaan Rumah Sakit yang Sepi da...
# 4  [[SALAH] Vaksin Covid-19 berbasis mRNA Dapat M...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/08/salah-china...
# 1  https://turnbackhoax.id/2020/12/07/salah-grati...
# 2  https://turnbackhoax.id/2020/12/07/salah-kopi-...
# 3  https://turnbackhoax.id/2020/12/04/salah-foto-...
# 4  https://turnbackhoax.id/2020/11/28/salah-vaksi...

# %%
# Mengganti nama kolom pada DataFrame "df8"
df8.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df8.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] China Sembuh dari COVID-19 Tanpa Vaksin]
# 1  [[SALAH] Gratis Langganan Netflix Selama Satu ...
# 2   [[SALAH] Kopi Bisa Cegah dan Sembuhkan Covid-19]
# 3  [[SALAH] Foto Keadaan Rumah Sakit yang Sepi da...
# 4  [[SALAH] Vaksin Covid-19 berbasis mRNA Dapat M...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/12/08/salah-china...
# 1  https://turnbackhoax.id/2020/12/07/salah-grati...
# 2  https://turnbackhoax.id/2020/12/07/salah-kopi-...
# 3  https://turnbackhoax.id/2020/12/04/salah-foto-...
# 4  https://turnbackhoax.id/2020/11/28/salah-vaksi...

# %%
df8.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Pemerintah Berikan Bantuan Internet G...
# 16  [[SALAH] Pesan Pembuatan Grup WhatsApp tentang...
# 17  [[SALAH] Kawasan Johor Baru Malaysia Terdampak...
# 18  [[SALAH] Pandemi Telah Berakhir dan Covid-19 A...
# 19  [[SALAH] “Pendataan Imunisasi Covid-19 untuk T...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/11/02/salah-pemer...
# 16  https://turnbackhoax.id/2020/10/27/salah-pesan...
# 17  https://turnbackhoax.id/2020/10/27/salah-kawas...
# 18  https://turnbackhoax.id/2020/10/25/salah-pande...
# 19  https://turnbackhoax.id/2020/10/23/salah-penda...

# %% [markdown]
# ### Halaman 9

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/9/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df9 = pd.DataFrame(data)
df9.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Jenazah Pasien Covid-19 Dikubur Masih...
# 1  [[SALAH] Vaksin COVID-19 Dapat Mengubah DNA Ma...
# 2  [[SALAH] Presiden Donald Trump Meninggal Dunia...
# 3  [[SALAH] MUI Larang Penggunaan Vaksin Covid-19...
# 4  [[SALAH] COVID-19 Tidak Membuat Orang Meningga...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/20/salah-jenaz...
# 1  https://turnbackhoax.id/2020/10/19/salah-vaksi...
# 2  https://turnbackhoax.id/2020/10/17/salah-presi...
# 3  https://turnbackhoax.id/2020/10/16/salah-mui-l...
# 4  https://turnbackhoax.id/2020/10/15/salah-covid...

# %%
# Mengganti nama kolom pada DataFrame "df9"
df9.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df9.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Jenazah Pasien Covid-19 Dikubur Masih...
# 1  [[SALAH] Vaksin COVID-19 Dapat Mengubah DNA Ma...
# 2  [[SALAH] Presiden Donald Trump Meninggal Dunia...
# 3  [[SALAH] MUI Larang Penggunaan Vaksin Covid-19...
# 4  [[SALAH] COVID-19 Tidak Membuat Orang Meningga...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/10/20/salah-jenaz...
# 1  https://turnbackhoax.id/2020/10/19/salah-vaksi...
# 2  https://turnbackhoax.id/2020/10/17/salah-presi...
# 3  https://turnbackhoax.id/2020/10/16/salah-mui-l...
# 4  https://turnbackhoax.id/2020/10/15/salah-covid...

# %% [markdown]
# ### Halaman 10

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/10/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df10 = pd.DataFrame(data)
df10.head()
# Out:
#                                                    0  \
# 0  [[SALAH] 200 Mayat Korban Covid-19 Sekali Kubu...
# 1  [[SALAH] Foto Peta Persebaran COVID-19 di Jaka...
# 2  [[SALAH] Sejumlah Negara Membeli Produk Alat T...
# 3  [[SALAH] Video Teknik Menahan Napas Untuk Dete...
# 4  [[SALAH] Covid-19 Singkatan dari Certificate o...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/18/salah-200-m...
# 1  https://turnbackhoax.id/2020/09/18/salah-foto-...
# 2  https://turnbackhoax.id/2020/09/18/salah-sejum...
# 3  https://turnbackhoax.id/2020/09/14/salah-video...
# 4  https://turnbackhoax.id/2020/09/06/salah-covid...

# %%
# Mengganti nama kolom pada DataFrame "df10"
df10.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df10.tail()
# Out:
#                                                  Text  \
# 15     [[FALSE] Canada Is Already Free From Covid-19]
# 16      [[SALAH] Kanada Sudah Terbebas dari Covid-19]
# 17  [[SALAH] Pesan Berantai Kantor Pusat PT Kawan ...
# 18  [[ACARA] Muhammadiyah COVID-19 Command Center:...
# 19  [[SALAH] Setiap Hari Puskesmas di Kelapa Gadin...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/11/false-canad...
# 16  https://turnbackhoax.id/2020/08/11/salah-kanad...
# 17  https://turnbackhoax.id/2020/08/10/salah-pesan...
# 18  https://turnbackhoax.id/2020/08/08/acara-muham...
# 19  https://turnbackhoax.id/2020/08/07/salah-setia...

# %% [markdown]
# ### Halaman 11

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/11/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df11 = pd.DataFrame(data)
df11.tail()
# Out:
#                                                     0  \
# 15   [[SALAH] Covid-19 Tidak Murni Sebabkan Kematian]
# 16  [[SALAH] Beberapa RSUD Di Jakarta dan Depok Di...
# 17  [[SALAH] Pedagang di Pasar Segiri Positif Covi...
# 18  [[SALAH] Nasi Padang Menjadi Sumber Penularan ...
# 19  [[SALAH] “Video pembuangan jenazah-jenazah kor...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/07/17/salah-covid...
# 16  https://turnbackhoax.id/2020/07/16/salah-beber...
# 17  https://turnbackhoax.id/2020/07/13/salah-pedag...
# 18  https://turnbackhoax.id/2020/07/13/salah-nasi-...
# 19  https://turnbackhoax.id/2020/07/12/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df11"
df11.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df11.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Pedagang di Pasar Mayestik Meninggal ...
# 1  [[ACARA] MAFINDO Malang: Bincang Online “Cek F...
# 2  [[DOKUMENTASI] MAFINDO Jombang: The Fact Talk ...
# 3  [[BERITA] KOMPAS: “Infodemi Membuat Publik Aba...
# 4  [[SALAH] Foto Presiden Jokowi Bersama Pelawak ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/08/07/salah-pedag...
# 1  https://turnbackhoax.id/2020/08/05/dokumentasi...
# 2  https://turnbackhoax.id/2020/08/05/dokumentasi...
# 3  https://turnbackhoax.id/2020/08/05/berita-komp...
# 4  https://turnbackhoax.id/2020/08/04/salah-foto-...

# %% [markdown]
# ### Halaman 12

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/12/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
"""
"Untuk Looping Cuman Masih Gagal"
data = []
#count_page = 0

for page in range(1, 56):
    #count_page += 1
    #print("Halaman Scrapping: ", count_page)
    
    req = requests.get(url + str(page))
    soup = BeautifulSoup(req.text, "html.parser")
    column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))
    
    for i in column:
        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
        link = i.find("a", {"rel": "bookmark"})["href"]
        data.append([text, link])
"""
# Out:
# '\n"Untuk Looping Cuman Masih Gagal"\ndata = []\n#count_page = 0\n\nfor page in range(1, 56):\n    #count_page += 1\n    #print("Halaman Scrapping: ", count_page)\n    \n    req = requests.get(url + str(page))\n    soup = BeautifulSoup(req.text, "html.parser")\n    column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))\n    \n    for i in column:\n        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")\n        link = i.find("a", {"rel": "bookmark"})["href"]\n        data.append([text, link])\n'

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df12 = pd.DataFrame(data)
df12.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Petugas Rapid Test Jarang Mengganti S...
# 16  [[SALAH] “warga Puruk cahu murung raya desa ma...
# 17  [[SALAH] Video “Kisah pilu dari ITALY IBU nya ...
# 18  [[SALAH] PBB Tak Beri Bantuan Covid-19 Bagi Ne...
# 19  [[SALAH] “Italia mengalahkan COVID-19 “Koagula...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/06/02/salah-sarun...
# 16  https://turnbackhoax.id/2020/05/28/salah-warga...
# 17  https://turnbackhoax.id/2020/05/27/salah-video...
# 18  https://turnbackhoax.id/2020/05/26/salah-pbb-t...
# 19  https://turnbackhoax.id/2020/05/26/salah-itali...

# %%
# Mengganti nama kolom pada DataFrame "df12"
df12.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df12.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “SEHARI SETELAH DILAKUKAN RAPID TEST ...
# 1  [[SALAH] Desain Helm Covid-19 Pada Kompetisi NFL]
# 2  [[SALAH] Pesta Homo Seksual di Italia Sebelum ...
# 3  [[SALAH] Tak Perlu Ikut Rapid Test, Mencium Ba...
# 4  [[SALAH] Dokter RSAL Surabaya Meninggal akibat...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/07/05/salah-sehar...
# 1  https://turnbackhoax.id/2020/07/03/salah-desai...
# 2  https://turnbackhoax.id/2020/06/27/salah-pesta...
# 3  https://turnbackhoax.id/2020/06/25/salah-tak-p...
# 4  https://turnbackhoax.id/2020/06/23/salah-dokte...

# %% [markdown]
# ### Halaman 13

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/13/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df13 = pd.DataFrame(data)
df13.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Virus Covid-19 Sengaja Dimasukkan ked...
# 16  [[SALAH] Donasi Bahan Iftar dan Sahur di Masa ...
# 17  [[SALAH] ”Seorang Pasien Dalam Pengawasan Covi...
# 18  [[SALAH] Pesan Berantai “Taman Raya Tahap V Zo...
# 19  [[SALAH] Kuota 100GB Gratis dari Pemerintah Se...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/05/12/salah-virus...
# 16  https://turnbackhoax.id/2020/05/12/salah-donas...
# 17  https://turnbackhoax.id/2020/05/11/salah-seora...
# 18  https://turnbackhoax.id/2020/05/11/salah-pesan...
# 19  https://turnbackhoax.id/2020/05/10/salah-kuota...

# %%
# Mengganti nama kolom pada DataFrame "df13"
df13.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df13.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “WHO: Pria berpenis besar lebih renta...
# 1  [[SALAH] Sekeluarga Terinfeksi Covid-19 Setela...
# 2  [[SALAH] Golden Swalayan Jadi Klaster Baru Cov...
# 3  [[SALAH] Manager Giant Pal 6 Banjarmasin Menin...
# 4  [[SALAH] “Registrasi Ambil Dana Bantuan Anda C...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/05/22/salah-who-p...
# 1  https://turnbackhoax.id/2020/05/22/salah-sekel...
# 2  https://turnbackhoax.id/2020/05/19/salah-golde...
# 3  https://turnbackhoax.id/2020/05/19/salah-manag...
# 4  https://turnbackhoax.id/2020/05/18/salah-regis...

# %% [markdown]
# ### Halaman 14

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/14/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df14 = pd.DataFrame(data)
df14.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Bioskop di Palangka Raya Kembali Buka...
# 16  [[SALAH] Hanya di Indonesia Narapidana Dibebas...
# 17  [[SALAH] Beberapa Negara Membuang Jenazah Pasi...
# 18  [[SALAH] Peta Sebaran Covid-19 Wilayah Situbondo]
# 19  [[SALAH] Dari Ratusan Ribu Tahanan Tidak Ada S...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/27/salah-biosk...
# 16  https://turnbackhoax.id/2020/04/26/salah-hanya...
# 17  https://turnbackhoax.id/2020/04/26/salah-beber...
# 18  https://turnbackhoax.id/2020/04/24/salah-peta-...
# 19  https://turnbackhoax.id/2020/04/22/salah-dari-...

# %%
# Mengganti nama kolom pada DataFrame "df14"
df14.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df14.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “Ternyata Klaster penyebar Covid-19 t...
# 1  [[SALAH] Seorang Kakek di Tulungagung Meningga...
# 2  [[SALAH] “Setelah adanya Virus Covid-19. Umat ...
# 3  [[SALAH] “Tenaga Medis Covid-19 RSUD Purworejo...
# 4  [[SALAH] Satgas Covid-19 Kabupaten Pangkep Sem...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/05/10/salah-terny...
# 1  https://turnbackhoax.id/2020/05/07/salah-seora...
# 2  https://turnbackhoax.id/2020/05/07/salah-setel...
# 3  https://turnbackhoax.id/2020/05/07/salah-tenag...
# 4  https://turnbackhoax.id/2020/05/07/salah-satga...

# %% [markdown]
# ### Halaman 15

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/15/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df15 = pd.DataFrame(data)
df15.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Menag Izinkan Masjid Gelar Salat Tara...
# 16  [[SALAH] “Modus Menghabisi Ustadz, disuntik co...
# 17  [[SALAH] Mantan Manajer RAPP dan Istri Terpapa...
# 18  [[SALAH] Terlibat Pembuatan COVID-19 di China,...
# 19  [[SALAH] Rakyat Italia Buang Duit ke Jalan kar...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/08/salah-menag...
# 16  https://turnbackhoax.id/2020/04/06/salah-modus...
# 17  https://turnbackhoax.id/2020/04/06/salah-manta...
# 18  https://turnbackhoax.id/2020/04/03/salah-terli...
# 19  https://turnbackhoax.id/2020/04/03/salah-rakya...

# %%
# Mengganti nama kolom pada DataFrame "df15"
df15.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df15.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Alfamart Menyumbangkan 6000 Kupon Unt...
# 1  [[SALAH] Semua Pasien Positif Covid-19 di Pada...
# 2  [[SALAH] RSUD Waluyo Jati Ditutup Karena Semua...
# 3  [[SALAH] Foto “Italia telah Gagal Sepenuhnya C...
# 4  [[SALAH] Video “Obat COVID-19 Telah Ditemukan ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/22/salah-alfam...
# 1  https://turnbackhoax.id/2020/04/22/salah-semua...
# 2  https://turnbackhoax.id/2020/04/20/salah-rsud-...
# 3  https://turnbackhoax.id/2020/04/19/salah-foto-...
# 4  https://turnbackhoax.id/2020/04/17/salah-video...

# %% [markdown]
# ### Halaman 16

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/16/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df16 = pd.DataFrame(data)
df16.tail()
# Out:
#                                                     0  \
# 15  [[BERITA] Update status WNA yang Meninggal di ...
# 16  [[BERITA] Perkembangan Chloroquine Untuk Obat ...
# 17         [[SALAH] “Ganja Mampu Menangkal Covid-19”]
# 18  [[SALAH] Dosen Kedokteran Gigi UI Meninggal Ka...
# 19  [[SALAH] Foto “1 korban dlm pengawasan Covid-1...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/21/berita-upda...
# 16  https://turnbackhoax.id/2020/03/21/berita-perk...
# 17  https://turnbackhoax.id/2020/03/20/salah-ganja...
# 18  https://turnbackhoax.id/2020/03/18/salah-dosen...
# 19  https://turnbackhoax.id/2020/03/18/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df16"
df16.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df16.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “jakarta menjadi daerah paling banyak...
# 1  [[RILIS PERS] Launching AyoLawanCOVID19.ID, Ge...
# 2  [[SALAH] Menaruh Amoxilin Dalam Tandon Air Dap...
# 3  [[SALAH] Mulai Senin 30 Maret Kota Makassar lo...
# 4  [[SALAH] Foto “kumpulan untuk mengakhiri COVID...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/03/salah-jakar...
# 1  https://turnbackhoax.id/2020/04/02/rilis-pers-...
# 2  https://turnbackhoax.id/2020/03/31/salah-menar...
# 3  https://turnbackhoax.id/2020/03/30/salah-mulai...
# 4  https://turnbackhoax.id/2020/03/30/salah-foto-...

# %% [markdown]
# ### Halaman 17

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/17/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df17 = pd.DataFrame(data)
df17.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “WHO : Merokok, Salah satu solusi pen...
# 16  [[SALAH] WHO Merencanakan Modifikasi Genetik M...
# 17  [[SALAH] Video “mama Egawati yg lagi dirawat d...
# 18  [[SALAH] Video “Rakyat Menang.. !! Pemerintah ...
# 19  [[SALAH] Tukul Arwana Alami Pendarahan Otak ka...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/08/salah-who-m...
# 16  https://turnbackhoax.id/2021/10/01/salah-who-m...
# 17  https://turnbackhoax.id/2021/09/30/salah-video...
# 18  https://turnbackhoax.id/2021/09/30/salah-video...
# 19  https://turnbackhoax.id/2021/09/30/salah-tukul...

# %%
# Mengganti nama kolom pada DataFrame "df17"
df17.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df17.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “Satu lagi Mentri Kabinet Jokowi Posi...
# 1  [[SALAH] “Chloroquine (Obat Malaria Klorokuin)...
# 2         [[SALAH] COVID-19 Sudah Sampai Purwakarta]
# 3  [[SALAH] “Alkohol Bisa Membunuh Coronavirus Co...
# 4  [[SALAH] Ditemukannya Virus Corona atau COVID-...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/03/17/salah-satu-...
# 1  https://turnbackhoax.id/2020/03/17/salah-chlor...
# 2  https://turnbackhoax.id/2020/03/16/salah-covid...
# 3  https://turnbackhoax.id/2020/03/16/salah-alkoh...
# 4  https://turnbackhoax.id/2020/03/16/salah-ditem...

# %% [markdown]
# ### Halaman 18

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/18/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df18 = pd.DataFrame(data)
df18.tail()
# Out:
#                                                     0  \
# 15       [[SALAH] Video Kota Prabumulih tanpa Korona]
# 16  [[SALAH] Vaksin Corona Mengandung Babi, Dapat ...
# 17  [[SALAH] Foto Poster Pengumuman Nikah Gratis d...
# 18  [[SALAH] Bendera Merah Putih Dilarang Berkibar...
# 19  [[SALAH] Akun Whatsapp Sekretaris Daerah Kota ...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/08/27/salah-video...
# 16  https://turnbackhoax.id/2021/08/27/salah-vaksi...
# 17  https://turnbackhoax.id/2021/08/27/salah-foto-...
# 18  https://turnbackhoax.id/2021/08/25/salah-bende...
# 19  https://turnbackhoax.id/2021/08/24/salah-akun-...

# %%
# Mengganti nama kolom pada DataFrame "df18"
df18.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df18.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Operasi Razia Lalu Lintas di Banjarma...
# 1      [[SALAH] PPKM diperpanjang Bansos dihentikan]
# 2  [[SALAH] Video Umat Nasrani Diikat di Afganistan]
# 3  [[SALAH] Siaran tvOneNews “Harta Pejabat Menin...
# 4  [[SALAH] Panggilan Telepon Informasi Seputar V...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/09/27/salah-opera...
# 1  https://turnbackhoax.id/2021/09/26/salah-ppkm-...
# 2  https://turnbackhoax.id/2021/09/22/salah-video...
# 3  https://turnbackhoax.id/2021/09/20/salah-siara...
# 4  https://turnbackhoax.id/2021/09/19/salah-pangg...

# %% [markdown]
# ### Halaman 19

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/19/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df19 = pd.DataFrame(data)
df19.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Vaksin Astrazeneca, Pfizer, dan Moder...
# 16  [[SALAH] Tautan Pendaftaran Bantuan Sosial Seb...
# 17  [[SALAH] “Vaksin Corona Tidak Terbukti Aman da...
# 18  [[SALAH] Akun Instagram PT Wijaya Karya Indust...
# 19  [[SALAH] Pernyataan Moh Indro Cahyono “TERBONG...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/08/09/salah-vaksi...
# 16  https://turnbackhoax.id/2021/08/07/salah-tauta...
# 17  https://turnbackhoax.id/2021/08/07/salah-vaksi...
# 18  https://turnbackhoax.id/2021/08/02/salah-akun-...
# 19  https://turnbackhoax.id/2021/07/31/salah-perny...

# %%
# Mengganti nama kolom pada DataFrame "df19"
df19.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df19.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Biang covid bill gates kena ti...
# 1  [[SALAH] Hewan Mati Bergelimpangan karena Efek...
# 2  [[SALAH] Informasi Vaksin Dosis 1 dan 2 16 Agu...
# 3       [[SALAH] Ustad Yahya Waloni Meninggal Dunia]
# 4  [[SALAH] Pernyataan Dr. Ir. Hj. Sri Nurdiati “...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/08/22/salah-video...
# 1  https://turnbackhoax.id/2021/08/21/salah-hewan...
# 2  https://turnbackhoax.id/2021/08/20/salah-infor...
# 3  https://turnbackhoax.id/2021/08/20/salah-ustad...
# 4  https://turnbackhoax.id/2021/08/19/salah-perny...

# %% [markdown]
# ### Halaman 20

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/20/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df20 = pd.DataFrame(data)
df20.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “AKHIRNYA!! DUNIA SETUJUI VAKSIN NUSA...
# 16  [[SALAH] Campuran Lemon dan Soda Kue Dapat Mem...
# 17  [[SALAH] “Pemerintah Resmi Izinkan Sholat Idul...
# 18  [[SALAH] Video Kondisi Gibran “BERITA TERBARU ...
# 19  [[SALAH] Pernyataan “Semua orang yang divaksin...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/22/salah-akhir...
# 16  https://turnbackhoax.id/2021/07/22/salah-campu...
# 17  https://turnbackhoax.id/2021/07/22/salah-pemer...
# 18  https://turnbackhoax.id/2021/07/21/salah-video...
# 19  https://turnbackhoax.id/2021/07/20/salah-perny...

# %%
# Mengganti nama kolom pada DataFrame "df20"
df20.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df20.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “Mobil Dinas Presiden Baru, Harga ber...
# 1  [[SALAH] Shopee, Grab dan Gojek Dukung Aksi Na...
# 2  [[SALAH] Surat Donasi Tempat Ibadah Oleh Pemka...
# 3  [[SALAH] Bantuan PPKM Rp1 Juta Bagi Pemilik Se...
# 4  [[SALAH] BNPB Membuka Donasi Kaos Oblong bagi ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/31/salah-mobil...
# 1  https://turnbackhoax.id/2021/07/31/salah-shope...
# 2  https://turnbackhoax.id/2021/07/30/salah-surat...
# 3  https://turnbackhoax.id/2021/07/30/salah-bantu...
# 4  https://turnbackhoax.id/2021/07/29/salah-bnpb-...

# %% [markdown]
# ### Halaman 21

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/21/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df21 = pd.DataFrame(data)
df21.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Relawan Siaga Meluncurkan Program Pen...
# 16  [[SALAH] SPBU Tutup Sementara dari 12 sampai 1...
# 17  [[SALAH] Air Rebusan Bawang Putih Dapat Menyem...
# 18  [[SALAH] “Gubernur Sumut Instruksikan Seluruh ...
# 19  [[SALAH] “Khusus D.K.I Mulai tanggal 7-30 juli...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/12/salah-relaw...
# 16  https://turnbackhoax.id/2021/07/11/salah-spbu-...
# 17  https://turnbackhoax.id/2021/07/10/salah-air-r...
# 18  https://turnbackhoax.id/2021/07/09/salah-guber...
# 19  https://turnbackhoax.id/2021/07/09/salah-khusu...

# %%
# Mengganti nama kolom pada DataFrame "df21"
df21.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df21.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Imbauan Lepas Masker Mulai Rabu 21 Ju...
# 1  [[SALAH] Ustadz Abdul Somad (UAS) Meninggal Du...
# 2  [[SALAH] “Semangkin Gawat Indonesia sekarang i...
# 3  [[SALAH] Chemtrails Penyebar Virus Penyakit Mu...
# 4  [[SALAH] Tabung Selam Dapat Digunakan sebagai ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/20/salah-imbau...
# 1  https://turnbackhoax.id/2021/07/20/salah-ustad...
# 2  https://turnbackhoax.id/2021/07/19/salah-seman...
# 3  https://turnbackhoax.id/2021/07/19/salah-chemt...
# 4  https://turnbackhoax.id/2021/07/18/salah-tabun...

# %% [markdown]
# ### Halaman 22

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/22/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df22 = pd.DataFrame(data)
df22.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Anies Baswedan Hanya Mengurusi Asbak ...
# 16  [[SALAH] Konsumsi Nigella Oil Menghilangkan Pe...
# 17  [[SALAH] Pesan Berantai “SANDIWARA CORONA” dar...
# 18  [[SALAH] “##BERAKHIR PAHIT##. SK GUBERNUR DI C...
# 19     [[SALAH] Foto “Erdogan cium tangan joe biden”]
#
#                                                     1
# 15  https://turnbackhoax.id/2021/06/27/salah-anies...
# 16  https://turnbackhoax.id/2021/06/24/salah-konsu...
# 17  https://turnbackhoax.id/2021/06/23/salah-pesan...
# 18  https://turnbackhoax.id/2021/06/22/salah-berak...
# 19  https://turnbackhoax.id/2021/06/21/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df22"
df22.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df22.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Suara Adzan Di Masjid Dapat Mengecilk...
# 1  [[SALAH] Video “3 ambulance yang sengaja muter...
# 2  [[SALAH] “MAHASISWA AKAN AKSI BESAR BESARAN da...
# 3  [[SALAH] Virus Corona Sangat Ganas Dan Menakut...
# 4  [[SALAH] Per 1 Juli 2021 Mengurus SIM dan SKCK...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/09/salah-suara...
# 1  https://turnbackhoax.id/2021/07/07/salah-video...
# 2  https://turnbackhoax.id/2021/07/05/salah-mahas...
# 3  https://turnbackhoax.id/2021/07/05/salah-virus...
# 4  https://turnbackhoax.id/2021/07/04/salah-per-1...

# %% [markdown]
# ### Halaman 23

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/23/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df23 = pd.DataFrame(data)
df23.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Polisi Membubarkan Massa Aksi Bela Pa...
# 16  [[SALAH] Berada Di Sekitar Orang yang Baru Div...
# 17  [[SALAH] Video “Warga Malaysia antri nginep di...
# 18     [[SALAH] Obat dan Bahan Herbal Mencegah Covid]
# 19  [[SALAH] Foto “Wapres Ma’ruf Amin video call d...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/05/25/salah-polis...
# 16  https://turnbackhoax.id/2021/05/23/salah-berad...
# 17  https://turnbackhoax.id/2021/05/20/salah-video...
# 18  https://turnbackhoax.id/2021/05/20/salah-obat-...
# 19  https://turnbackhoax.id/2021/05/19/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df23"
df23.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df23.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Malaysia Dapat Tambahan 10 Ribu Kuota...
# 1  [[SALAH] “Ini sinetron Bajay Bajuri thn 2002,s...
# 2  [[SALAH] “TAK TERTOLONG..!!! SELAMAT JALAN FAD...
# 3  [[SALAH] Pesepakbola Christian Eriksen Terkena...
# 4  [[SALAH] Bantuan Sosial Rp1.2 Juta Rupiah untu...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/06/19/salah-malay...
# 1  https://turnbackhoax.id/2021/06/19/salah-ini-s...
# 2  https://turnbackhoax.id/2021/06/18/salah-tak-t...
# 3  https://turnbackhoax.id/2021/06/16/salah-pesep...
# 4  https://turnbackhoax.id/2021/06/16/salah-bantu...

# %% [markdown]
# ### Halaman 24

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/24/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df24 = pd.DataFrame(data)
df24.tail()
# Out:
#                                                     0  \
# 15  [[SALAH]  Foto Seorang Anak Memberikan Masker ...
# 16  [[SALAH] Video “salah satu pejabat pemerintah ...
# 17  [[SALAH] Kenaikan Limfosit Usai Vaksin, Sebabk...
# 18  [[SALAH] Video Seorang Kakek Ditahan Karena Ti...
# 19  [[SALAH] Akun Twittter Doku.id “@CsDOKUid” dan...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/04/23/salah-foto-...
# 16  https://turnbackhoax.id/2021/04/21/salah-video...
# 17  https://turnbackhoax.id/2021/04/21/salah-kenai...
# 18  https://turnbackhoax.id/2021/04/19/salah-video...
# 19  https://turnbackhoax.id/2021/04/17/salah-akun-...

# %%
# Mengganti nama kolom pada DataFrame "df24"
df24.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df24.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Mengonsumsi Air Hangat dan Berkumur D...
# 1  [[SALAH] Video “Akhirnya Ketahuan Kenapa Cina ...
# 2  [[SALAH] Video Warga India Menyerang Kendaraan...
# 3  [[SALAH] Mendeteksi Virus Corona dengan Menaha...
# 4  [[SALAH] Foto “Persiapan penutupan jalan tangg...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/05/10/salah-mengo...
# 1  https://turnbackhoax.id/2021/05/10/salah-video...
# 2  https://turnbackhoax.id/2021/05/09/salah-video...
# 3  https://turnbackhoax.id/2021/05/08/salah-mende...
# 4  https://turnbackhoax.id/2021/05/06/salah-foto-...

# %% [markdown]
# ### Halaman 25

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/25/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df25 = pd.DataFrame(data)
df25.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Khawatir Tim Medis Lupa Jenis Vaksin ...
# 16  [[SALAH] Ekstrak Nanas Bisa Dijadikan Obat Vir...
# 17  [[SALAH] Nama AstraZeneca Memiliki Arti ‘Senja...
# 18  [[SALAH] Vaksin Berbasis mRna, Dapat Menyebabk...
# 19  [[SALAH] “Yg vaksin jgn Lupa Kalau bisa sesuai...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/03/30/salah-khawa...
# 16  https://turnbackhoax.id/2021/03/29/salah-ekstr...
# 17  https://turnbackhoax.id/2021/03/29/salah-nama-...
# 18  https://turnbackhoax.id/2021/03/25/salah-vaksi...
# 19  https://turnbackhoax.id/2021/03/25/salah-yg-va...

# %%
# Mengganti nama kolom pada DataFrame "df25"
df25.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df25.head()
# Out:
#                                                 Text  \
# 0     [[SALAH] Bupati Bojonegoro Sebar Bantuan UMKM]
# 1  [[SALAH] Positif Covid Disebabkan oleh Kekuran...
# 2  [[SALAH] “vaksin korongna itu mRNA, ini bukan ...
# 3  [[SALAH] WHO Ungkapkan Bahwa Hasil Tes PCR ada...
# 4  [[SALAH] “Korban Vaksin Lagi. Kini anggota Bri...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/04/17/salah-bupat...
# 1  https://turnbackhoax.id/2021/04/16/salah-posit...
# 2  https://turnbackhoax.id/2021/04/16/salah-vaksi...
# 3  https://turnbackhoax.id/2021/04/16/salah-who-u...
# 4  https://turnbackhoax.id/2021/04/13/salah-korba...

# %% [markdown]
# ### Halaman 26

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/26/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df26 = pd.DataFrame(data)
df26.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Haji 2021 Akan Berlangsung Seperti B...
# 1  [[SALAH] “Tulisan ini dari kawan-kawan komunit...
# 2  [[SALAH] Rumput Paragis untuk Menyembuhkan Kan...
# 3  [[SALAH] Foto Gubernur Korea Selatan Menggunak...
# 4  [[SALAH] 17 Negara Melarang Penyebaran Vaksin ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/25/salah-haji-...
# 1  https://turnbackhoax.id/2021/03/24/salah-tulis...
# 2  https://turnbackhoax.id/2021/03/22/salah-rumpu...
# 3  https://turnbackhoax.id/2021/03/21/salah-foto-...
# 4  https://turnbackhoax.id/2021/03/21/salah-17-ne...

# %%
# Mengganti nama kolom pada DataFrame "df26"
df26.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df26.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Vaksinasi di PPSDMK Cukup Bawa KTP Se...
# 16  [[SALAH] Masa Lockdown di Kanada Berakhir Seja...
# 17  [[SALAH] “Anosmia Bukan Gejala khas Virus, Min...
# 18  [[SALAH] “Jual Minuman Keras Hukumnya Boleh un...
# 19  [[SALAH] Bantuan 3,5 Juta dari Pemerintah untu...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/03/03/salah-vaksi...
# 16  https://turnbackhoax.id/2021/03/03/salah-masa-...
# 17  https://turnbackhoax.id/2021/03/01/salah-anosm...
# 18  https://turnbackhoax.id/2021/03/01/salah-jual-...
# 19  https://turnbackhoax.id/2021/02/27/salah-bantu...

# %% [markdown]
# ### Halaman 27

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/27/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df27 = pd.DataFrame(data)
df27.head()
# Out:
#                                                    0  \
# 0  [[FALSE] “12 important questions and answers b...
# 1  [[SALAH] Menteri Agama Tandatangani Surat Lara...
# 2  [[SALAH] Pernyataan Ketua Satgas Covid terkait...
# 3   [[SALAH] Foto “vtube skrg dibawah naungan FIFA”]
# 4  [[SALAH] “setelah di vaksin maka kasus HIV dan...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/02/27/false-12-im...
# 1  https://turnbackhoax.id/2021/02/23/salah-mente...
# 2  https://turnbackhoax.id/2021/02/23/salah-perny...
# 3  https://turnbackhoax.id/2021/02/20/salah-foto-...
# 4  https://turnbackhoax.id/2021/02/20/salah-setel...

# %%
# Mengganti nama kolom pada DataFrame "df27"
df27.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df27.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Penjualan GeNose C19 Seharga 75 Juta ...
# 16  [[SALAH] “PSBB jawa & Bali di perpanjang sampa...
# 17       [[SALAH] “Semua Fraksi Sepakat Copot Anies”]
# 18  [[SALAH] “Satu2nya negara yg tidak ada COVID19...
# 19          [[SALAH] Pesan Berantai “Paradox vaksin”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/02/06/salah-penju...
# 16  https://turnbackhoax.id/2021/02/06/salah-psbb-...
# 17  https://turnbackhoax.id/2021/02/05/salah-semua...
# 18  https://turnbackhoax.id/2021/02/03/salah-satu2...
# 19  https://turnbackhoax.id/2021/02/02/salah-pesan...

# %% [markdown]
# ### Halaman 28

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/28/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df28 = pd.DataFrame(data)
df28.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “test Ge Nose C19, Mudah n murah. Rp ...
# 1  [[SALAH] Video “Anda Harus Tahu Kebenaran ada ...
# 2  [[SALAH] Video “Cawapres USA Kamala Harris dis...
# 3  [[SALAH] “Gereja Haramkan Vaksin kok MUI Halal...
# 4   [[SALAH] Bank Indonesia Cetak Uang 300 Triliyun]
#
#                                                    1
# 0  https://turnbackhoax.id/2021/02/02/salah-test-...
# 1  https://turnbackhoax.id/2021/02/01/salah-video...
# 2  https://turnbackhoax.id/2021/02/01/salah-video...
# 3  https://turnbackhoax.id/2021/01/31/salah-gerej...
# 4  https://turnbackhoax.id/2021/01/29/salah-bank-...

# %%
# Mengganti nama kolom pada DataFrame "df28"
df28.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df28.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Ada 32 hotel di Jakarta untuk ISOLAS...
# 16  [[SALAH] Ketua BPOM Ditekan dan Diancam Untuk ...
# 17  [[SALAH] Foto Pemerintahan Biden Mengibarkan B...
# 18  [[SALAH] “VAKSINASI PRESIDEN HARUS DIULANG DAN...
# 19  [[SALAH] Tangkapan Layar Video CNN Memberitaka...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/23/salah-ada-3...
# 16  https://turnbackhoax.id/2021/01/23/salah-ketua...
# 17  https://turnbackhoax.id/2021/01/22/salah-foto-...
# 18  https://turnbackhoax.id/2021/01/22/salah-vaksi...
# 19  https://turnbackhoax.id/2021/01/21/salah-tangk...

# %% [markdown]
# ### Halaman 29

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/29/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df29 = pd.DataFrame(data)
df29.head()
# Out:
#                                                    0  \
# 0         [[SALAH] Video Pemakaman Syeikh Ali Jaber]
# 1  [[SALAH] Video “Setelah disuntik vaksin pingsa...
# 2  [[SALAH] “Kasdim 0817 Gresik Mayor Sugeng Riya...
# 3     [[SALAH] Merokok Bisa Menghadang Virus Corona]
# 4  [[SALAH] Pembagian Masker Gratis Dicampur Obat...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/20/salah-video...
# 1  https://turnbackhoax.id/2021/01/19/salah-video...
# 2  https://turnbackhoax.id/2021/01/18/salah-kasdi...
# 3  https://turnbackhoax.id/2021/01/18/salah-merok...
# 4  https://turnbackhoax.id/2021/01/18/salah-pemba...

# %%
# Mengganti nama kolom pada DataFrame "df29"
df29.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df29.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Razia Anak Tidak Bermasker Akan Dikar...
# 16  [[SALAH] Jokowi Kejang dan Meninggal Dunia set...
# 17   [[SALAH] Jokowi Menggunakan Vaksin Buatan Eropa]
# 18  [[SALAH] “Rakyat Aceh menolak vaksin covid19 k...
# 19  [[SALAH] “Kemasan vaksin Sinovac ga pake ampul...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/15/salah-razia...
# 16  https://turnbackhoax.id/2021/01/15/salah-jokow...
# 17  https://turnbackhoax.id/2021/01/14/salah-jokow...
# 18  https://turnbackhoax.id/2021/01/14/salah-rakya...
# 19  https://turnbackhoax.id/2021/01/13/salah-kemas...

# %% [markdown]
# ### Halaman 30

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/30/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df30 = pd.DataFrame(data)
df30.head()
# Out:
#                                                    0  \
# 0   [[SALAH] Anies Ngumpet Pura-Pura Positif Corona]
# 1     [[SALAH] Risma Joget Tanpa Menggunakan Masker]
# 2  [[SALAH] 21% Pasien Mengalami Efek Samping Set...
# 3  [[SALAH] Pesan Berantai Rekrutmen Relawan Untu...
# 4  [[SALAH] Video “vaksin AstraZeneca menggunakan...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/13/salah-anies...
# 1  https://turnbackhoax.id/2021/01/13/salah-risma...
# 2  https://turnbackhoax.id/2021/01/12/salah-21-pa...
# 3  https://turnbackhoax.id/2021/01/12/salah-pesan...
# 4  https://turnbackhoax.id/2021/01/11/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df30"
df30.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df30.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Fabiana Souza, penerima perdana sunt...
# 16  [[SALAH] Vaksin Bermasalah dan Mengerikan, Dis...
# 17  [[SALAH] Masjid Istiqlal Tidak Mengadakan Sala...
# 18  [[SALAH] “Raja Thailand panggil ulama Islam ba...
# 19  [[SALAH] Vaksin Sinovac Mengandung Sel Kera Hi...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/07/salah-fabia...
# 16  https://turnbackhoax.id/2021/01/06/salah-vaksi...
# 17  https://turnbackhoax.id/2021/01/06/salah-masji...
# 18  https://turnbackhoax.id/2021/01/05/salah-raja-...
# 19  https://turnbackhoax.id/2021/01/05/salah-vaksi...

# %% [markdown]
# ### Halaman 31

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/31/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df31 = pd.DataFrame(data)
df31.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Artikel CNN “Seorang Dokter Merekomen...
# 1  [[SALAH] Surat Edaran Kompensasi Zona Merah ol...
# 2  [[SALAH] “kesimpulan Rob Oswald: COVID 19 adal...
# 3  [[SALAH] “mulai tanggal 31-12-2020 pukul 06.00...
# 4  [[SALAH] “WHO menyatakan bahwa vaksin Sinovac ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/05/salah-artik...
# 1  https://turnbackhoax.id/2021/01/03/salah-surat...
# 2  https://turnbackhoax.id/2021/01/01/salah-kesim...
# 3  https://turnbackhoax.id/2021/01/01/salah-mulai...
# 4  https://turnbackhoax.id/2021/01/01/salah-who-m...

# %%
# Mengganti nama kolom pada DataFrame "df31"
df31.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df31.tail()
# Out:
#                                                  Text  \
# 15       [[SALAH] Orang yang Shalat Aman dari Corona]
# 16  [[SALAH] “Rumah Sakit Di Lockdown Karena Pasie...
# 17  [[SALAH] Purworejo Lockdown Mulai Tanggal 24 D...
# 18  [[SALAH] “Syarat Vaksin Gratis Jokowi: BPJS Ke...
# 19       [[SALAH] Foto Demonstrasi di Paris, Prancis]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/12/25/salah-orang...
# 16  https://turnbackhoax.id/2020/12/25/salah-rumah...
# 17  https://turnbackhoax.id/2020/12/24/salah-purwo...
# 18  https://turnbackhoax.id/2020/12/23/salah-syara...
# 19  https://turnbackhoax.id/2020/12/23/salah-foto-...

# %% [markdown]
# ### Halaman 32

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/32/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df32 = pd.DataFrame(data)
df32.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Relawan Alami Gangguan Saraf Setelah ...
# 1  [[SALAH] “Paus Fransiskus Mengatakan Vaksin Co...
# 2  [[SALAH] Jokowi Akan Menggunakan Vaksin Pfizer...
# 3  [[SALAH] Kerumunan Gibran Bebas Hukuman karena...
# 4  [[SALAH] Kebijakan Lockdown dan Menjaga Jarak ...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/23/salah-relaw...
# 1  https://turnbackhoax.id/2020/12/22/salah-paus-...
# 2  https://turnbackhoax.id/2020/12/21/salah-jokow...
# 3  https://turnbackhoax.id/2020/12/20/salah-kerum...
# 4  https://turnbackhoax.id/2020/12/20/salah-kebij...

# %%
# Mengganti nama kolom pada DataFrame "df32"
df32.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df32.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Sidak Masker di Wilayah Kabupaten Jep...
# 16  [[SALAH] Link Untuk Mendapatkan 35 GB Kuota Gr...
# 17  [[SALAH] Pesan WhatsApp Soal Razia Keliling Se...
# 18  [[SALAH] “Baru sehari mentrinya jd TSK bantuan...
# 19    [[SALAH] Pemasangan Barcode pada Badan Manusia]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/12/10/salah-sidak...
# 16  https://turnbackhoax.id/2020/12/09/salah-link-...
# 17  https://turnbackhoax.id/2020/12/07/salah-pesan...
# 18  https://turnbackhoax.id/2020/12/07/salah-baru-...
# 19  https://turnbackhoax.id/2020/12/06/salah-pemas...

# %% [markdown]
# ### Halaman 33

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/33/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df33 = pd.DataFrame(data)
df33.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Pemerintah Kota Surakarta menetapkan...
# 1  [[SALAH] “tim satgas cov ugm saat ini sangat k...
# 2  [[SALAH] Presiden Pecat Menteri Polhukam Mahfu...
# 3  [[SALAH] Wakil Wali Kota Probolinggo Meninggal...
# 4  [[SALAH] “Pesan Bupati Situbondo Sebelum Belia...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/05/salah-pemer...
# 1  https://turnbackhoax.id/2020/12/04/salah-tim-s...
# 2  https://turnbackhoax.id/2020/12/02/salah-presi...
# 3  https://turnbackhoax.id/2020/11/30/salah-wakil...
# 4  https://turnbackhoax.id/2020/11/29/salah-pesan...

# %%
# Mengganti nama kolom pada DataFrame "df33"
df33.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df33.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Pesan Berantai ‘India Is Doing It’ Bi...
# 16  [[SALAH] BPOM Halangi Vaksin yang akan Diberikan]
# 17         [[SALAH] Voucher Undian Alfamart 21 Tahun]
# 18           [[SALAH] Presiden Jokowi Menjadi Dokter]
# 19  [[SALAH] “Bioskop XXI Kembali Dibuka, Penonton...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/11/05/salah-pesan...
# 16  https://turnbackhoax.id/2020/11/03/salah-bpom-...
# 17  https://turnbackhoax.id/2020/10/29/salah-vouch...
# 18  https://turnbackhoax.id/2020/10/28/salah-presi...
# 19  https://turnbackhoax.id/2020/10/21/salah-biosk...

# %% [markdown]
# ### Halaman 34

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/34/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df34 = pd.DataFrame(data)
df34.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Situs Formulir Online BANPRES oleh Ke...
# 1  [[SALAH] “TERNYATA SUDAH 10 hari PENDEMO tidak...
# 2  [[SALAH] Donald Trump: “Darahku adalah vaksinn...
# 3  [[SALAH] Perusakan Alat Musik Ketipung oleh Pe...
# 4  [[SALAH] Dinkes Bantul Keluarkan Surat Penutup...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/20/salah-situs...
# 1  https://turnbackhoax.id/2020/10/18/salah-terny...
# 2  https://turnbackhoax.id/2020/10/16/salah-donal...
# 3  https://turnbackhoax.id/2020/10/16/salah-perus...
# 4  https://turnbackhoax.id/2020/10/16/salah-dinke...

# %%
# Mengganti nama kolom pada DataFrame "df34"
df34.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df34.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Positif Corona, Kondisi Donald Trump...
# 16  [[SALAH] “Emil Saat Diambil Darah untuk Uji Va...
# 17  [[SALAH] “Peneliti, analis laboratorium, tidak...
# 18  [[SALAH] Arahan Kapolres Simalungun Meniadakan...
# 19  [[SALAH] PT Telkom Indonesia Berikan 100GB Dat...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/10/04/salah-posit...
# 16  https://turnbackhoax.id/2020/10/03/salah-emil-...
# 17  https://turnbackhoax.id/2020/10/02/salah-penel...
# 18  https://turnbackhoax.id/2020/10/02/salah-araha...
# 19  https://turnbackhoax.id/2020/10/01/salah-pt-te...

# %% [markdown]
# ### Halaman 35

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/35/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df35 = pd.DataFrame(data)
df35.head()
# Out:
#                                                    0  \
# 0       [[SALAH] “BANSER ADALAH BESANAN DENGAN PKI”]
# 1  [[SALAH] “Cina mentargetkan 100 jt penduduk in...
# 2  [[SALAH] “menghilangkan virus adalah mengkonsu...
# 3  [[SALAH] “Bocor A1. dari temen Gue di Mabes Po...
# 4  [[SALAH] Artikel Detik.com “Trans Studio Bandu...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/01/salah-banse...
# 1  https://turnbackhoax.id/2020/10/01/salah-cina-...
# 2  https://turnbackhoax.id/2020/10/01/salah-mengh...
# 3  https://turnbackhoax.id/2020/09/30/salah-bocor...
# 4  https://turnbackhoax.id/2020/09/28/salah-artik...

# %%
# Mengganti nama kolom pada DataFrame "df35"
df35.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df35.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Ini ada ratusan nyawa dokter yang su...
# 16  [[SALAH] “Jokowi: Tidak Perlu Dibesar besarkan...
# 17  [[SALAH] Foto “Akhirnya Syekh Ali Jabber terba...
# 18  [[SALAH] Selama Covid19 Ada, Tidak ada Orang G...
# 19  [[SALAH] “Anies dapat instruksi dari ‘KAMI’ ag...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/09/17/salah-ini-a...
# 16  https://turnbackhoax.id/2020/09/17/salah-jokow...
# 17  https://turnbackhoax.id/2020/09/17/salah-foto-...
# 18  https://turnbackhoax.id/2020/09/15/salah-selam...
# 19  https://turnbackhoax.id/2020/09/14/salah-anies...

# %% [markdown]
# ### Halaman 36

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/36/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df36 = pd.DataFrame(data)
df36.head()
# Out:
#                                                    0  \
# 0    [[SALAH] Pembagian Masker Gratis Dicampur Bius]
# 1  [[SALAH] “Sejumlah Negara Tak Izinkan WNI Data...
# 2  [[SALAH] Anies Baswedan Mengendarai Mobil Peti...
# 3  [[SALAH] Rumah DP 0% DKI Jakarta dengan Foto P...
# 4  [[SALAH] “RS wisma atlet lampu Kamar menyala s...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/14/salah-pemba...
# 1  https://turnbackhoax.id/2020/09/13/salah-sejum...
# 2  https://turnbackhoax.id/2020/09/12/salah-anies...
# 3  https://turnbackhoax.id/2020/09/12/salah-rumah...
# 4  https://turnbackhoax.id/2020/09/11/salah-rs-wi...

# %%
# Mengganti nama kolom pada DataFrame "df36"
df36.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df36.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Ketika rakyat muak dan jijik, tak ad...
# 16             [[SALAH] Vaksin Covid Sebabkan Mandul]
# 17  [[SALAH] Hukuman Masuk Peti Mati Karena Tidak ...
# 18  [[SALAH] Putri Vladimir Putin Meninggal Setela...
# 19  [[SALAH] Presiden Joko Widodo Terlihat Memakai...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/09/01/salah-ketik...
# 16  https://turnbackhoax.id/2020/08/30/salah-vaksi...
# 17  https://turnbackhoax.id/2020/08/29/salah-hukum...
# 18  https://turnbackhoax.id/2020/08/20/salah-putri...
# 19  https://turnbackhoax.id/2020/08/17/salah-presi...

# %% [markdown]
# ### Halaman 37

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/37/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df37 = pd.DataFrame(data)
df37.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video Rusia Jadi Pemenang Pembuatan V...
# 1  [[SALAH] “Adeku di tilang di toko Samarinda Ce...
# 2          [[SALAH] BIN Tetapkan Jakarta Zona Hitam]
# 3  [[SALAH] Foto “Putri Presiden Rusia Vladimir P...
# 4  [[SALAH] “Gunakan Bagian Putih Masker Di Luar ...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/08/16/salah-video...
# 1  https://turnbackhoax.id/2020/08/16/salah-adeku...
# 2  https://turnbackhoax.id/2020/08/16/salah-bin-t...
# 3  https://turnbackhoax.id/2020/08/15/salah-foto-...
# 4  https://turnbackhoax.id/2020/08/14/salah-gunak...

# %%
# Mengganti nama kolom pada DataFrame "df37"
df37.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df37.tail()
# Out:
#                                                  Text  \
# 15  [[BERITA] Metro TV: “Mafindo: Perlu Ada Kode E...
# 16          [[SALAH] STAN Ditutup Karena Radikalisme]
# 17  [[SALAH] Seluruh Karyawan Pabrik ESEMKA Terken...
# 18  [[SALAH] Foto “1 Agustus 2020, jutaan warga Je...
# 19  [[SALAH] Pesan Berantai “Sebuah peringatan !! ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/09/berita-metr...
# 16  https://turnbackhoax.id/2020/08/07/salah-stan-...
# 17  https://turnbackhoax.id/2020/08/07/salah-selur...
# 18  https://turnbackhoax.id/2020/08/07/salah-foto-...
# 19  https://turnbackhoax.id/2020/08/07/salah-pesan...

# %% [markdown]
# ### Halaman 38

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/38/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df38 = pd.DataFrame(data)
df38.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “99, 9% Tingkat Kesembuhan Covid dan ...
# 1  [[SALAH] Video Jokowi Tidak Tahu Penyebab Kasu...
# 2  [[SALAH] Foto Sirkuit Mandalika NTB Siap digun...
# 3  [[SALAH] Virus ini punya obat Hydroxychloroqui...
# 4  [[SALAH] “Cita-cita kalian sudah saya wujudkan...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/08/06/salah-99-9-...
# 1  https://turnbackhoax.id/2020/08/06/salah-video...
# 2  https://turnbackhoax.id/2020/08/05/salah-foto-...
# 3  https://turnbackhoax.id/2020/08/04/salah-virus...
# 4  https://turnbackhoax.id/2020/08/04/salah-cita-...

# %%
# Mengganti nama kolom pada DataFrame "df38"
df38.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df38.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Kapal Kargo Pengangkut Kadrun tengge...
# 16  [[SALAH] Awas Hati-hati Apa Yang Disemprotkan ...
# 17  [[SALAH] “mayat positif covid 19 dikuburkan ma...
# 18  [[SALAH] Inventaris Pesawat Terbang Untuk Para...
# 19  [[SALAH] “hindari Citos byk karyawannya terpap...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/07/28/salah-kapal...
# 16  https://turnbackhoax.id/2020/07/28/salah-awas-...
# 17  https://turnbackhoax.id/2020/07/28/salah-mayat...
# 18  https://turnbackhoax.id/2020/07/28/salah-inven...
# 19  https://turnbackhoax.id/2020/07/27/salah-hinda...

# %% [markdown]
# ### Halaman 39

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/39/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df39 = pd.DataFrame(data)
df39.head()
# Out:
#                                                    0  \
# 0       [[SALAH] Virus Baru bernama SFTS dari China]
# 1  [[SALAH] Penginjil Asal Amerika Serikat Joyce ...
# 2  [[SALAH] “Indonesia satu2nya negara didunia ya...
# 3  [[SALAH] Foto “Heboh, Israel Ubah Masjid Berse...
# 4  [[SALAH] Petani dipukuli Polisi yang dibayar o...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/07/27/salah-virus...
# 1  https://turnbackhoax.id/2020/07/26/salah-pengi...
# 2  https://turnbackhoax.id/2020/07/26/salah-indon...
# 3  https://turnbackhoax.id/2020/07/25/salah-foto-...
# 4  https://turnbackhoax.id/2020/07/25/salah-petan...

# %%
# Mengganti nama kolom pada DataFrame "df39"
df39.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df39.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Video “Didemo rakyat, KETUA WAKIL RAK...
# 16  [[SALAH] Risma Sujud ke IDI Karena Warga Surab...
# 17  [[SALAH] Xi Jinping Berterimakasih Karena Terp...
# 18  [[SALAH] “Dirut RSUI bersama 2 Direktur RSUI l...
# 19  [[SALAH] Selebaran Kegiatan Budaya “Gawai Daya...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/07/11/salah-video...
# 16  https://turnbackhoax.id/2020/07/10/salah-risma...
# 17  https://turnbackhoax.id/2020/07/10/salah-xi-ji...
# 18  https://turnbackhoax.id/2020/07/08/salah-dirut...
# 19  https://turnbackhoax.id/2020/07/07/salah-seleb...

# %% [markdown]
# ### Halaman 40

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/40/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df40 = pd.DataFrame(data)
df40.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video “Raja Thailand dan Istrinya ber...
# 1  [[FALSE] “Actor Javed Haider sells vegetables ...
# 2  [[SALAH] “Aktor Javed Haider menjual sayuran k...
# 3  [[SALAH] Tenaga Medis di Sampang Sengaja Sebar...
# 4  [[SALAH] Video “rumah sakit terkenal di Brazil...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/07/07/salah-video...
# 1  https://turnbackhoax.id/2020/07/07/false-actor...
# 2  https://turnbackhoax.id/2020/07/07/salah-aktor...
# 3  https://turnbackhoax.id/2020/07/06/salah-tenag...
# 4  https://turnbackhoax.id/2020/07/04/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df40"
df40.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df40.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Peta Kasus Covid DKI “DKI kembali Zon...
# 16  [[SALAH] “New Fatwa ‘Sholat Tanpa Wudhu Tanpa ...
# 17  [[SALAH] Denda Rp250 Ribu Saat Razia Masker Ta...
# 18  [[SALAH] “Menurut laporan WHO, Corona Virus ad...
# 19  [[SALAH] “dokter gigi di Surabaya stres telanj...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/06/24/salah-peta-...
# 16  https://turnbackhoax.id/2020/06/23/salah-new-f...
# 17  https://turnbackhoax.id/2020/06/22/salah-denda...
# 18  https://turnbackhoax.id/2020/06/21/salah-menur...
# 19  https://turnbackhoax.id/2020/06/20/salah-dokte...

# %% [markdown]
# ### Halaman 41

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/41/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df41 = pd.DataFrame(data)
df41.head()
# Out:
#                                                    0  \
# 0  [[EVENT] East-West Center: “Fighting Disinform...
# 1     [[SALAH] “sakitnya apa di diagnosa nya covid”]
# 2  [[SALAH] Abu Vulkanik Dapat Membunuh Virus Cor...
# 3  [[SALAH] Akun Facebook Bupati Tegal “Hajjah Um...
# 4  [[SALAH] Servis Mobil Gratis “Suzuki Peduli Co...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/06/19/event-east-...
# 1  https://turnbackhoax.id/2020/06/18/salah-sakit...
# 2  https://turnbackhoax.id/2020/06/17/salah-abu-v...
# 3          https://turnbackhoax.id/2020/06/17/41098/
# 4  https://turnbackhoax.id/2020/06/17/salah-servi...

# %%
# Mengganti nama kolom pada DataFrame "df41"
df41.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df41.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Keasang pengarep mampu menangani vir...
# 16  [[SALAH] 30 Pembantu Baru Positif Corona di Pe...
# 17  [[SALAH] “Heboh! Pernyataan Dokter Indonesia S...
# 18  [[SALAH] “Pemprov DKI Tunaikan Janji Bansos, N...
# 19      [[SALAH] Video “Setelah lockdown … Maradona”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/06/11/salah-keasa...
# 16  https://turnbackhoax.id/2020/06/11/salah-30-pe...
# 17  https://turnbackhoax.id/2020/06/10/salah-heboh...
# 18  https://turnbackhoax.id/2020/06/10/salah-pempr...
# 19  https://turnbackhoax.id/2020/06/08/salah-video...

# %% [markdown]
# ### Halaman 42

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/42/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df42 = pd.DataFrame(data)
df42.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Corona Virus adalah BOHONG. bukan da...
# 1  [[SALAH] Rekrutmen PT BGA Bersyarat “Bukan ora...
# 2                      [[SALAH] Zona Hitam Surabaya]
# 3                   [[SALAH] PKI Nyamar Jadi Dokter]
# 4  [[SALAH] Foto “Sekarang malesiya sapu habis pe...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/06/06/salah-coron...
# 1  https://turnbackhoax.id/2020/06/06/salah-rekru...
# 2  https://turnbackhoax.id/2020/06/06/salah-zona-...
# 3  https://turnbackhoax.id/2020/06/06/salah-pki-n...
# 4  https://turnbackhoax.id/2020/06/02/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df42"
df42.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df42.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Buntut Penerapan PSBB di Palembang, B...
# 16  [[SALAH] “KRN PEMERINTAHNYA NGEYEL & RAKYATNYA...
# 17  [[SALAH] “kadus dihakimi warga sampai babak be...
# 18  [[SALAH] Voucher Dua Pizza Besar Domino’s Pizz...
# 19  [[SALAH] Ellen DeGeneres Membagikan Bantuan Un...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/26/salah-buntu...
# 16  https://turnbackhoax.id/2020/05/26/salah-krn-p...
# 17  https://turnbackhoax.id/2020/05/25/salah-kadus...
# 18  https://turnbackhoax.id/2020/05/25/salah-vouch...
# 19  https://turnbackhoax.id/2020/05/24/salah-ellen...

# %% [markdown]
# ### Halaman 43

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/43/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df43 = pd.DataFrame(data)
df43.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Video “PENJELASAN AHLI VIRUS BAHWA CO...
# 1     [[SALAH] Daftar Virus yang Berasal dari China]
# 2  [[SALAH] Seleksi Alam Dimulai, 7 Nyawa Dalam 2...
# 3  [[SALAH] Foto “FBI Menangkap Bill Gates Karena...
# 4           [[SALAH] Video “Tanah abang penuh bray”]
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/23/salah-video...
# 1  https://turnbackhoax.id/2020/05/23/salah-dafta...
# 2  https://turnbackhoax.id/2020/05/22/salah-selek...
# 3  https://turnbackhoax.id/2020/05/22/salah-foto-...
# 4  https://turnbackhoax.id/2020/05/21/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df43"
df43.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df43.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Wapres Tidak Masalah Konser Di Bulan...
# 16  [[SALAH] “Perawat Royal td suaminya jg wafat b...
# 17  [[SALAH] “Katanya jaga jarak mutusin mataranta...
# 18  [[SALAH] Pesan Berantai “Ganjar Pranowo Bolehk...
# 19  [[SALAH] “Bikin laboratorium apa mau jualan ub...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/18/salah-wapre...
# 16  https://turnbackhoax.id/2020/05/18/salah-peraw...
# 17  https://turnbackhoax.id/2020/05/18/salah-katan...
# 18  https://turnbackhoax.id/2020/05/18/salah-pesan...
# 19  https://turnbackhoax.id/2020/05/17/salah-bikin...

# %% [markdown]
# ### Halaman 44

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/44/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df44 = pd.DataFrame(data)
df44.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “jgn ke lippo dulu sdh zona merah, 14...
# 1  [[SALAH] Pesan Berantai “ada 13 org penjual da...
# 2  [[SALAH] Video “Warga india diserang Serangga ...
# 3  [[SALAH] Foto Kondisi Pasar Baru Jakarta Ramai...
# 4  [[SALAH] Warga India Membuang Patung Ke Sungai...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/16/salah-jgn-k...
# 1  https://turnbackhoax.id/2020/05/16/salah-pesan...
# 2  https://turnbackhoax.id/2020/05/15/salah-video...
# 3  https://turnbackhoax.id/2020/05/15/salah-foto-...
# 4  https://turnbackhoax.id/2020/05/14/salah-warga...

# %%
# Mengganti nama kolom pada DataFrame "df44"
df44.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df44.tail()
# Out:
#                                                  Text  \
# 15  [[FALSE] “Jack Ma’s advice, hopefully we can g...
# 16  [[SALAH] “Saran Jack Ma semoga kita bisa melew...
# 17  [[SALAH] “Masuukk truusss silahkan masuukk, Or...
# 18    [[SALAH] Bupati Konawe Akui Disuap Menko Luhut]
# 19                        [[SALAH] Video “Plandemic”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/11/false-jack-...
# 16  https://turnbackhoax.id/2020/05/11/salah-saran...
# 17  https://turnbackhoax.id/2020/05/11/salah-masuu...
# 18  https://turnbackhoax.id/2020/05/10/salah-bupat...
# 19  https://turnbackhoax.id/2020/05/10/salah-video...

# %% [markdown]
# ### Halaman 45

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/45/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df45 = pd.DataFrame(data)
df45.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “baru kemarin pemerintah putuskan tak...
# 1  [[SALAH] Sri Mulyani: Pemerintah Pusat Tidak M...
# 2  [[SALAH] Berdamai dengan Corona yang Dimaksud ...
# 3  [[SALAH] “Warga Dibolehkan Mudik Oleh Kemenhub...
# 4  [[SALAH] “menteri kesehatan America sdh menand...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/10/salah-baru-...
# 1  https://turnbackhoax.id/2020/05/09/salah-sri-m...
# 2  https://turnbackhoax.id/2020/05/09/salah-berda...
# 3  https://turnbackhoax.id/2020/05/07/salah-warga...
# 4  https://turnbackhoax.id/2020/05/07/salah-mente...

# %%
# Mengganti nama kolom pada DataFrame "df45"
df45.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df45.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Arab Saudi merayakan masa berakhirny...
# 16  [[SALAH] “Elisa Granato kelinci percobaan vaks...
# 17  [[SALAH] “Fatwah wapres gila Menghina Jokowi S...
# 18  [[SALAH] “Profesor Dr Tasuku Honjo mengatakan ...
# 19  [[SALAH] WHO Sebut Penularan Corona Tak Lagi H...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/01/salah-arab-...
# 16  https://turnbackhoax.id/2020/05/01/salah-elisa...
# 17  https://turnbackhoax.id/2020/05/01/salah-fatwa...
# 18  https://turnbackhoax.id/2020/04/29/salah-profe...
# 19  https://turnbackhoax.id/2020/04/29/salah-who-s...

# %% [markdown]
# ### Halaman 46

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/46/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df46 = pd.DataFrame(data)
df46.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Apabila ada masyarakat tidak mampu m...
# 1  [[SALAH] Donasi Kaos Oblong Bekas Untuk Tim Me...
# 2  [[SALAH] Italia Meminta Dibacakan Al-Qur’an Da...
# 3  [[SALAH] Razia Besar-besaran Karena Kerabat Be...
# 4  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/04/29/salah-apabi...
# 1  https://turnbackhoax.id/2020/04/29/salah-donas...
# 2  https://turnbackhoax.id/2020/04/28/salah-itali...
# 3  https://turnbackhoax.id/2020/04/28/salah-razia...
# 4  https://turnbackhoax.id/2020/04/28/top-5-topik...

# %%
# Mengganti nama kolom pada DataFrame "df46"
df46.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df46.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Gubernur SUMUT instruksikan Seluruh ...
# 16  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 17  [[SALAH] Foto Di Tengah Pemerintah Sibuk Melaw...
# 18       [[SALAH] Azan Dapat Melemahkan Virus Corona]
# 19  [[SALAH] Luhut Perintahkan TNI-Polri Tangkap P...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/04/24/salah-guber...
# 16  https://turnbackhoax.id/2020/04/22/top-5-topik...
# 17  https://turnbackhoax.id/2020/04/22/salah-foto-...
# 18  https://turnbackhoax.id/2020/04/21/salah-azan-...
# 19  https://turnbackhoax.id/2020/04/21/salah-luhut...

# %% [markdown]
# ### Halaman 47

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/47/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df47 = pd.DataFrame(data)
df47.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Hotman Paris Berencana Undang BTS dan...
# 16  [[SALAH] Jokowi Keluarkan Kartu Corona Indones...
# 17  [[SALAH] Akun Instagram Mengatasnamakan BNPB M...
# 18  [[SALAH] Video “BLACK MARKET *ITALIA SUDAH MEN...
# 19  [[SALAH] Insentif Virus Corona, Pemerintah Gra...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/14/salah-hotma...
# 16  https://turnbackhoax.id/2020/04/14/salah-jokow...
# 17  https://turnbackhoax.id/2020/04/13/salah-akun-...
# 18  https://turnbackhoax.id/2020/04/13/salah-video...
# 19  https://turnbackhoax.id/2020/04/12/salah-insen...

# %%
# Mengganti nama kolom pada DataFrame "df47"
df47.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df47.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “di DKI setiap keluarga sudah diberi ...
# 1  [[SALAH] Video “Sudah Lockdown, Sikafir China ...
# 2  [[SALAH] “FBI menggrebek sinagoge Yahudi di Ne...
# 3  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 4  [[SALAH] “Darurat Corona, Ma’ruf Amin Himbau M...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/20/salah-di-dk...
# 1  https://turnbackhoax.id/2020/04/20/salah-video...
# 2  https://turnbackhoax.id/2020/04/18/salah-fbi-m...
# 3  https://turnbackhoax.id/2020/04/17/top-5-topik...
# 4  https://turnbackhoax.id/2020/04/17/salah-darur...

# %% [markdown]
# ### Halaman 48

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/48/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df48 = pd.DataFrame(data)
df48.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Merokok Menghadang Virus Corona Masuk...
# 16  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 17  [[SALAH] “Rezim togog Bedebah pasilitasi karan...
# 18  [[SALAH] Video “Ngeri Karena Corona Italia pun...
# 19  [[SALAH] Video “Donald Trump di ruqyah sebab s...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/07/salah-merok...
# 16  https://turnbackhoax.id/2020/04/07/top-5-topik...
# 17  https://turnbackhoax.id/2020/04/06/salah-rezim...
# 18  https://turnbackhoax.id/2020/04/06/salah-video...
# 19  https://turnbackhoax.id/2020/04/06/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df48"
df48.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df48.head()
# Out:
#                                                 Text  \
# 0  [[FALSE] “Italy arrest Doctor for intentionall...
# 1  [[SALAH] Surat Imbauan Dinkes Kota Batam untuk...
# 2  [[SALAH] Dokter Italia Sengaja Membunuh Pasien...
# 3  [[SALAH] “Tadi Malem di Amerika Serikat, Shola...
# 4  [[SALAH] “Lagu “corona” dr Bimbo.. lagu 30 tah...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/12/false-italy...
# 1  https://turnbackhoax.id/2020/04/12/salah-surat...
# 2  https://turnbackhoax.id/2020/04/12/salah-dokte...
# 3  https://turnbackhoax.id/2020/04/10/salah-tadi-...
# 4  https://turnbackhoax.id/2020/04/10/salah-lagu-...

# %% [markdown]
# ### Halaman 49

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/49/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df49 = pd.DataFrame(data)
df49.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “Untuk mengalahkan virus korona adala...
# 16  [[SALAH] Video “Azan PERTAMA di SPANYOL Setela...
# 17  [[SALAH] “Sekeluarga Kena Corona, Tinggal di B...
# 18             [[FALSE] Video of “lockdown in Spain”]
# 19  [[SALAH] Pemerintah Stop Layanan KRL, MRT, LRT...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/03/salah-untuk...
# 16  https://turnbackhoax.id/2020/04/02/salah-video...
# 17  https://turnbackhoax.id/2020/04/02/salah-sekel...
# 18  https://turnbackhoax.id/2020/04/02/false-pictu...
# 19  https://turnbackhoax.id/2020/04/02/salah-pemer...

# %%
# Mengganti nama kolom pada DataFrame "df49"
df49.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df49.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Puncak Persebaran Virus Corona 4 Apri...
# 1  [[SALAH] Video “Gereja minta di azankan corona...
# 2  [[BERITA] Pasien positif Covid -19 di RST Latu...
# 3     [[SALAH] Video “ITALIA bergema takbir aamiin”]
# 4  [[SALAH] Foto “Dampak 16 Hari Lockdown di Ital...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/06/salah-punca...
# 1  https://turnbackhoax.id/2020/04/05/salah-video...
# 2  https://turnbackhoax.id/2020/04/05/berita-pasi...
# 3  https://turnbackhoax.id/2020/04/05/salah-video...
# 4  https://turnbackhoax.id/2020/04/05/salah-foto-...

# %% [markdown]
# ### Halaman 50

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/50/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df50 = pd.DataFrame(data)
df50.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Foto “59 Orang Jemaat Gereja Tew4s Mi...
# 16  [[SALAH] “ISTANA : TIDAK ADA LOCK DOWN DAERAH,...
# 17             [[SALAH] Bukit Tinggi Segera Lockdown]
# 18  [[SALAH] Video “Di Amerika sudah terjadi penja...
# 19  [[SALAH] Jembatan Suramadu Bebas dari Aktivita...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/30/salah-foto-...
# 16  https://turnbackhoax.id/2020/03/30/salah-istan...
# 17  https://turnbackhoax.id/2020/03/29/salah-bukit...
# 18  https://turnbackhoax.id/2020/03/29/salah-video...
# 19  https://turnbackhoax.id/2020/03/28/salah-jemba...

# %%
# Mengganti nama kolom pada DataFrame "df50"
df50.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df50.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Enam Penumpang Kapal di Pelabuhan Sam...
# 1  [[SALAH] “Ternyata virus corona dapat diobati ...
# 2  [[SALAH] Warga Jakarta Saling Memberikan Seman...
# 3  [[SALAH] “China memang bener” jahat mengirim b...
# 4  [[SALAH] Imigran China Sengaja Membawa Virus, ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/02/salah-enam-...
# 1  https://turnbackhoax.id/2020/04/02/salah-terny...
# 2  https://turnbackhoax.id/2020/04/01/salah-warga...
# 3  https://turnbackhoax.id/2020/04/01/salah-china...
# 4  https://turnbackhoax.id/2020/04/01/salah-imigr...

# %% [markdown]
# ### Menggabungkan Beberapa DataFrame Menjadi 1

# %%
# Membuat DataFrame untuk menampung hasil dari 50 df
data = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, 
       df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40,
       df41, df42, df43, df44, df45, df46, df47, df48, df49, df50]

# Menggabungkan 50 df menjadi 1 dengan fungsi "concat"
data_scrapping = pd.concat(data)

data_scrapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    1000 non-null   object
#  1   URL     1000 non-null   object
# dtypes: object(2)
# memory usage: 23.4+ KB

# %%
data_scrapping.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Foto “59 Orang Jemaat Gereja Tew4s Mi...
# 16  [[SALAH] “ISTANA : TIDAK ADA LOCK DOWN DAERAH,...
# 17             [[SALAH] Bukit Tinggi Segera Lockdown]
# 18  [[SALAH] Video “Di Amerika sudah terjadi penja...
# 19  [[SALAH] Jembatan Suramadu Bebas dari Aktivita...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/03/30/salah-foto-...
# 16  https://turnbackhoax.id/2020/03/30/salah-istan...
# 17  https://turnbackhoax.id/2020/03/29/salah-bukit...
# 18  https://turnbackhoax.id/2020/03/29/salah-video...
# 19  https://turnbackhoax.id/2020/03/28/salah-jemba...

# %%
# Menjadikan DataFrame "data_scrapping" ke dalam bentuk .csv
data_scrapping.to_csv("data scrapping.csv", index=False)
