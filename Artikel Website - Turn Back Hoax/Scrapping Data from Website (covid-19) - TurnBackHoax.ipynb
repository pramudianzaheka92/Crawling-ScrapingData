# %%
# Import Library
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ### Halaman 1

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/?s={}".format(keyword)

# %%
#Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
"""
"Untuk Looping Cuman Masih Gagal"
data = []

for page in range(1, 56):
    req = requests.get("https://turnbackhoax.id/?s=covid-19"+ str(page))
    soup = BeautifulSoup(req.text, "html.parser")
    
    content = [1, 56]
    for teks in content:
        column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))
    
    for i in column:
        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
        link = i.find("a", {"rel": "bookmark"})["href"]
data.append([text, link])
"""
# Out:
# '\n"Untuk Looping Cuman Masih Gagal"\ndata = []\n\nfor page in range(1, 56):\n    req = requests.get("https://turnbackhoax.id/?s=covid-19"+ str(page))\n    soup = BeautifulSoup(req.text, "html.parser")\n    \n    content = [1, 56]\n    for teks in content:\n        column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))\n    \n    for i in column:\n        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")\n        link = i.find("a", {"rel": "bookmark"})["href"]\ndata.append([text, link])\n'

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df1 = pd.DataFrame(data)
df1.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Darah Orang yang Divaksin Covid-19 Me...
# 1  [[SALAH]: Situs Pedulilindungiq.com dan Minta ...
# 2  [[SALAH] Covid-19 adalah Rencana Depopulasi Du...
# 3  [[SALAH] Foto PM Singapura Mengantre Vaksin Co...
# 4  [[SALAH] Vaksin Covid-19 Dapat Mengubah Warna ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/10/14/salah-darah...
# 1  https://turnbackhoax.id/2021/10/10/salah-situs...
# 2  https://turnbackhoax.id/2021/10/08/salah-covid...
# 3  https://turnbackhoax.id/2021/10/06/salah-foto-...
# 4  https://turnbackhoax.id/2021/09/30/salah-vaksi...

# %%
# Mengganti nama kolom pada DataFrame "df1"
df1.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df1.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Darah Orang yang Divaksin Covid-19 Me...
# 1  [[SALAH]: Situs Pedulilindungiq.com dan Minta ...
# 2  [[SALAH] Covid-19 adalah Rencana Depopulasi Du...
# 3  [[SALAH] Foto PM Singapura Mengantre Vaksin Co...
# 4  [[SALAH] Vaksin Covid-19 Dapat Mengubah Warna ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/10/14/salah-darah...
# 1  https://turnbackhoax.id/2021/10/10/salah-situs...
# 2  https://turnbackhoax.id/2021/10/08/salah-covid...
# 3  https://turnbackhoax.id/2021/10/06/salah-foto-...
# 4  https://turnbackhoax.id/2021/09/30/salah-vaksi...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 2

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/2/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df2 = pd.DataFrame(data)
df2.head()
# Out:
#                                                    0  \
# 0    [[SALAH] Daun Sungkai dapat Menangkal Covid-19]
# 1  [[SALAH] Orang yang Pernah Terinfeksi Covid-19...
# 2               [[SALAH] Air Keran Positif Covid-19]
# 3  [[SALAH] Foto Beberapa Jenazah Covid-19 di Bek...
# 4  [[SALAH] Mata Jenazah Covid-19 diambil tanpa S...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/07/29/salah-daun-...
# 1  https://turnbackhoax.id/2021/07/28/salah-orang...
# 2  https://turnbackhoax.id/2021/07/28/salah-air-k...
# 3  https://turnbackhoax.id/2021/07/25/salah-foto-...
# 4  https://turnbackhoax.id/2021/07/25/salah-mata-...

# %%
# Mengganti nama kolom pada DataFrame "df2"
df2.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df2.head()
# Out:
#                                                 Text  \
# 0    [[SALAH] Daun Sungkai dapat Menangkal Covid-19]
# 1  [[SALAH] Orang yang Pernah Terinfeksi Covid-19...
# 2               [[SALAH] Air Keran Positif Covid-19]
# 3  [[SALAH] Foto Beberapa Jenazah Covid-19 di Bek...
# 4  [[SALAH] Mata Jenazah Covid-19 diambil tanpa S...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/29/salah-daun-...
# 1  https://turnbackhoax.id/2021/07/28/salah-orang...
# 2  https://turnbackhoax.id/2021/07/28/salah-air-k...
# 3  https://turnbackhoax.id/2021/07/25/salah-foto-...
# 4  https://turnbackhoax.id/2021/07/25/salah-mata-...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 3

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/3/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df3 = pd.DataFrame(data)
df3.head()
# Out:
#                                                    0  \
# 0  [[FALSE] Biopharmaceutical Company Moderna, In...
# 1  [[SALAH] Foto Daftar Obat Dari RS Yang Bisa Di...
# 2  [[SALAH] Perusahaan Biofarmasi Moderna, Inc Me...
# 3                 [[SALAH] Covid-19 Tidak Mematikan]
# 4         [[SALAH] Resep Obat Untuk Pasien Covid-19]
#
#                                                    1
# 0  https://turnbackhoax.id/2021/07/04/false-bioph...
# 1  https://turnbackhoax.id/2021/07/02/salah-foto-...
# 2  https://turnbackhoax.id/2021/07/02/salah-perus...
# 3  https://turnbackhoax.id/2021/06/26/salah-covid...
# 4  https://turnbackhoax.id/2021/06/25/salah-resep...

# %%
# Mengganti nama kolom pada DataFrame "df3"
df3.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df3.head()
# Out:
#                                                 Text  \
# 0  [[FALSE] Biopharmaceutical Company Moderna, In...
# 1  [[SALAH] Foto Daftar Obat Dari RS Yang Bisa Di...
# 2  [[SALAH] Perusahaan Biofarmasi Moderna, Inc Me...
# 3                 [[SALAH] Covid-19 Tidak Mematikan]
# 4         [[SALAH] Resep Obat Untuk Pasien Covid-19]
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/04/false-bioph...
# 1  https://turnbackhoax.id/2021/07/02/salah-foto-...
# 2  https://turnbackhoax.id/2021/07/02/salah-perus...
# 3  https://turnbackhoax.id/2021/06/26/salah-covid...
# 4  https://turnbackhoax.id/2021/06/25/salah-resep...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 4

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/4/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df4 = pd.DataFrame(data)
df4.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Indonesia berduka, 10 Dokter meningga...
# 1  [[SALAH] Foto “Kremasi massal saat melonjaknya...
# 2  [[SALAH] Covid-19 Adalah Bakteri yang Terpapar...
# 3  [[SALAH] Video “Seseorang yang wafat karena te...
# 4  [[SALAH] Foto Seorang Lansia Menggunakan Alat ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/05/11/salah-indon...
# 1  https://turnbackhoax.id/2021/05/04/salah-foto-...
# 2  https://turnbackhoax.id/2021/05/03/salah-covid...
# 3  https://turnbackhoax.id/2021/05/02/salah-video...
# 4  https://turnbackhoax.id/2021/04/25/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df4"
df4.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df4.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Indonesia berduka, 10 Dokter meningga...
# 1  [[SALAH] Foto “Kremasi massal saat melonjaknya...
# 2  [[SALAH] Covid-19 Adalah Bakteri yang Terpapar...
# 3  [[SALAH] Video “Seseorang yang wafat karena te...
# 4  [[SALAH] Foto Seorang Lansia Menggunakan Alat ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/05/11/salah-indon...
# 1  https://turnbackhoax.id/2021/05/04/salah-foto-...
# 2  https://turnbackhoax.id/2021/05/03/salah-covid...
# 3  https://turnbackhoax.id/2021/05/02/salah-video...
# 4  https://turnbackhoax.id/2021/04/25/salah-foto-...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 5

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/5/?s={}".format(keyword)

# %%
# Scrapping data per halaman secara otomatis
#for page in range (1, 10):

# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df5 = pd.DataFrame(data)
df5.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Tidak Ada Kasus Covid-19 di Bhutan ka...
# 1  [[SALAH] Vaksinasi Covid-19 untuk Warga Non DK...
# 2  [[SALAH] Rusia Menemukan bahwa Covid-19 Tidak ...
# 3  [[SALAH] Bio Farma Mengadakan Vaksinasi Covid-...
# 4  [[SALAH] Menghirup Uap Panas Teh Herbal Dapat ...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/16/salah-tidak...
# 1  https://turnbackhoax.id/2021/03/14/salah-vaksi...
# 2  https://turnbackhoax.id/2021/03/12/salah-rusia...
# 3  https://turnbackhoax.id/2021/03/12/salah-bio-f...
# 4  https://turnbackhoax.id/2021/03/10/salah-mengh...

# %%
# Mengganti nama kolom pada DataFrame "df5"
df5.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df5.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Tidak Ada Kasus Covid-19 di Bhutan ka...
# 1  [[SALAH] Vaksinasi Covid-19 untuk Warga Non DK...
# 2  [[SALAH] Rusia Menemukan bahwa Covid-19 Tidak ...
# 3  [[SALAH] Bio Farma Mengadakan Vaksinasi Covid-...
# 4  [[SALAH] Menghirup Uap Panas Teh Herbal Dapat ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/03/16/salah-tidak...
# 1  https://turnbackhoax.id/2021/03/14/salah-vaksi...
# 2  https://turnbackhoax.id/2021/03/12/salah-rusia...
# 3  https://turnbackhoax.id/2021/03/12/salah-bio-f...
# 4  https://turnbackhoax.id/2021/03/10/salah-mengh...

# %% [markdown]
# ### Halaman 6

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/6/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df6 = pd.DataFrame(data)
df6.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Ramuan Penangkal Covid-19 oleh Kemenkes]
# 1  [[SALAH] Menteri Kesehatan Thailand Menangis S...
# 2  [[SALAH] Bantuan Covid-19 untuk Pemilik SIM A ...
# 3  [[SALAH] Lianhua Qingwen Dapat Digunakan Sebag...
# 4  [[SALAH] Nomor Palsu Satgas Covid-19 Beredar d...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/02/05/salah-ramua...
# 1  https://turnbackhoax.id/2021/02/03/salah-mente...
# 2  https://turnbackhoax.id/2021/02/03/salah-bantu...
# 3  https://turnbackhoax.id/2021/01/28/salah-lianh...
# 4  https://turnbackhoax.id/2021/01/28/salah-nomor...

# %%
# Mengganti nama kolom pada DataFrame "df6"
df6.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df6.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Ramuan Penangkal Covid-19 oleh Kemenkes]
# 1  [[SALAH] Menteri Kesehatan Thailand Menangis S...
# 2  [[SALAH] Bantuan Covid-19 untuk Pemilik SIM A ...
# 3  [[SALAH] Lianhua Qingwen Dapat Digunakan Sebag...
# 4  [[SALAH] Nomor Palsu Satgas Covid-19 Beredar d...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/02/05/salah-ramua...
# 1  https://turnbackhoax.id/2021/02/03/salah-mente...
# 2  https://turnbackhoax.id/2021/02/03/salah-bantu...
# 3  https://turnbackhoax.id/2021/01/28/salah-lianh...
# 4  https://turnbackhoax.id/2021/01/28/salah-nomor...

# %% [markdown]
# ### Halaman 7

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/7/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])
    #print(link)

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df7 = pd.DataFrame(data)
df7.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Hydro Oxy Mouth Freshener Spray Dapat...
# 1  [[SALAH] “Vaksin Sinovac Covid-19 yang akan di...
# 2  [[SALAH] Tulisan dr. Siti Fadillah terkait Pen...
# 3  [[SALAH] Resep Campuran Teh Hijau dan Lemon Un...
# 4  [[SALAH] Video Ribuan Jamaah Tanpa Masker Samb...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/07/salah-hydro...
# 1  https://turnbackhoax.id/2021/01/06/salah-vaksi...
# 2  https://turnbackhoax.id/2021/01/05/salah-tulis...
# 3  https://turnbackhoax.id/2021/01/05/salah-resep...
# 4  https://turnbackhoax.id/2021/01/02/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df7"
df7.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df7.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Hydro Oxy Mouth Freshener Spray Dapat...
# 1  [[SALAH] “Vaksin Sinovac Covid-19 yang akan di...
# 2  [[SALAH] Tulisan dr. Siti Fadillah terkait Pen...
# 3  [[SALAH] Resep Campuran Teh Hijau dan Lemon Un...
# 4  [[SALAH] Video Ribuan Jamaah Tanpa Masker Samb...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/01/07/salah-hydro...
# 1  https://turnbackhoax.id/2021/01/06/salah-vaksi...
# 2  https://turnbackhoax.id/2021/01/05/salah-tulis...
# 3  https://turnbackhoax.id/2021/01/05/salah-resep...
# 4  https://turnbackhoax.id/2021/01/02/salah-video...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    20 non-null     object
#  1   URL     20 non-null     object
# dtypes: object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Halaman 8

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/8/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df8 = pd.DataFrame(data)
df8.head()
# Out:
#                                                    0  \
# 0  [[SALAH] COVID-19 Merupakan Buatan Manusia seb...
# 1  [[SALAH] Jangan Datang ke Jalan Melong Cikawao...
# 2  [[SALAH] Minum Minyak Kayu Putih Dapat Menyemb...
# 3  [[SALAH] China Sembuh dari COVID-19 Tanpa Vaksin]
# 4  [[SALAH] Gratis Langganan Netflix Selama Satu ...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/11/salah-covid...
# 1  https://turnbackhoax.id/2020/12/11/salah-janga...
# 2  https://turnbackhoax.id/2020/12/08/salah-minum...
# 3  https://turnbackhoax.id/2020/12/08/salah-china...
# 4  https://turnbackhoax.id/2020/12/07/salah-grati...

# %%
# Mengganti nama kolom pada DataFrame "df8"
df8.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df8.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] COVID-19 Merupakan Buatan Manusia seb...
# 1  [[SALAH] Jangan Datang ke Jalan Melong Cikawao...
# 2  [[SALAH] Minum Minyak Kayu Putih Dapat Menyemb...
# 3  [[SALAH] China Sembuh dari COVID-19 Tanpa Vaksin]
# 4  [[SALAH] Gratis Langganan Netflix Selama Satu ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/12/11/salah-covid...
# 1  https://turnbackhoax.id/2020/12/11/salah-janga...
# 2  https://turnbackhoax.id/2020/12/08/salah-minum...
# 3  https://turnbackhoax.id/2020/12/08/salah-china...
# 4  https://turnbackhoax.id/2020/12/07/salah-grati...

# %%
df8.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Luhut Positif Covid-19 dan Dilarikan ...
# 16  [[SALAH] 48 Orang di Korea Selatan Meninggal S...
# 17  [[SALAH] Kisah Dokter yang Kekasihnya Positif ...
# 18  [[SALAH] Pemerintah Berikan Bantuan Internet G...
# 19  [[SALAH] Pesan Pembuatan Grup WhatsApp tentang...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/11/11/salah-luhut...
# 16  https://turnbackhoax.id/2020/11/09/salah-48-or...
# 17  https://turnbackhoax.id/2020/11/09/salah-kisah...
# 18  https://turnbackhoax.id/2020/11/02/salah-pemer...
# 19  https://turnbackhoax.id/2020/10/27/salah-pesan...

# %% [markdown]
# ### Halaman 9

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/9/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML menjadi BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df9 = pd.DataFrame(data)
df9.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Kawasan Johor Baru Malaysia Terdampak...
# 1  [[SALAH] Pandemi Telah Berakhir dan Covid-19 A...
# 2  [[SALAH] “Pendataan Imunisasi Covid-19 untuk T...
# 3  [[SALAH] Jenazah Pasien Covid-19 Dikubur Masih...
# 4  [[SALAH] Vaksin COVID-19 Dapat Mengubah DNA Ma...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/27/salah-kawas...
# 1  https://turnbackhoax.id/2020/10/25/salah-pande...
# 2  https://turnbackhoax.id/2020/10/23/salah-penda...
# 3  https://turnbackhoax.id/2020/10/20/salah-jenaz...
# 4  https://turnbackhoax.id/2020/10/19/salah-vaksi...

# %%
# Mengganti nama kolom pada DataFrame "df9"
df9.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df9.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Kawasan Johor Baru Malaysia Terdampak...
# 1  [[SALAH] Pandemi Telah Berakhir dan Covid-19 A...
# 2  [[SALAH] “Pendataan Imunisasi Covid-19 untuk T...
# 3  [[SALAH] Jenazah Pasien Covid-19 Dikubur Masih...
# 4  [[SALAH] Vaksin COVID-19 Dapat Mengubah DNA Ma...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/10/27/salah-kawas...
# 1  https://turnbackhoax.id/2020/10/25/salah-pande...
# 2  https://turnbackhoax.id/2020/10/23/salah-penda...
# 3  https://turnbackhoax.id/2020/10/20/salah-jenaz...
# 4  https://turnbackhoax.id/2020/10/19/salah-vaksi...

# %% [markdown]
# ### Halaman 10

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/10/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df10 = pd.DataFrame(data)
df10.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Daun Mimba Dapat Menyembuhkan Covid-...
# 1  [[SALAH] “Minum Kopi 3 x Sehari untuk menangka...
# 2  [[SALAH] Tutorial Mendapat Kuota Gratis 20GB d...
# 3  [[SALAH] 200 Mayat Korban Covid-19 Sekali Kubu...
# 4  [[SALAH] Foto Peta Persebaran COVID-19 di Jaka...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/23/salah-daun-...
# 1  https://turnbackhoax.id/2020/09/21/salah-minum...
# 2          https://turnbackhoax.id/2020/09/20/47786/
# 3  https://turnbackhoax.id/2020/09/18/salah-200-m...
# 4  https://turnbackhoax.id/2020/09/18/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df10"
df10.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df10.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Tangkapan Layar Pengakuan Relawan Su...
# 16  [[SALAH] Video “Kembang api Olimpiade ditampil...
# 17  [[SALAH] Air Kelapa Muda, Jeruk Nipis, dan Gar...
# 18     [[FALSE] Canada Is Already Free From Covid-19]
# 19      [[SALAH] Kanada Sudah Terbebas dari Covid-19]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/18/salah-tangk...
# 16  https://turnbackhoax.id/2020/08/17/salah-video...
# 17  https://turnbackhoax.id/2020/08/16/salah-air-k...
# 18  https://turnbackhoax.id/2020/08/11/false-canad...
# 19  https://turnbackhoax.id/2020/08/11/salah-kanad...

# %% [markdown]
# ### Halaman 11

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/11/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df11 = pd.DataFrame(data)
df11.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] 71 Pasien Covid-19 Klaster Hajatan Bo...
# 16  [[SALAH] Kondisi Jenazah Korban Covid-19 Di Ru...
# 17  [[SALAH] “Takut Dibunuh, Ahli Virus China Kabu...
# 18   [[SALAH] Covid-19 Tidak Murni Sebabkan Kematian]
# 19  [[SALAH] Beberapa RSUD Di Jakarta dan Depok Di...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/07/22/salah-71-pa...
# 16  https://turnbackhoax.id/2020/07/21/salah-kondi...
# 17  https://turnbackhoax.id/2020/07/21/salah-takut...
# 18  https://turnbackhoax.id/2020/07/17/salah-covid...
# 19  https://turnbackhoax.id/2020/07/16/salah-beber...

# %%
# Mengganti nama kolom pada DataFrame "df11"
df11.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df11.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Pesan Berantai Kantor Pusat PT Kawan ...
# 1  [[ACARA] Muhammadiyah COVID-19 Command Center:...
# 2  [[SALAH] Setiap Hari Puskesmas di Kelapa Gadin...
# 3  [[SALAH] Pedagang di Pasar Mayestik Meninggal ...
# 4  [[ACARA] MAFINDO Malang: Bincang Online “Cek F...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/08/10/salah-pesan...
# 1  https://turnbackhoax.id/2020/08/08/acara-muham...
# 2  https://turnbackhoax.id/2020/08/07/salah-setia...
# 3  https://turnbackhoax.id/2020/08/07/salah-pedag...
# 4  https://turnbackhoax.id/2020/08/05/dokumentasi...

# %% [markdown]
# ### Halaman 12

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/12/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
"""
"Untuk Looping Cuman Masih Gagal"
data = []
#count_page = 0

for page in range(1, 56):
    #count_page += 1
    #print("Halaman Scrapping: ", count_page)
    
    req = requests.get(url + str(page))
    soup = BeautifulSoup(req.text, "html.parser")
    column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))
    
    for i in column:
        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
        link = i.find("a", {"rel": "bookmark"})["href"]
        data.append([text, link])
"""
# Out:
# '\n"Untuk Looping Cuman Masih Gagal"\ndata = []\n#count_page = 0\n\nfor page in range(1, 56):\n    #count_page += 1\n    #print("Halaman Scrapping: ", count_page)\n    \n    req = requests.get(url + str(page))\n    soup = BeautifulSoup(req.text, "html.parser")\n    column = soup.findAll("div", "mh-loop-content mh-clearfix"+ str(teks))\n    \n    for i in column:\n        text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")\n        link = i.find("a", {"rel": "bookmark"})["href"]\n        data.append([text, link])\n'

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df12 = pd.DataFrame(data)
df12.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Video “DI BALIK COVID-19/CORONA TERNY...
# 16  [[SALAH] Santri yang Hidupnya di Pondok Dicuri...
# 17  [[SALAH] Pasien Covid-19 di Cimahi Kabur Dari ...
# 18  [[SALAH] Petugas Rapid Test Jarang Mengganti S...
# 19  [[SALAH] “warga Puruk cahu murung raya desa ma...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/06/08/salah-video...
# 16  https://turnbackhoax.id/2020/06/04/salah-santr...
# 17  https://turnbackhoax.id/2020/06/02/salah-pasie...
# 18  https://turnbackhoax.id/2020/06/02/salah-sarun...
# 19  https://turnbackhoax.id/2020/05/28/salah-warga...

# %%
# Mengganti nama kolom pada DataFrame "df12"
df12.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df12.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Pedagang di Pasar Segiri Positif Covi...
# 1  [[SALAH] Nasi Padang Menjadi Sumber Penularan ...
# 2  [[SALAH] “Video pembuangan jenazah-jenazah kor...
# 3  [[SALAH] “SEHARI SETELAH DILAKUKAN RAPID TEST ...
# 4  [[SALAH] Desain Helm Covid-19 Pada Kompetisi NFL]
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/07/13/salah-pedag...
# 1  https://turnbackhoax.id/2020/07/13/salah-nasi-...
# 2  https://turnbackhoax.id/2020/07/12/salah-video...
# 3  https://turnbackhoax.id/2020/07/05/salah-sehar...
# 4  https://turnbackhoax.id/2020/07/03/salah-desai...

# %% [markdown]
# ### Halaman 13

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/13/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df13 = pd.DataFrame(data)
df13.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] 236 Anggota Polisi Positif Covid-19 d...
# 16  [[SALAH] Ulama Windusari Dijemput Paksa Terkai...
# 17  [[SALAH] Tuduhan Foto Interior Lab Darurat COV...
# 18  [[SALAH] Virus Covid-19 Sengaja Dimasukkan ked...
# 19  [[SALAH] Donasi Bahan Iftar dan Sahur di Masa ...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/05/16/salah-236-a...
# 16  https://turnbackhoax.id/2020/05/14/salah-ulama...
# 17  https://turnbackhoax.id/2020/05/14/salah-tuduh...
# 18  https://turnbackhoax.id/2020/05/12/salah-virus...
# 19  https://turnbackhoax.id/2020/05/12/salah-donas...

# %%
# Mengganti nama kolom pada DataFrame "df13"
df13.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df13.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Kisah pilu dari ITALY IBU nya ...
# 1  [[SALAH] PBB Tak Beri Bantuan Covid-19 Bagi Ne...
# 2  [[SALAH] “Italia mengalahkan COVID-19 “Koagula...
# 3  [[SALAH] “WHO: Pria berpenis besar lebih renta...
# 4  [[SALAH] Sekeluarga Terinfeksi Covid-19 Setela...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/05/27/salah-video...
# 1  https://turnbackhoax.id/2020/05/26/salah-pbb-t...
# 2  https://turnbackhoax.id/2020/05/26/salah-itali...
# 3  https://turnbackhoax.id/2020/05/22/salah-who-p...
# 4  https://turnbackhoax.id/2020/05/22/salah-sekel...

# %% [markdown]
# ### Halaman 14

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/14/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df14 = pd.DataFrame(data)
df14.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Sheikh Hamdan Al Maktoum Memberikan U...
# 16  [[SALAH] Akibat Pandemi COVID-19, Keluarga Beb...
# 17  [[SALAH] Karena Pandemi COVID-19, yang Seharus...
# 18  [[SALAH] Bioskop di Palangka Raya Kembali Buka...
# 19  [[SALAH] Hanya di Indonesia Narapidana Dibebas...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/29/salah-sheik...
# 16  https://turnbackhoax.id/2020/04/28/salah-akiba...
# 17  https://turnbackhoax.id/2020/04/27/salah-karen...
# 18  https://turnbackhoax.id/2020/04/27/salah-biosk...
# 19  https://turnbackhoax.id/2020/04/26/salah-hanya...

# %%
# Mengganti nama kolom pada DataFrame "df14"
df14.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df14.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] ”Seorang Pasien Dalam Pengawasan Covi...
# 1  [[SALAH] Pesan Berantai “Taman Raya Tahap V Zo...
# 2  [[SALAH] Kuota 100GB Gratis dari Pemerintah Se...
# 3  [[SALAH] “Ternyata Klaster penyebar Covid-19 t...
# 4  [[SALAH] Seorang Kakek di Tulungagung Meningga...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/05/11/salah-seora...
# 1  https://turnbackhoax.id/2020/05/11/salah-pesan...
# 2  https://turnbackhoax.id/2020/05/10/salah-kuota...
# 3  https://turnbackhoax.id/2020/05/10/salah-terny...
# 4  https://turnbackhoax.id/2020/05/07/salah-seora...

# %% [markdown]
# ### Halaman 15

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/15/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df15 = pd.DataFrame(data)
df15.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Kumpulan Mobil di Pool Grab Cinere ka...
# 16  [[SALAH] Erdogan Tak akan Tutup Mesjid di Turk...
# 17  [[SALAH] “Tidak ada sama sekali Ucapan bela su...
# 18  [[SALAH] Menag Izinkan Masjid Gelar Salat Tara...
# 19  [[SALAH] “Modus Menghabisi Ustadz, disuntik co...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/10/salah-kumpu...
# 16  https://turnbackhoax.id/2020/04/09/salah-erdog...
# 17  https://turnbackhoax.id/2020/04/09/salah-tidak...
# 18  https://turnbackhoax.id/2020/04/08/salah-menag...
# 19  https://turnbackhoax.id/2020/04/06/salah-modus...

# %%
# Mengganti nama kolom pada DataFrame "df15"
df15.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df15.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Beberapa Negara Membuang Jenazah Pasi...
# 1  [[SALAH] Peta Sebaran Covid-19 Wilayah Situbondo]
# 2  [[SALAH] Dari Ratusan Ribu Tahanan Tidak Ada S...
# 3  [[SALAH] Alfamart Menyumbangkan 6000 Kupon Unt...
# 4  [[SALAH] Semua Pasien Positif Covid-19 di Pada...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/26/salah-beber...
# 1  https://turnbackhoax.id/2020/04/24/salah-peta-...
# 2  https://turnbackhoax.id/2020/04/22/salah-dari-...
# 3  https://turnbackhoax.id/2020/04/22/salah-alfam...
# 4  https://turnbackhoax.id/2020/04/22/salah-semua...

# %% [markdown]
# ### Halaman 16

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/16/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df16 = pd.DataFrame(data)
df16.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “Kematian disebabkan COVID-19: Dibalu...
# 16  [[SALAH] RS Premier Bintaro di-Lockdown, 19 Te...
# 17  [[SALAH] Tulisan “TO:FRONT PEMBELA ISLAM” di F...
# 18  [[BERITA] Update status WNA yang Meninggal di ...
# 19  [[BERITA] Perkembangan Chloroquine Untuk Obat ...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/24/salah-kemat...
# 16  https://turnbackhoax.id/2020/03/23/salah-rs-pr...
# 17  https://turnbackhoax.id/2020/03/23/salah-tulis...
# 18  https://turnbackhoax.id/2020/03/21/berita-upda...
# 19  https://turnbackhoax.id/2020/03/21/berita-perk...

# %%
# Mengganti nama kolom pada DataFrame "df16"
df16.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df16.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Mantan Manajer RAPP dan Istri Terpapa...
# 1  [[SALAH] Terlibat Pembuatan COVID-19 di China,...
# 2  [[SALAH] Rakyat Italia Buang Duit ke Jalan kar...
# 3  [[SALAH] “jakarta menjadi daerah paling banyak...
# 4  [[RILIS PERS] Launching AyoLawanCOVID19.ID, Ge...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/06/salah-manta...
# 1  https://turnbackhoax.id/2020/04/03/salah-terli...
# 2  https://turnbackhoax.id/2020/04/03/salah-rakya...
# 3  https://turnbackhoax.id/2020/04/03/salah-jakar...
# 4  https://turnbackhoax.id/2020/04/02/rilis-pers-...

# %% [markdown]
# ### Halaman 17

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/17/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df17 = pd.DataFrame(data)
df17.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Arahan Gubernur DKI Terkait Himbauan ...
# 16  [[SALAH] Daniel Radcliffe Positiv Terinfeksi C...
# 17  [[BERITA] Klarifikasi Mentari International Sc...
# 18  [[SALAH] “WHO : Merokok, Salah satu solusi pen...
# 19  [[SALAH] Penjualan Kalender Police News 2022 o...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/12/salah-araha...
# 16  https://turnbackhoax.id/2020/03/12/salah-danie...
# 17  https://turnbackhoax.id/2020/03/09/berita-klar...
# 18  https://turnbackhoax.id/2020/03/08/salah-who-m...
# 19  https://turnbackhoax.id/2021/10/11/salah-penju...

# %%
# Mengganti nama kolom pada DataFrame "df17"
df17.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df17.head()
# Out:
#                                                 Text  \
# 0         [[SALAH] “Ganja Mampu Menangkal Covid-19”]
# 1  [[SALAH] Dosen Kedokteran Gigi UI Meninggal Ka...
# 2  [[SALAH] Foto “1 korban dlm pengawasan Covid-1...
# 3  [[SALAH] “Satu lagi Mentri Kabinet Jokowi Posi...
# 4  [[SALAH] “Chloroquine (Obat Malaria Klorokuin)...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/03/20/salah-ganja...
# 1  https://turnbackhoax.id/2020/03/18/salah-dosen...
# 2  https://turnbackhoax.id/2020/03/18/salah-foto-...
# 3  https://turnbackhoax.id/2020/03/17/salah-satu-...
# 4  https://turnbackhoax.id/2020/03/17/salah-chlor...

# %% [markdown]
# ### Halaman 18

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/18/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df18 = pd.DataFrame(data)
df18.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Poster Ungkapan Duka Cita Oleh PMI DK...
# 16  [[SALAH] Mencuci Hidung Dengan Garam Menghilan...
# 17  [[SALAH] Video “BERITA TERKINI~GARA-GARA INI !...
# 18  [[SALAH] Pernyataan Dr. Ir. Hj. Sri Nurdiati “...
# 19             [[SALAH] “Madagaskar keluar dari WHO”]
#
#                                                     1
# 15  https://turnbackhoax.id/2021/09/10/salah-poste...
# 16  https://turnbackhoax.id/2021/09/06/salah-mencu...
# 17  https://turnbackhoax.id/2021/09/05/salah-video...
# 18  https://turnbackhoax.id/2021/08/31/salah-perny...
# 19  https://turnbackhoax.id/2021/08/31/salah-madag...

# %%
# Mengganti nama kolom pada DataFrame "df18"
df18.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df18.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] CDC Amerika Serikat Memperingatkan Ad...
# 1  [[SALAH] Video Jokowi Berjoget dan Kerumunan T...
# 2  [[SALAH] WHO Merencanakan Modifikasi Genetik M...
# 3  [[SALAH] Video “mama Egawati yg lagi dirawat d...
# 4  [[SALAH] Video “Rakyat Menang.. !! Pemerintah ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/10/10/salah-cdc-a...
# 1  https://turnbackhoax.id/2021/10/08/salah-video...
# 2  https://turnbackhoax.id/2021/10/01/salah-who-m...
# 3  https://turnbackhoax.id/2021/09/30/salah-video...
# 4  https://turnbackhoax.id/2021/09/30/salah-video...

# %% [markdown]
# ### Halaman 19

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/19/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df19 = pd.DataFrame(data)
df19.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Hasil Perhitungan Data Orang yang Sud...
# 16  [[SALAH] Presiden, Menteri Agama, dan TV Nasio...
# 17  [[SALAH] Bantuan Rp500 Ribu dari Kementerian S...
# 18  [[SALAH] Lowongan Kerja Crew Runner PON Papua ...
# 19  [[SALAH] Virus Corona Katanya Ganas dan Memati...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/08/14/salah-hasil...
# 16  https://turnbackhoax.id/2021/08/14/salah-presi...
# 17  https://turnbackhoax.id/2021/08/11/salah-bantu...
# 18  https://turnbackhoax.id/2021/08/11/salah-lowon...
# 19  https://turnbackhoax.id/2021/08/10/salah-virus...

# %%
# Mengganti nama kolom pada DataFrame "df19"
df19.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df19.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] “WAPRES: VAKSIN MERUPAKAN PERINTAH AG...
# 1       [[SALAH] Video Kota Prabumulih tanpa Korona]
# 2  [[SALAH] Vaksin Corona Mengandung Babi, Dapat ...
# 3  [[SALAH] Foto Poster Pengumuman Nikah Gratis d...
# 4  [[SALAH] Bendera Merah Putih Dilarang Berkibar...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/08/29/salah-wapre...
# 1  https://turnbackhoax.id/2021/08/27/salah-video...
# 2  https://turnbackhoax.id/2021/08/27/salah-vaksi...
# 3  https://turnbackhoax.id/2021/08/27/salah-foto-...
# 4  https://turnbackhoax.id/2021/08/25/salah-bende...

# %% [markdown]
# ### Halaman 20

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/20/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df20 = pd.DataFrame(data)
df20.tail()
# Out:
#                                                     0  \
# 15        [[SALAH] Vaksin Mengandung Racun Berbahaya]
# 16  [[SALAH] CNN Indonesia Menawarkan Hadiah agar ...
# 17  [[SALAH] Video “Raja Thailand dan istrinya ber...
# 18  [[SALAH] Ketentuan Baru, Mau Buat KTP Harus Pu...
# 19                [[SALAH] Habib Rizieq Lumpuh Total]
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/26/salah-vaksi...
# 16  https://turnbackhoax.id/2021/07/25/salah-cnn-i...
# 17  https://turnbackhoax.id/2021/07/23/salah-video...
# 18  https://turnbackhoax.id/2021/07/23/salah-keten...
# 19  https://turnbackhoax.id/2021/07/23/salah-habib...

# %%
# Mengganti nama kolom pada DataFrame "df20"
df20.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df20.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Seluruh Objek Wisata di Kabupaten Pan...
# 1  [[SALAH] Vaksin Astrazeneca, Pfizer, dan Moder...
# 2  [[SALAH] Tautan Pendaftaran Bantuan Sosial Seb...
# 3  [[SALAH] “Vaksin Corona Tidak Terbukti Aman da...
# 4  [[SALAH] Akun Instagram PT Wijaya Karya Indust...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/08/09/salah-selur...
# 1  https://turnbackhoax.id/2021/08/09/salah-vaksi...
# 2  https://turnbackhoax.id/2021/08/07/salah-tauta...
# 3  https://turnbackhoax.id/2021/08/07/salah-vaksi...
# 4  https://turnbackhoax.id/2021/08/02/salah-akun-...

# %% [markdown]
# ### Halaman 21

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/21/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df21 = pd.DataFrame(data)
df21.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Video Rombongan WNA di Bandara Soekar...
# 16  [[SALAH] Foto Akting Plandemi Kantong Mayat Pa...
# 17  [[SALAH] Berkumur dengan Air Garam dan Meminum...
# 18  [[SALAH] Video “Mereka menguburkan Peti Mati y...
# 19  [[SALAH] Cuci Hidung dengan NaCl 0,9% dapat Me...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/16/salah-video...
# 16  https://turnbackhoax.id/2021/07/15/salah-foto-...
# 17  https://turnbackhoax.id/2021/07/15/salah-berku...
# 18  https://turnbackhoax.id/2021/07/15/salah-video...
# 19  https://turnbackhoax.id/2021/07/14/salah-cuci-...

# %%
# Mengganti nama kolom pada DataFrame "df21"
df21.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df21.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Mata Pengemudi ditusuk hingga Buta ol...
# 1  [[SALAH] “AKHIRNYA!! DUNIA SETUJUI VAKSIN NUSA...
# 2  [[SALAH] Campuran Lemon dan Soda Kue Dapat Mem...
# 3  [[SALAH] “Pemerintah Resmi Izinkan Sholat Idul...
# 4  [[SALAH] Video Kondisi Gibran “BERITA TERBARU ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/22/salah-mata-...
# 1  https://turnbackhoax.id/2021/07/22/salah-akhir...
# 2  https://turnbackhoax.id/2021/07/22/salah-campu...
# 3  https://turnbackhoax.id/2021/07/22/salah-pemer...
# 4  https://turnbackhoax.id/2021/07/21/salah-video...

# %% [markdown]
# ### Halaman 22

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/22/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df22 = pd.DataFrame(data)
df22.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “sekarang angkut mayat gak lg pake Am...
# 16  [[SALAH] Video “Dibilang Corona Setelah Peti D...
# 17  [[SALAH] Gambar “Seruan Siaga 1 Majelis Ulama ...
# 18  [[SALAH] “ke masjid tidak perlu memakai masker...
# 19  [[SALAH] Video “Sri Mulyani suntik vaksin utk ...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/07/02/salah-sekar...
# 16  https://turnbackhoax.id/2021/07/01/salah-video...
# 17  https://turnbackhoax.id/2021/07/01/salah-gamba...
# 18  https://turnbackhoax.id/2021/06/29/salah-ke-ma...
# 19  https://turnbackhoax.id/2021/06/29/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df22"
df22.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df22.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Video “Mesjid ditutup sementara, KATE...
# 1  [[SALAH] Relawan Siaga Meluncurkan Program Pen...
# 2  [[SALAH] SPBU Tutup Sementara dari 12 sampai 1...
# 3  [[SALAH] Air Rebusan Bawang Putih Dapat Menyem...
# 4  [[SALAH] “Gubernur Sumut Instruksikan Seluruh ...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/07/13/salah-video...
# 1  https://turnbackhoax.id/2021/07/12/salah-relaw...
# 2  https://turnbackhoax.id/2021/07/11/salah-spbu-...
# 3  https://turnbackhoax.id/2021/07/10/salah-air-r...
# 4  https://turnbackhoax.id/2021/07/09/salah-guber...

# %% [markdown]
# ### Halaman 23

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/23/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df23 = pd.DataFrame(data)
df23.tail()
# Out:
#                                                     0  \
# 15         [[SALAH] Video “MALAYSIA MENYEDIHKAN LUR”]
# 16  [[SALAH] Foto Polisi India dengan Poster Tulis...
# 17      [[SALAH] Suntikan Vaksin Kosong di Indonesia]
# 18  [[SALAH] Akun Facebook Bupati Mojokerto Menawa...
# 19  [[SALAH] Tangkapan Layar “hati2,,, rakyat akan...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/06/06/salah-video...
# 16  https://turnbackhoax.id/2021/05/31/salah-foto-...
# 17  https://turnbackhoax.id/2021/05/31/salah-sunti...
# 18  https://turnbackhoax.id/2021/05/29/salah-akun-...
# 19  https://turnbackhoax.id/2021/05/29/salah-tangk...

# %%
# Mengganti nama kolom pada DataFrame "df23"
df23.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df23.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Meminum Minuman Panas dan Menghirup U...
# 1  [[SALAH] Anies Baswedan Hanya Mengurusi Asbak ...
# 2  [[SALAH] Konsumsi Nigella Oil Menghilangkan Pe...
# 3  [[SALAH] Pesan Berantai “SANDIWARA CORONA” dar...
# 4  [[SALAH] “##BERAKHIR PAHIT##. SK GUBERNUR DI C...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/06/27/salah-memin...
# 1  https://turnbackhoax.id/2021/06/27/salah-anies...
# 2  https://turnbackhoax.id/2021/06/24/salah-konsu...
# 3  https://turnbackhoax.id/2021/06/23/salah-pesan...
# 4  https://turnbackhoax.id/2021/06/22/salah-berak...

# %% [markdown]
# ### Halaman 24

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/24/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df24 = pd.DataFrame(data)
df24.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Akun Whatsapp ”0812-3360-5930” Wakil ...
# 16  [[SALAH] Sebuah Peralatan Telekomunikasi Bertu...
# 17  [[SALAH] Foto Syuting Film Horor agar Masyarak...
# 18  [[SALAH] Tangkapan layar KOMPAS.com “Eksclusiv...
# 19  [[SALAH] Video “ini terjadi di India, varian b...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/04/30/salah-akun-...
# 16  https://turnbackhoax.id/2021/04/29/salah-sebua...
# 17  https://turnbackhoax.id/2021/04/29/salah-foto-...
# 18  https://turnbackhoax.id/2021/04/28/salah-tangk...
# 19  https://turnbackhoax.id/2021/04/24/salah-video...

# %%
# Mengganti nama kolom pada DataFrame "df24"
df24.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df24.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Setelah Divaksin, Tubuh Punya Daya Ma...
# 1  [[SALAH] Polisi Membubarkan Massa Aksi Bela Pa...
# 2  [[SALAH] Berada Di Sekitar Orang yang Baru Div...
# 3  [[SALAH] Video “Warga Malaysia antri nginep di...
# 4     [[SALAH] Obat dan Bahan Herbal Mencegah Covid]
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/05/27/salah-setel...
# 1  https://turnbackhoax.id/2021/05/25/salah-polis...
# 2  https://turnbackhoax.id/2021/05/23/salah-berad...
# 3  https://turnbackhoax.id/2021/05/20/salah-video...
# 4  https://turnbackhoax.id/2021/05/20/salah-obat-...

# %% [markdown]
# ### Halaman 25

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/25/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df25 = pd.DataFrame(data)
df25.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Artikel berjudul “China Tidak Bisa Be...
# 16  [[SALAH] Video “Lebih banyak mayat bertumpuk a...
# 17  [[SALAH] Presiden Boleh Hadiri Pesta Artis, Se...
# 18              [[SALAH] Jadwal Penerimaan IPDN 2021]
# 19  [[SALAH] Denda Mudik Rp100 Juta Pada 6-7 Mei 2...
#
#                                                     1
# 15  https://turnbackhoax.id/2021/04/07/salah-artik...
# 16  https://turnbackhoax.id/2021/04/06/salah-video...
# 17  https://turnbackhoax.id/2021/04/06/salah-presi...
# 18  https://turnbackhoax.id/2021/04/06/salah-jadwa...
# 19  https://turnbackhoax.id/2021/03/31/salah-denda...

# %%
# Mengganti nama kolom pada DataFrame "df25"
df25.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df25.head()
# Out:
#                                                 Text  \
# 0        [[SALAH] Gambar Anis Menunjukkan Lem Aibon]
# 1  [[SALAH]  Foto Seorang Anak Memberikan Masker ...
# 2  [[SALAH] Video “salah satu pejabat pemerintah ...
# 3  [[SALAH] Kenaikan Limfosit Usai Vaksin, Sebabk...
# 4  [[SALAH] Video Seorang Kakek Ditahan Karena Ti...
#
#                                                  URL
# 0  https://turnbackhoax.id/2021/04/24/salah-gamba...
# 1  https://turnbackhoax.id/2021/04/23/salah-foto-...
# 2  https://turnbackhoax.id/2021/04/21/salah-video...
# 3  https://turnbackhoax.id/2021/04/21/salah-kenai...
# 4  https://turnbackhoax.id/2021/04/19/salah-video...

# %% [markdown]
# ### Halaman 26

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/26/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df26 = pd.DataFrame(data)
df26.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Kompensasi Biaya #dirumahaja sebesar ...
# 1  [[SALAH] Khawatir Tim Medis Lupa Jenis Vaksin ...
# 2  [[SALAH] Ekstrak Nanas Bisa Dijadikan Obat Vir...
# 3  [[SALAH] Nama AstraZeneca Memiliki Arti ‘Senja...
# 4  [[SALAH] Vaksin Berbasis mRna, Dapat Menyebabk...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/31/salah-kompe...
# 1  https://turnbackhoax.id/2021/03/30/salah-khawa...
# 2  https://turnbackhoax.id/2021/03/29/salah-ekstr...
# 3  https://turnbackhoax.id/2021/03/29/salah-nama-...
# 4  https://turnbackhoax.id/2021/03/25/salah-vaksi...

# %%
# Mengganti nama kolom pada DataFrame "df26"
df26.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df26.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Video “Presiden Jokowi Ingatkan OJK/S...
# 16  [[SALAH] Akun Facebook Wali Kota Kendari Menga...
# 17  [[SALAH] “Vaksin Sinovac, Vaksin yg sebenarnya...
# 18  [[SALAH] Vaksin Sinovac berisikan Virus Hidup ...
# 19      [[SALAH] Video “Vaksinasi di.mall T.Anggrek”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/03/15/salah-video...
# 16  https://turnbackhoax.id/2021/03/13/salah-akun-...
# 17  https://turnbackhoax.id/2021/03/13/salah-vaksi...
# 18  https://turnbackhoax.id/2021/03/11/salah-vaksi...
# 19  https://turnbackhoax.id/2021/03/11/salah-video...

# %% [markdown]
# ### Halaman 27

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/27/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df27 = pd.DataFrame(data)
df27.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Vaksin Moderna Dirancang untuk Mengub...
# 1  [[SALAH] Vaksinasi di PPSDMK Cukup Bawa KTP Se...
# 2  [[SALAH] Masa Lockdown di Kanada Berakhir Seja...
# 3  [[SALAH] “Anosmia Bukan Gejala khas Virus, Min...
# 4  [[SALAH] “Jual Minuman Keras Hukumnya Boleh un...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/03/07/salah-vaksi...
# 1  https://turnbackhoax.id/2021/03/03/salah-vaksi...
# 2  https://turnbackhoax.id/2021/03/03/salah-masa-...
# 3  https://turnbackhoax.id/2021/03/01/salah-anosm...
# 4  https://turnbackhoax.id/2021/03/01/salah-jual-...

# %%
# Mengganti nama kolom pada DataFrame "df27"
df27.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df27.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Yang bikin banyak positif bukan acar...
# 16  [[SALAH] “SETAHUN Koma di Rumah Sakit, Begitu ...
# 17  [[SALAH] Menyamar Dengan Baju Nakes, Tentara C...
# 18  [[SALAH] Terseret Korupsi Dana Formula E, Anie...
# 19     [[SALAH] “Setelah difucksin, otak jadi Lelet”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/02/12/salah-yang-...
# 16  https://turnbackhoax.id/2021/02/09/salah-setah...
# 17  https://turnbackhoax.id/2021/02/08/salah-menya...
# 18  https://turnbackhoax.id/2021/02/08/salah-terse...
# 19  https://turnbackhoax.id/2021/02/07/salah-setel...

# %% [markdown]
# ### Halaman 28

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/28/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df28 = pd.DataFrame(data)
df28.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Imbauan Penutupan Pasar dan Tempat Wi...
# 1  [[SALAH] Penjualan GeNose C19 Seharga 75 Juta ...
# 2  [[SALAH] “PSBB jawa & Bali di perpanjang sampa...
# 3       [[SALAH] “Semua Fraksi Sepakat Copot Anies”]
# 4  [[SALAH] “Satu2nya negara yg tidak ada COVID19...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/02/07/salah-imbau...
# 1  https://turnbackhoax.id/2021/02/06/salah-penju...
# 2  https://turnbackhoax.id/2021/02/06/salah-psbb-...
# 3  https://turnbackhoax.id/2021/02/05/salah-semua...
# 4  https://turnbackhoax.id/2021/02/03/salah-satu2...

# %%
# Mengganti nama kolom pada DataFrame "df28"
df28.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df28.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Karena Disuntik Vaksin, Dokter di Pal...
# 16        [[SALAH] “Olimpiade Tokyo 2021 DIBATALKAN”]
# 17  [[SALAH] “Kesan Abdul Somad Saat Divaksin: Nda...
# 18       [[SALAH] Foto “anak korban vaksinasi covid”]
# 19  [[SALAH] Indonesia Tidak Dapat Menggugat Jika ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/25/salah-karen...
# 16  https://turnbackhoax.id/2021/01/25/salah-olimp...
# 17  https://turnbackhoax.id/2021/01/24/salah-kesan...
# 18  https://turnbackhoax.id/2021/01/24/salah-foto-...
# 19  https://turnbackhoax.id/2021/01/23/salah-indon...

# %% [markdown]
# ### Halaman 29

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/29/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df29 = pd.DataFrame(data)
df29.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Surat Perintah Karantina Selama Dua M...
# 1  [[SALAH] “Ada 32 hotel di Jakarta untuk ISOLAS...
# 2  [[SALAH] Ketua BPOM Ditekan dan Diancam Untuk ...
# 3  [[SALAH] Foto Pemerintahan Biden Mengibarkan B...
# 4  [[SALAH] “VAKSINASI PRESIDEN HARUS DIULANG DAN...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/23/salah-surat...
# 1  https://turnbackhoax.id/2021/01/23/salah-ada-3...
# 2  https://turnbackhoax.id/2021/01/23/salah-ketua...
# 3  https://turnbackhoax.id/2021/01/22/salah-foto-...
# 4  https://turnbackhoax.id/2021/01/22/salah-vaksi...

# %%
# Mengganti nama kolom pada DataFrame "df29"
df29.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df29.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Berita Terbaru Hari Ini ~ 48 Orang T...
# 16  [[SALAH] Surat Elektronik Rekrutmen Karyawan P...
# 17  [[SALAH] “Kronologi Syekh Ali Jabar Wafat 2 ja...
# 18  [[SALAH] “Ketua Fraksi PDIP saja ga mau di vak...
# 19                       [[SALAH] Jakarta Zona Hitam]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/16/salah-berit...
# 16  https://turnbackhoax.id/2021/01/16/salah-surat...
# 17  https://turnbackhoax.id/2021/01/16/salah-krono...
# 18  https://turnbackhoax.id/2021/01/16/salah-ketua...
# 19  https://turnbackhoax.id/2021/01/16/salah-jakar...

# %% [markdown]
# ### Halaman 30

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/30/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df30 = pd.DataFrame(data)
df30.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Terapi Uap Panas dan Minyak Kayu Puti...
# 1  [[SALAH] Razia Anak Tidak Bermasker Akan Dikar...
# 2  [[SALAH] Jokowi Kejang dan Meninggal Dunia set...
# 3   [[SALAH] Jokowi Menggunakan Vaksin Buatan Eropa]
# 4  [[SALAH] “Rakyat Aceh menolak vaksin covid19 k...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/15/salah-terap...
# 1  https://turnbackhoax.id/2021/01/15/salah-razia...
# 2  https://turnbackhoax.id/2021/01/15/salah-jokow...
# 3  https://turnbackhoax.id/2021/01/14/salah-jokow...
# 4  https://turnbackhoax.id/2021/01/14/salah-rakya...

# %%
# Mengganti nama kolom pada DataFrame "df30"
df30.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df30.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Penerima Vaksin Perdana Meninggal Dun...
# 16  [[SALAH] Jawa-Bali Lockdown pada Tanggal 11-25...
# 17  [[SALAH] “Ternyata VAKSIN Yg Akan Di Suntikan ...
# 18  [[SALAH] “Inalilahi wainailaihi rojiun Telah m...
# 19       [[SALAH] Pesan Berantai “Wisma Atlet penuh”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2021/01/09/salah-pener...
# 16  https://turnbackhoax.id/2021/01/09/salah-jawa-...
# 17  https://turnbackhoax.id/2021/01/09/salah-terny...
# 18  https://turnbackhoax.id/2021/01/08/salah-inali...
# 19  https://turnbackhoax.id/2021/01/08/salah-pesan...

# %% [markdown]
# ### Halaman 31

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/31/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df31 = pd.DataFrame(data)
df31.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “vaksin Sinovac disebutkan memberi ef...
# 1  [[SALAH] “Fabiana Souza, penerima perdana sunt...
# 2  [[SALAH] Vaksin Bermasalah dan Mengerikan, Dis...
# 3  [[SALAH] Masjid Istiqlal Tidak Mengadakan Sala...
# 4  [[SALAH] “Raja Thailand panggil ulama Islam ba...
#
#                                                    1
# 0  https://turnbackhoax.id/2021/01/08/salah-vaksi...
# 1  https://turnbackhoax.id/2021/01/07/salah-fabia...
# 2  https://turnbackhoax.id/2021/01/06/salah-vaksi...
# 3  https://turnbackhoax.id/2021/01/06/salah-masji...
# 4  https://turnbackhoax.id/2021/01/05/salah-raja-...

# %%
# Mengganti nama kolom pada DataFrame "df31"
df31.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df31.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “GELOMBANG KE-3 Kuota Internet Free d...
# 16  [[SALAH]: Link Untuk Mengecek Daftar KK Peneri...
# 17  [[SALAH] Larangan Mengikuti Natal di Kabupaten...
# 18  [[SALAH] Gubernur Riau dikabarkan dilarikan ke...
# 19  [[SALAH] Corona Varian Baru Tidak Terdeteksi PCR]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/12/29/salah-gelom...
# 16  https://turnbackhoax.id/2020/12/28/salah-link-...
# 17  https://turnbackhoax.id/2020/12/28/salah-laran...
# 18  https://turnbackhoax.id/2020/12/28/salah-guber...
# 19  https://turnbackhoax.id/2020/12/26/salah-coron...

# %% [markdown]
# ### Halaman 32

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/32/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df32 = pd.DataFrame(data)
df32.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Belajar Tatap Muka RESMI Januari 202...
# 1       [[SALAH] Orang yang Shalat Aman dari Corona]
# 2  [[SALAH] “Rumah Sakit Di Lockdown Karena Pasie...
# 3  [[SALAH] Purworejo Lockdown Mulai Tanggal 24 D...
# 4  [[SALAH] “Syarat Vaksin Gratis Jokowi: BPJS Ke...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/25/salah-belaj...
# 1  https://turnbackhoax.id/2020/12/25/salah-orang...
# 2  https://turnbackhoax.id/2020/12/25/salah-rumah...
# 3  https://turnbackhoax.id/2020/12/24/salah-purwo...
# 4  https://turnbackhoax.id/2020/12/23/salah-syara...

# %%
# Mengganti nama kolom pada DataFrame "df32"
df32.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df32.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Klaster Supermarket Sendy’s, 28 Pegaw...
# 16  [[SALAH] “IDI tolak yg Pertama dpt Vaksin Sino...
# 17  [[SALAH] 44 Orang Tenaga Kesehatan Positif Cov...
# 18               [[SALAH] Foto Keluarga CEO BioNTech]
# 19  [[SALAH] “Himbauan Bpk Kapolresta Malang Siapa...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/12/17/salah-klast...
# 16  https://turnbackhoax.id/2020/12/15/salah-idi-t...
# 17  https://turnbackhoax.id/2020/12/15/salah-44-or...
# 18  https://turnbackhoax.id/2020/12/15/salah-foto-...
# 19  https://turnbackhoax.id/2020/12/14/salah-himba...

# %% [markdown]
# ### Halaman 33

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/33/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df33 = pd.DataFrame(data)
df33.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Surat Perintah Penyidikan KPK Terhada...
# 1  [[SALAH] Sidak Masker di Wilayah Kabupaten Jep...
# 2  [[SALAH] Link Untuk Mendapatkan 35 GB Kuota Gr...
# 3  [[SALAH] Pesan WhatsApp Soal Razia Keliling Se...
# 4  [[SALAH] “Baru sehari mentrinya jd TSK bantuan...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/12/11/salah-surat...
# 1  https://turnbackhoax.id/2020/12/10/salah-sidak...
# 2  https://turnbackhoax.id/2020/12/09/salah-link-...
# 3  https://turnbackhoax.id/2020/12/07/salah-pesan...
# 4  https://turnbackhoax.id/2020/12/07/salah-baru-...

# %%
# Mengganti nama kolom pada DataFrame "df33"
df33.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df33.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Video Biden Merayakan Ulang Tahun Tan...
# 16  [[SALAH] Corona Adalah Kedok dari Penyakit Rad...
# 17  [[SALAH] Presentase Bunuh Diri Naik 200% Selam...
# 18  [[SALAH] Perdana Menteri Tiongkok Mengultimatu...
# 19  [[SALAH] Formulir Online untuk Banpres Produkt...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/11/24/salah-video...
# 16  https://turnbackhoax.id/2020/11/23/salah-coron...
# 17  https://turnbackhoax.id/2020/11/21/salah-prese...
# 18  https://turnbackhoax.id/2020/11/17/salah-perda...
# 19  https://turnbackhoax.id/2020/11/10/salah-formu...

# %% [markdown]
# ### Halaman 34

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/34/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df34 = pd.DataFrame(data)
df34.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Jenazah pasien yang ‘katanya’ kena k...
# 1  [[SALAH] Pesan Berantai ‘India Is Doing It’ Bi...
# 2  [[SALAH] BPOM Halangi Vaksin yang akan Diberikan]
# 3         [[SALAH] Voucher Undian Alfamart 21 Tahun]
# 4           [[SALAH] Presiden Jokowi Menjadi Dokter]
#
#                                                    1
# 0  https://turnbackhoax.id/2020/11/09/salah-jenaz...
# 1  https://turnbackhoax.id/2020/11/05/salah-pesan...
# 2  https://turnbackhoax.id/2020/11/03/salah-bpom-...
# 3  https://turnbackhoax.id/2020/10/29/salah-vouch...
# 4  https://turnbackhoax.id/2020/10/28/salah-presi...

# %%
# Mengganti nama kolom pada DataFrame "df34"
df34.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df34.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Info valid dari org dlm Istana: LBP ...
# 16  [[SALAH] “Cie ga pake masker cie berdekatan ci...
# 17  [[SALAH] “Corona itu adanya di China bukan di ...
# 18  [[SALAH] “BERSEPEDA PAKAI MASKER, MAKAN KORBAN...
# 19  [[SALAH] Surat Edaran MUI tentang Rapid Test b...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/10/09/salah-info-...
# 16  https://turnbackhoax.id/2020/10/08/salah-cie-g...
# 17  https://turnbackhoax.id/2020/10/07/salah-coron...
# 18  https://turnbackhoax.id/2020/10/06/salah-berse...
# 19  https://turnbackhoax.id/2020/10/04/salah-surat...

# %% [markdown]
# ### Halaman 35

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/35/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df35 = pd.DataFrame(data)
df35.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Tim Kampanye Donald Trump Galang Dana...
# 1  [[SALAH] “Positif Corona, Kondisi Donald Trump...
# 2  [[SALAH] “Emil Saat Diambil Darah untuk Uji Va...
# 3  [[SALAH] “Peneliti, analis laboratorium, tidak...
# 4  [[SALAH] Arahan Kapolres Simalungun Meniadakan...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/10/04/salah-tim-k...
# 1  https://turnbackhoax.id/2020/10/04/salah-posit...
# 2  https://turnbackhoax.id/2020/10/03/salah-emil-...
# 3  https://turnbackhoax.id/2020/10/02/salah-penel...
# 4  https://turnbackhoax.id/2020/10/02/salah-araha...

# %%
# Mengganti nama kolom pada DataFrame "df35"
df35.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df35.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Breaking News! Pilkada Serentak Ditu...
# 16  [[SALAH] SPK Tender Pengadaan Barang di Masa P...
# 17  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 18  [[SALAH] Pelarangan Masker Scuba Politik Perus...
# 19  [[SALAH] Pernyataan Teddy Gusnaidi Sebut Anies...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/09/23/salah-break...
# 16  https://turnbackhoax.id/2020/09/23/salah-spk-t...
# 17  https://turnbackhoax.id/2020/09/22/top-5-topik...
# 18  https://turnbackhoax.id/2020/09/20/salah-pelar...
# 19  https://turnbackhoax.id/2020/09/19/salah-perny...

# %% [markdown]
# ### Halaman 36

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/36/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df36 = pd.DataFrame(data)
df36.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Ketika di vaksin, microchip yg sanga...
# 1  [[SALAH] “Ini ada ratusan nyawa dokter yang su...
# 2  [[SALAH] “Jokowi: Tidak Perlu Dibesar besarkan...
# 3  [[SALAH] Foto “Akhirnya Syekh Ali Jabber terba...
# 4  [[SALAH] Selama Covid19 Ada, Tidak ada Orang G...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/19/salah-ketik...
# 1  https://turnbackhoax.id/2020/09/17/salah-ini-a...
# 2  https://turnbackhoax.id/2020/09/17/salah-jokow...
# 3  https://turnbackhoax.id/2020/09/17/salah-foto-...
# 4  https://turnbackhoax.id/2020/09/15/salah-selam...

# %%
# Mengganti nama kolom pada DataFrame "df36"
df36.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df36.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Campuran Air Kelapa Muda, Jeruk Nipis...
# 16  [[SALAH] Pesan Singkat Rektor Unsoed soal Dana...
# 17  [[SALAH] “Cilandak Barat, Jakarta Selatan suda...
# 18  [[SALAH] Pesan WhatsApp Soal Razia Keliling di...
# 19  [[SALAH] Perdana Menteri Jepang Mundur Karena ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/09/04/salah-campu...
# 16  https://turnbackhoax.id/2020/09/04/salah-pesan...
# 17  https://turnbackhoax.id/2020/09/04/salah-cilan...
# 18  https://turnbackhoax.id/2020/09/04/salah-pesan...
# 19  https://turnbackhoax.id/2020/09/02/salah-perda...

# %% [markdown]
# ### Halaman 37

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/37/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df37 = pd.DataFrame(data)
df37.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Gara-gara HTI Pertamina Rugi 11 Tril...
# 1  [[SALAH] “Ketika rakyat muak dan jijik, tak ad...
# 2             [[SALAH] Vaksin Covid Sebabkan Mandul]
# 3  [[SALAH] Hukuman Masuk Peti Mati Karena Tidak ...
# 4  [[SALAH] Putri Vladimir Putin Meninggal Setela...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/09/01/salah-gara-...
# 1  https://turnbackhoax.id/2020/09/01/salah-ketik...
# 2  https://turnbackhoax.id/2020/08/30/salah-vaksi...
# 3  https://turnbackhoax.id/2020/08/29/salah-hukum...
# 4  https://turnbackhoax.id/2020/08/20/salah-putri...

# %%
# Mengganti nama kolom pada DataFrame "df37"
df37.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df37.tail()
# Out:
#                                                  Text  \
# 15                    [[SALAH] “Corona adalah hoaks”]
# 16  [[SALAH] Surat Edaran Penolakan Rapid Test Maj...
# 17    [[SALAH] Video Animasi Penyebaran Virus Corona]
# 18  [[SALAH] “Lampu bendera Lebanon dinyalakan di ...
# 19  [[ACARA] Campaign “Jaga Jogja” MAFINDO Yogyaka...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/11/salah-coron...
# 16  https://turnbackhoax.id/2020/08/11/salah-surat...
# 17  https://turnbackhoax.id/2020/08/11/salah-video...
# 18  https://turnbackhoax.id/2020/08/11/salah-lampu...
# 19  https://turnbackhoax.id/2020/08/10/acara-campa...

# %% [markdown]
# ### Halaman 38

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/38/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df38 = pd.DataFrame(data)
df38.head()
# Out:
#                                                    0  \
# 0  [[BERITA] Sempat Sebut Hoaks, Pasar Jaya Akui ...
# 1  [[BERITA] Metro TV: “Mafindo: Perlu Ada Kode E...
# 2          [[SALAH] STAN Ditutup Karena Radikalisme]
# 3  [[SALAH] Seluruh Karyawan Pabrik ESEMKA Terken...
# 4  [[SALAH] Foto “1 Agustus 2020, jutaan warga Je...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/08/09/berita-semp...
# 1  https://turnbackhoax.id/2020/08/09/berita-metr...
# 2  https://turnbackhoax.id/2020/08/07/salah-stan-...
# 3  https://turnbackhoax.id/2020/08/07/salah-selur...
# 4  https://turnbackhoax.id/2020/08/07/salah-foto-...

# %%
# Mengganti nama kolom pada DataFrame "df38"
df38.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df38.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Nih yang bikin Covid, si jagoan Wall...
# 16  [[SALAH] China Lakukan Uji Coba Vaksin di Indo...
# 17  [[SALAH] Foto “Penipuan para medis, termasuk a...
# 18  [[SALAH] Jokowi dikabarkan Siap Pindah jadi Wa...
# 19  [[SALAH] Foto Tenaga Medis Merangkai Kata ‘BAC...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/08/01/salah-nih-y...
# 16  https://turnbackhoax.id/2020/07/30/salah-china...
# 17  https://turnbackhoax.id/2020/07/30/salah-foto-...
# 18  https://turnbackhoax.id/2020/07/29/salah-jokow...
# 19  https://turnbackhoax.id/2020/07/29/salah-foto-...

# %% [markdown]
# ### Halaman 39

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/39/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df39 = pd.DataFrame(data)
df39.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “KASAD klarifikasi, anggota TNI di ba...
# 1  [[SALAH] “Kapal Kargo Pengangkut Kadrun tengge...
# 2  [[SALAH] Awas Hati-hati Apa Yang Disemprotkan ...
# 3  [[SALAH] “mayat positif covid 19 dikuburkan ma...
# 4  [[SALAH] Inventaris Pesawat Terbang Untuk Para...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/07/28/salah-kasad...
# 1  https://turnbackhoax.id/2020/07/28/salah-kapal...
# 2  https://turnbackhoax.id/2020/07/28/salah-awas-...
# 3  https://turnbackhoax.id/2020/07/28/salah-mayat...
# 4  https://turnbackhoax.id/2020/07/28/salah-inven...

# %%
# Mengganti nama kolom pada DataFrame "df39"
df39.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df39.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Aturan Baru Pemprov DKI, Pemotongan T...
# 16  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 17  [[SALAH] “DAHSYATNYA FITNAH CORONA, ketakutan ...
# 18     [[SALAH] Pesan Berantai Adidas Berikan Masker]
# 19  [[SALAH] Instruksi Gubernur DKI Jakarta Penila...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/07/22/salah-atura...
# 16  https://turnbackhoax.id/2020/07/21/top-5-topik...
# 17  https://turnbackhoax.id/2020/07/20/salah-dahsy...
# 18  https://turnbackhoax.id/2020/07/19/salah-pesan...
# 19  https://turnbackhoax.id/2020/07/18/salah-instr...

# %% [markdown]
# ### Halaman 40

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/40/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df40 = pd.DataFrame(data)
df40.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Instruksi Gubernur Jateng tentang pe...
# 1  [[SALAH] Video “Didemo rakyat, KETUA WAKIL RAK...
# 2  [[SALAH] Risma Sujud ke IDI Karena Warga Surab...
# 3  [[SALAH] Xi Jinping Berterimakasih Karena Terp...
# 4  [[SALAH] “Dirut RSUI bersama 2 Direktur RSUI l...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/07/17/salah-instr...
# 1  https://turnbackhoax.id/2020/07/11/salah-video...
# 2  https://turnbackhoax.id/2020/07/10/salah-risma...
# 3  https://turnbackhoax.id/2020/07/10/salah-xi-ji...
# 4  https://turnbackhoax.id/2020/07/08/salah-dirut...

# %%
# Mengganti nama kolom pada DataFrame "df40"
df40.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df40.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Tanggal 2-24 Juli Ada Pelayanan Akta ...
# 16  [[SALAH] Workshop Peningkatan Kapasitas Pemeri...
# 17  [[SALAH] “Aliran Komunis & Gerakan PKI Bangkit...
# 18  [[SALAH] Rektor IAIN Surakarta Umumkan Penerim...
# 19  [[SALAH] “MA’RUF AMIN NGAKU KALO GROMBOLAN MER...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/07/01/salah-tangg...
# 16  https://turnbackhoax.id/2020/06/27/salah-works...
# 17  https://turnbackhoax.id/2020/06/26/salah-alira...
# 18  https://turnbackhoax.id/2020/06/26/salah-rekto...
# 19  https://turnbackhoax.id/2020/06/25/salah-maruf...

# %% [markdown]
# ### Halaman 41

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/41/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df41 = pd.DataFrame(data)
df41.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Ruang Perawatan Covid di Riau Penuh, ...
# 1  [[SALAH] Peta Kasus Covid DKI “DKI kembali Zon...
# 2  [[SALAH] “New Fatwa ‘Sholat Tanpa Wudhu Tanpa ...
# 3  [[SALAH] Denda Rp250 Ribu Saat Razia Masker Ta...
# 4  [[SALAH] “Menurut laporan WHO, Corona Virus ad...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/06/25/salah-ruang...
# 1  https://turnbackhoax.id/2020/06/24/salah-peta-...
# 2  https://turnbackhoax.id/2020/06/23/salah-new-f...
# 3  https://turnbackhoax.id/2020/06/22/salah-denda...
# 4  https://turnbackhoax.id/2020/06/21/salah-menur...

# %%
# Mengganti nama kolom pada DataFrame "df41"
df41.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df41.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Di film kapten amerika, capten steve...
# 16  [[SALAH] Hantu Nge-GYM (Olahraga) di Taman Jha...
# 17  [[SALAH] “fadlizon mendaulat Anies jadi Duta G...
# 18  [[SALAH] Petinju Manny Pacman Bagi-bagi Hadiah...
# 19  [[SALAH] Jokowi Katakan “Kalian setuju kalau s...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/06/15/salah-di-fi...
# 16  https://turnbackhoax.id/2020/06/14/salah-hantu...
# 17  https://turnbackhoax.id/2020/06/14/salah-fadli...
# 18  https://turnbackhoax.id/2020/06/14/salah-petin...
# 19  https://turnbackhoax.id/2020/06/13/salah-jokow...

# %% [markdown]
# ### Halaman 42

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/42/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df42 = pd.DataFrame(data)
df42.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Anies Kembali Izinkan Diskotik dan P...
# 1  [[SALAH] “Keasang pengarep mampu menangani vir...
# 2  [[SALAH] 30 Pembantu Baru Positif Corona di Pe...
# 3  [[SALAH] “Heboh! Pernyataan Dokter Indonesia S...
# 4  [[SALAH] “Pemprov DKI Tunaikan Janji Bansos, N...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/06/11/salah-anies...
# 1  https://turnbackhoax.id/2020/06/11/salah-keasa...
# 2  https://turnbackhoax.id/2020/06/11/salah-30-pe...
# 3  https://turnbackhoax.id/2020/06/10/salah-heboh...
# 4  https://turnbackhoax.id/2020/06/10/salah-pempr...

# %%
# Mengganti nama kolom pada DataFrame "df42"
df42.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df42.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Dari DR. Ir. Hj. Sri Nurdiati, Dekan ...
# 16  [[SALAH] Pembatasan Sosial Jakarta-Bandung Sud...
# 17  [[SALAH] DIY Menjadi Daerah Percontohan Untuk ...
# 18  [[SALAH] Campuran Garam dan Air Hangat Mampu H...
# 19  [[SALAH] “Hari ini 2 kasir Chandra karang diny...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/30/salah-dari-...
# 16  https://turnbackhoax.id/2020/05/29/salah-pemba...
# 17  https://turnbackhoax.id/2020/05/28/salah-diy-m...
# 18  https://turnbackhoax.id/2020/05/28/salah-campu...
# 19  https://turnbackhoax.id/2020/05/27/salah-hari-...

# %% [markdown]
# ### Halaman 43

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/43/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df43 = pd.DataFrame(data)
df43.head()
# Out:
#                                                    0  \
# 0  [[SALAH] “Di Italia, ketika gereja dibuka kemb...
# 1  [[SALAH] Buntut Penerapan PSBB di Palembang, B...
# 2  [[SALAH] “KRN PEMERINTAHNYA NGEYEL & RAKYATNYA...
# 3  [[SALAH] “kadus dihakimi warga sampai babak be...
# 4  [[SALAH] Voucher Dua Pizza Besar Domino’s Pizz...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/27/salah-di-it...
# 1  https://turnbackhoax.id/2020/05/26/salah-buntu...
# 2  https://turnbackhoax.id/2020/05/26/salah-krn-p...
# 3  https://turnbackhoax.id/2020/05/25/salah-kadus...
# 4  https://turnbackhoax.id/2020/05/25/salah-vouch...

# %%
# Mengganti nama kolom pada DataFrame "df43"
df43.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df43.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “majalah Italia tahun 1962 menggambar...
# 16  [[SALAH] Program Mudik Sehat PSBB 2020 Oleh Bi...
# 17  [[SALAH] Video “Masjid/ mushola ditutup tpi kn...
# 18  [[SALAH] Rapid Test Di Bandara Soekarno-Hatta ...
# 19           [[SALAH] Peringatan Badai Panas Equinox]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/19/salah-majal...
# 16  https://turnbackhoax.id/2020/05/19/salah-progr...
# 17  https://turnbackhoax.id/2020/05/19/salah-video...
# 18  https://turnbackhoax.id/2020/05/19/salah-rapid...
# 19  https://turnbackhoax.id/2020/05/19/salah-perin...

# %% [markdown]
# ### Halaman 44

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/44/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df44 = pd.DataFrame(data)
df44.head()
# Out:
#                                                    0  \
# 0  [[FALSE] “1962 Italian magazine described 2022...
# 1  [[SALAH] “Wapres Tidak Masalah Konser Di Bulan...
# 2  [[SALAH] “Perawat Royal td suaminya jg wafat b...
# 3  [[SALAH] “Katanya jaga jarak mutusin mataranta...
# 4  [[SALAH] Pesan Berantai “Ganjar Pranowo Bolehk...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/19/false-1962-...
# 1  https://turnbackhoax.id/2020/05/18/salah-wapre...
# 2  https://turnbackhoax.id/2020/05/18/salah-peraw...
# 3  https://turnbackhoax.id/2020/05/18/salah-katan...
# 4  https://turnbackhoax.id/2020/05/18/salah-pesan...

# %%
# Mengganti nama kolom pada DataFrame "df44"
df44.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df44.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] Video “Ibu ini cuma dapat bantuan ber...
# 16  [[SALAH] “500 TKA dari China untuk sebagian pe...
# 17  [[SALAH] “Karena dia bukan pilihan rakyat, Ini...
# 18  [[SALAH] “Proses Pemilu dimasa Corona hanya me...
# 19  [[SALAH] Jalur Perbatasan Sintang Pinoh Ditutu...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/13/salah-video...
# 16  https://turnbackhoax.id/2020/05/13/salah-500-t...
# 17  https://turnbackhoax.id/2020/05/12/salah-karen...
# 18  https://turnbackhoax.id/2020/05/12/salah-prose...
# 19  https://turnbackhoax.id/2020/05/12/salah-jalur...

# %% [markdown]
# ### Halaman 45

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/45/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df45 = pd.DataFrame(data)
df45.head()
# Out:
#                                                    0  \
# 0  [[SALAH] @call.serviis.homecredit.id dan @home...
# 1  [[FALSE] “Jack Ma’s advice, hopefully we can g...
# 2  [[SALAH] “Saran Jack Ma semoga kita bisa melew...
# 3  [[SALAH] “Masuukk truusss silahkan masuukk, Or...
# 4    [[SALAH] Bupati Konawe Akui Disuap Menko Luhut]
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/12/salah-call-...
# 1  https://turnbackhoax.id/2020/05/11/false-jack-...
# 2  https://turnbackhoax.id/2020/05/11/salah-saran...
# 3  https://turnbackhoax.id/2020/05/11/salah-masuu...
# 4  https://turnbackhoax.id/2020/05/10/salah-bupat...

# %%
# Mengganti nama kolom pada DataFrame "df45"
df45.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df45.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Pengeluaran Rokok Ekspedisi Tanggal ...
# 16  [[SALAH] Video “cara pertolongan Emergency Cov...
# 17  [[SALAH] Terjadi Pemblokiran Akses Jalan Kerin...
# 18  [[SALAH] Foto “Satu-satunya orang yang diizink...
# 19   [[SALAH] “Data menunjukkan ACEH hanya 1 korban”]
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/05/03/salah-penge...
# 16  https://turnbackhoax.id/2020/05/03/salah-video...
# 17  https://turnbackhoax.id/2020/05/02/salah-terja...
# 18  https://turnbackhoax.id/2020/05/02/salah-foto-...
# 19  https://turnbackhoax.id/2020/05/02/salah-data-...

# %% [markdown]
# ### Halaman 46

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/46/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df46 = pd.DataFrame(data)
df46.head()
# Out:
#                                                    0  \
# 0  [[SALAH] Peta Jalur Lalu Lintas PSBB Kota Tasi...
# 1  [[SALAH] “Arab Saudi merayakan masa berakhirny...
# 2  [[SALAH] “Elisa Granato kelinci percobaan vaks...
# 3  [[SALAH] “Fatwah wapres gila Menghina Jokowi S...
# 4  [[SALAH] “Profesor Dr Tasuku Honjo mengatakan ...
#
#                                                    1
# 0  https://turnbackhoax.id/2020/05/01/salah-peta-...
# 1  https://turnbackhoax.id/2020/05/01/salah-arab-...
# 2  https://turnbackhoax.id/2020/05/01/salah-elisa...
# 3  https://turnbackhoax.id/2020/05/01/salah-fatwa...
# 4  https://turnbackhoax.id/2020/04/29/salah-profe...

# %%
# Mengganti nama kolom pada DataFrame "df46"
df46.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df46.tail()
# Out:
#                                                  Text  \
# 15  [[SALAH] “Gibran: Kata Bapak Jadi Pemimpin Itu...
# 16        [[SALAH] Pilkada 2020 Sumenep Siap Digelar]
# 17  [[SALAH] Petugas Kebersihan SMAN 10 Yogyakarta...
# 18  [[SALAH] Tidak Ada Pasien Positif Corona di Aceh]
# 19  [[SALAH] Video “nasehat dari alm. Erma Yunita ...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/04/27/salah-gibra...
# 16  https://turnbackhoax.id/2020/04/27/salah-pilka...
# 17  https://turnbackhoax.id/2020/04/26/salah-petug...
# 18  https://turnbackhoax.id/2020/04/25/salah-tidak...
# 19  https://turnbackhoax.id/2020/04/25/salah-video...

# %% [markdown]
# ### Halaman 47

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/47/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df47 = pd.DataFrame(data)
df47.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] “Ini kiriman video betapa dahsyatnya ...
# 16              [[SALAH] Foto “Percuma di lock down”]
# 17  [[SALAH] “Sejumlah Polisi India Telah Tiba Di ...
# 18  [[SALAH] KJP Dicabut Dan Kurungan 3 Bulan Bagi...
# 19  [[SALAH] “ujar Xi Jin Ping Hanya Indonesia Yg ...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/15/salah-ini-k...
# 16  https://turnbackhoax.id/2020/04/14/salah-foto-...
# 17  https://turnbackhoax.id/2020/04/14/salah-sejum...
# 18  https://turnbackhoax.id/2020/04/14/salah-kjp-d...
# 19  https://turnbackhoax.id/2020/04/14/salah-ujar-...

# %%
# Mengganti nama kolom pada DataFrame "df47"
df47.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df47.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Kota Serang Berlakukan PSBB Terhitung...
# 1  [[SALAH] “Gubernur SUMUT instruksikan Seluruh ...
# 2  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 3  [[SALAH] Foto Di Tengah Pemerintah Sibuk Melaw...
# 4       [[SALAH] Azan Dapat Melemahkan Virus Corona]
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/25/salah-kota-...
# 1  https://turnbackhoax.id/2020/04/24/salah-guber...
# 2  https://turnbackhoax.id/2020/04/22/top-5-topik...
# 3  https://turnbackhoax.id/2020/04/22/salah-foto-...
# 4  https://turnbackhoax.id/2020/04/21/salah-azan-...

# %% [markdown]
# ### Halaman 48

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/48/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df48 = pd.DataFrame(data)
df48.tail()
# Out:
#                                                     0  \
# 15       [[SALAH] Perampokan di Jalan Tidar Surabaya]
# 16  [[FALSE] Videos of “Italian suicide who lost e...
# 17  [[SALAH] “Listrik gratis dan diskon yang diber...
# 18                     [[SALAH] “SITUBONDO LOCKDOWN”]
# 19  [[SALAH] “Daftar list hotel di bali yg di jual...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/09/salah-peram...
# 16  https://turnbackhoax.id/2020/04/09/false-video...
# 17  https://turnbackhoax.id/2020/04/09/salah-listr...
# 18  https://turnbackhoax.id/2020/04/08/salah-situb...
# 19  https://turnbackhoax.id/2020/04/08/salah-dafta...

# %%
# Mengganti nama kolom pada DataFrame "df48"
df48.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df48.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Pasien Postif Virus Corona di Sungai ...
# 1  [[SALAH] Hotman Paris Berencana Undang BTS dan...
# 2  [[SALAH] Jokowi Keluarkan Kartu Corona Indones...
# 3  [[SALAH] Akun Instagram Mengatasnamakan BNPB M...
# 4  [[SALAH] Video “BLACK MARKET *ITALIA SUDAH MEN...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/14/salah-pasie...
# 1  https://turnbackhoax.id/2020/04/14/salah-hotma...
# 2  https://turnbackhoax.id/2020/04/14/salah-jokow...
# 3  https://turnbackhoax.id/2020/04/13/salah-akun-...
# 4  https://turnbackhoax.id/2020/04/13/salah-video...

# %% [markdown]
# ### Halaman 49

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/49/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df49 = pd.DataFrame(data)
df49.tail()
# Out:
#                                                     0  \
# 15  [[SALAH] Video “Italian millionaire terjun Dar...
# 16  [[FALSE] Picture of “In Italy they throw their...
# 17  [[SALAH] Seperti Inilah Bentuk Corona Yang Ber...
# 18   [[SALAH] “Pengumuman Dia Masih Punya Stok Malu”]
# 19  [[SALAH] Gratis Layanan Netflix Selama Tiga Bu...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/04/04/salah-video...
# 16  https://turnbackhoax.id/2020/04/03/false-pictu...
# 17  https://turnbackhoax.id/2020/04/03/salah-seper...
# 18  https://turnbackhoax.id/2020/04/03/salah-pengu...
# 19  https://turnbackhoax.id/2020/04/03/salah-grati...

# %%
# Mengganti nama kolom pada DataFrame "df49"
df49.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df49.head()
# Out:
#                                                 Text  \
# 0  [[SALAH] Corona Jihad: Seorang Pedagang Sengaj...
# 1  [[SALAH] Merokok Menghadang Virus Corona Masuk...
# 2  [[Top 5] Topik Teratas Periksa Fakta MAFINDO P...
# 3  [[SALAH] “Rezim togog Bedebah pasilitasi karan...
# 4  [[SALAH] Video “Ngeri Karena Corona Italia pun...
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/07/salah-coron...
# 1  https://turnbackhoax.id/2020/04/07/salah-merok...
# 2  https://turnbackhoax.id/2020/04/07/top-5-topik...
# 3  https://turnbackhoax.id/2020/04/06/salah-rezim...
# 4  https://turnbackhoax.id/2020/04/06/salah-video...

# %% [markdown]
# ### Halaman 50

# %%
# Memanggil keyword dan menyalin url
keyword = "covid-19"
url = "https://turnbackhoax.id/page/50/?s={}".format(keyword)

# %%
# Request URL
req = requests.get(url)

# Merubah format dari yang semula HTML dengan BeautifulSoup 
soup = BeautifulSoup(req.text, "html.parser")

# Memanggil seluruh artikel yang berada di halaman luar
column = soup.findAll("div", "mh-loop-content mh-clearfix")

data = [] # Untuk menampung hasil dari scrapping data

for i in column:
    text = i.find("h3", "entry-title mh-loop-title").text.strip().split("\n")
    link = i.find("a", {"rel": "bookmark"})["href"]
    data.append([text, link])

# %%
# Memasukkan hasil scrapping ke dalam DataFrame
df50 = pd.DataFrame(data)
df50.tail()
# Out:
#                                                     0  \
# 15               [[SALAH] Karantina Wilayah Di India]
# 16  [[SALAH] Universitas Brawijaya Kembalikan Uang...
# 17  [[SALAH] Penganut Islam Kristen, Yahudi dan Bu...
# 18  [[SALAH] Efek Kejut Ciri Khas Gubernur, Angka ...
# 19  [[FALSE] Video “In America there has been loot...
#
#                                                     1
# 15  https://turnbackhoax.id/2020/03/31/salah-karan...
# 16  https://turnbackhoax.id/2020/03/31/salah-unive...
# 17  https://turnbackhoax.id/2020/03/31/salah-penga...
# 18  https://turnbackhoax.id/2020/03/31/salah-efek-...
# 19  https://turnbackhoax.id/2020/03/30/false-video...

# %%
# Mengganti nama kolom pada DataFrame "df50"
df50.rename(columns={0:"Text", 1:"URL"}, inplace = True)
df50.head()
# Out:
#                                                 Text  \
# 0          [[SALAH] Video “Ini lockdown di Spanyol”]
# 1  [[SALAH] “Untuk mengalahkan virus korona adala...
# 2  [[SALAH] Video “Azan PERTAMA di SPANYOL Setela...
# 3  [[SALAH] “Sekeluarga Kena Corona, Tinggal di B...
# 4             [[FALSE] Video of “lockdown in Spain”]
#
#                                                  URL
# 0  https://turnbackhoax.id/2020/04/03/salah-video...
# 1  https://turnbackhoax.id/2020/04/03/salah-untuk...
# 2  https://turnbackhoax.id/2020/04/02/salah-video...
# 3  https://turnbackhoax.id/2020/04/02/salah-sekel...
# 4  https://turnbackhoax.id/2020/04/02/false-pictu...

# %% [markdown]
# ### Menggabungkan Beberapa DataFrame Menjadi 1

# %%
# Membuat DataFrame untuk menampung hasil dari 50 df
data = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, 
       df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40,
       df41, df42, df43, df44, df45, df46, df47, df48, df49, df50]

# Menggabungkan 50 df menjadi 1 dengan fungsi "concat"
data_scrapping = pd.concat(data)

data_scrapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    1000 non-null   object
#  1   URL     1000 non-null   object
# dtypes: object(2)
# memory usage: 23.4+ KB

# %%
data_scrapping.tail()
# Out:
#                                                  Text  \
# 15               [[SALAH] Karantina Wilayah Di India]
# 16  [[SALAH] Universitas Brawijaya Kembalikan Uang...
# 17  [[SALAH] Penganut Islam Kristen, Yahudi dan Bu...
# 18  [[SALAH] Efek Kejut Ciri Khas Gubernur, Angka ...
# 19  [[FALSE] Video “In America there has been loot...
#
#                                                   URL
# 15  https://turnbackhoax.id/2020/03/31/salah-karan...
# 16  https://turnbackhoax.id/2020/03/31/salah-unive...
# 17  https://turnbackhoax.id/2020/03/31/salah-penga...
# 18  https://turnbackhoax.id/2020/03/31/salah-efek-...
# 19  https://turnbackhoax.id/2020/03/30/false-video...

# %%
# Menjadikan DataFrame ke dalam bentuk .csv
data_scrapping.to_csv("Data Scraping (turn back hoax) - covid-19.csv", index=False)
